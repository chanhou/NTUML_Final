# %% [markdown]
# ## Lasagne code try and edit

# %% [markdown]
# ## input our data

# %%
import numpy as np
import math
import scipy.linalg as sp
from sklearn.datasets import load_svmlight_file

# %%
xx_train, y = load_svmlight_file("./phase1/new/aug_train_50_big.dat")
# print type(xx_train)
print xx_train.shape
xx_train = np.array(xx_train.todense()).reshape(-1,)
# xx_train = xx_train.dtype(np.float32)
xx_train = np.float32(xx_train)
xx_train = xx_train.reshape(24696,2500)
# print xx_train.shape
print type(xx_train)
# Out:
# (24696, 2500)
# <type 'numpy.ndarray'>

# %%
sizee = 50

# %%
# pylab.ion()
# pylab.imshow(xxxx[0],cmap=cm.gray)
x = xx_train.reshape(24696,sizee**2)
x = x.astype(np.float32)

print x.shape
print type(x)
# Out:
# (24696, 2500)
# <type 'numpy.ndarray'>

# %%
def one_hot(x,n):
    if type(x) == list:
            x = np.array(x)
    x = x.flatten()
    o_h = np.zeros((len(x),n))
    o_h[np.arange(len(x)),x] = 1
    return o_h

y = y.astype(int32)    
y = one_hot(y, 32)
y = y.astype(np.float32)

print y.shape
# Out:
# (24696, 32)

# %% [markdown]
# ## split data

# %%
from sklearn import cross_validation as cv
from sklearn import svm
from sklearn import metrics
from sklearn import grid_search as gs

# %%
X_train, X_test, y_train, y_test = cv.train_test_split(x, y, test_size=0.2)

# %%
print X_train.shape
print X_test.shape
print y_train.shape
print y_test.shape

# %% [markdown]
# ## First model of Lasagne with single hidden layer

# %%
# add to kfkd.py
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet

net1 = NeuralNet(
    layers=[  # three layers: one hidden layer
        ('input', layers.InputLayer),
        ('hidden', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    # layer parameters:
    input_shape=(128, 2500),  # 128 images per batch times 100x100 input pixels
    hidden_num_units=300,  # number of units in hidden layer
    output_nonlinearity=None,  # output layer uses identity function
    output_num_units=32,  # 30 target values

    # optimization method:
    upate=nesterov_momentum,
    update_learning_rate=0.01,
    update_momentum=0.9,

    # regression=False,  # flag to indicate we're dealing with regression problem
    regression=True,  # flag to indicate we're dealing with regression problem
    max_epochs=1000,  # we want to train this many epochs
    verbose=1,
    )
# Out:
# Using gpu device 0: GRID K520

# %%
# %time net1.fit(X_train, y_train)

# %%
train_loss = np.array([i["train_loss"] for i in net1.train_history_])
valid_loss = np.array([i["valid_loss"] for i in net1.train_history_])
pyplot.plot(train_loss, linewidth=3, label="train")
pyplot.plot(valid_loss, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(2.5e-2, 0.32e-1)
# pyplot.yscale("log")
pyplot.show()

# %%
from sklearn import metrics

# overfit result, should use validation result
y_pred = net1.predict(X_test)
# print y_pred[1]
# np.argmax(y_pred[i]),np.argmax(y[i])
y_pred = np.array(map((lambda x: np.argmax(x)), y_pred))
yyy = np.array(map((lambda x: np.argmax(x)), y_test))

print metrics.classification_report((yyy), (y_pred))

# %% [markdown]
# ## NET 6 in the rock

# %%
import theano
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet

def float32(k):
    return np.cast['float32'](k)

class AdjustVariable(object):
    def __init__(self, name, start=0.03, stop=0.001):
        self.name = name
        self.start, self.stop = start, stop
        self.ls = None

    def __call__(self, nn, train_history):
        if self.ls is None:
            self.ls = np.linspace(self.start, self.stop, nn.max_epochs)

        epoch = train_history[-1]['epoch']
        new_value = float32(self.ls[epoch - 1])
        getattr(nn, self.name).set_value(new_value)

class EarlyStopping(object):
    def __init__(self, patience=100):
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_weights = None

    def __call__(self, nn, train_history):
        current_valid = train_history[-1]['valid_loss']
        current_epoch = train_history[-1]['epoch']
        if current_valid < self.best_valid:
            self.best_valid = current_valid
            self.best_valid_epoch = current_epoch
            self.best_weights = [w.get_value() for w in nn.get_all_params()]
        elif self.best_valid_epoch + self.patience < current_epoch:
            print("Early stopping.")
            print("Best valid loss was {:.6f} at epoch {}.".format(
                self.best_valid, self.best_valid_epoch))
            nn.load_weights_from(self.best_weights)
            raise StopIteration()
        
# use the cuda-convnet implementations of conv and max-pool layer
Conv2DLayer = layers.cuda_convnet.Conv2DCCLayer
MaxPool2DLayer = layers.cuda_convnet.MaxPool2DCCLayer

net7 = NeuralNet(
    layers=[
        ('input', layers.InputLayer),
        ('conv1', Conv2DLayer),
        ('pool1', MaxPool2DLayer),
        ('dropout1', layers.DropoutLayer),  # !
        ('conv2', Conv2DLayer),
        ('pool2', MaxPool2DLayer),
        ('dropout2', layers.DropoutLayer),  # !
        ('conv3', Conv2DLayer),
        ('pool3', MaxPool2DLayer),
        ('dropout3', layers.DropoutLayer),  # !
        ('hidden4', layers.DenseLayer),
        ('dropout4', layers.DropoutLayer),  # !
        ('hidden5', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    input_shape=(128, 1, 50,50),
    conv1_num_filters=32, conv1_filter_size=(3, 3), pool1_ds=(2, 2),
    # dropout1_p=0.1, # !
    dropout1_p=0.3,  # !
    conv2_num_filters=64, conv2_filter_size=(2, 2), pool2_ds=(2, 2),
    # dropout2_p=0.2,  # !
    dropout2_p=0.4,  # !
    conv3_num_filters=128, conv3_filter_size=(2, 2), pool3_ds=(2, 2),
    # dropout3_p=0.3,  # !
    dropout3_p=0.5,  # !
    hidden4_num_units=1000,
    # hidden4_num_units=1000,  # !
    dropout4_p=0.5,  # !
    hidden5_num_units=1000,
    # hidden5_num_units=1000,  # !
    output_num_units=32, output_nonlinearity=None,

    update_learning_rate=theano.shared(float32(0.03)),
    update_momentum=theano.shared(float32(0.9)),

    regression=True,
#     batch_iterator=FlipBatchIterator(batch_size=128),
    on_epoch_finished=[
        AdjustVariable('update_learning_rate', start=0.03, stop=0.0001),
        AdjustVariable('update_momentum', start=0.9, stop=0.999),
        EarlyStopping(patience=200),
        ],
    # max_epochs=3000,
    max_epochs=10000,
    verbose=1,
    )

# %%
def transform_6(X,y):
    X = X.reshape(-1, 50,50, 1)
    X = X.transpose(0, 3, 1, 2)
    return X, y

# X_train = X_train.reshape(-1,1,sizee,sizee)
# X_test = X_test.reshape(-1, 1,sizee,sizee)
# X_train.shape

# %%
import sys
sys.setrecursionlimit(10000)

X_6, y_6 = transform_6(X_train, y_train)
# %time net7.fit(X_6, y_6)

import cPickle as pickle
with open('Lasagne_6th_drop_change_extend.pickle', 'wb') as f:
    pickle.dump(net7, f, -1)

# %% [markdown]
# # start from here!!!!!!!!!!!!!!!!!!!!!
#
# ## load model from Lasagne_6th_drop_change_extend.pickle extend with test1 answer

# %%
import cPickle as pickle
with open('./Lasagne_5th_try_drop_change.pickle', 'rb') as f:
    net7 = pickle.load(f)

# %%
# from sklearn.base import clone
# model2 = clone(net7)
# model2.load_weights_from(model)

# %%
# model

# %%
train_loss_6 = np.array([i["train_loss"] for i in net7.train_history_])
valid_loss_6 = np.array([i["valid_loss"] for i in net7.train_history_])
pyplot.plot(train_loss_6, linewidth=3, label="train")
pyplot.plot(valid_loss_6, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(0.1e-2, 3.2e-2)
# pyplot.yscale("log")
pyplot.show()

# %%
# net7.dropout1_p = 0.2
# net7.dropout2_p = 0.3
# net7.dropout3_p = 0.4
net7.max_epochs = 2500

# %%
import sys
sys.setrecursionlimit(10000)

X_6, y_6 = transform_6(x, y)
# %time net7.fit(X_6, y_6)

import cPickle as pickle
with open('Lasagne_7th_test1_0.pickle', 'wb') as f:
    pickle.dump(net7, f, -1)

# %%
train_loss_6 = np.array([i["train_loss"] for i in net7.train_history_])
valid_loss_6 = np.array([i["valid_loss"] for i in net7.train_history_])
pyplot.plot(train_loss_6, linewidth=3, label="train")
pyplot.plot(valid_loss_6, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(0.1e-2, 3.2e-2)
# pyplot.yscale("log")
pyplot.show()

# %%
# from sklearn import metrics

# Xt_6, yt_6 = transform_6(X_test, y_test)

# # overfit result, should use validation result
# y_pred = net7.predict(Xt_6)
# # print y_pred[1]
# # np.argmax(y_pred[i]),np.argmax(y[i])
# y_pred = np.array(map((lambda x: np.argmax(x)), y_pred))
# yyy = np.array(map((lambda x: np.argmax(x)), yt_6))

# print metrics.classification_report((yyy), (y_pred))

# %% [markdown]
# ## load model

# %%
import cPickle as pickle

with open('./Lasagne_9th_all.pickle', 'rb') as f:
    specialists = pickle.load(f)

# %%
specialists.train_history_
# Out:
# [{'epoch': 1,
#   'train_loss': 0.031701237,
#   'valid_accuracy': 0.030251846,
#   'valid_loss': 0.030251846},
#  {'epoch': 2,
#   'train_loss': 0.030146869,
#   'valid_accuracy': 0.030227128,
#   'valid_loss': 0.030227128},
#  {'epoch': 3,
#   'train_loss': 0.030017456,
#   'valid_accuracy': 0.030227209,
#   'valid_loss': 0.030227209},
#  {'epoch': 4,
#   'train_loss': 0.029898841,
#   'valid_accuracy': 0.030235669,
#   'valid_loss': 0.030235669},
#  {'epoch': 5,
#   'train_loss': 0.029791014,
#   'valid_accuracy': 0.030251389,
#   'valid_loss': 0.030251389},
#  {'epoch': 6,
#   'train_loss': 0.029671911,
#   'valid_accuracy': 0.030271754,
#   'valid_loss': 0.030271754},
#  {'epoch': 7,
#   'train_loss': 0.029559325,
#   'valid_accuracy': 0.030300092,
#   'valid_loss': 0.030300092},
#  {'epoch': 8,
#   'train_loss': 0.029480547,
#   'valid_accuracy': 0.03030611,
#   'valid_loss': 0.03030611},
#  {'epoch': 9,
#   'train_loss': 0.029405085,
#   'valid_accuracy': 0.030296244,
#   'valid_loss': 0.030296244},
#  {'epoch': 10,
#   'train_loss': 0.02933673,
#   'valid_accuracy': 0.030306129,
#   'valid_loss': 0.030306129},
#  {'epoch': 11,
#   'train_loss': 0.029287631,
#   'valid_accuracy': 0.030309601,
#   'valid_loss': 0.030309601},
#  {'epoch': 12,
#   'train_loss': 0.02922334,
#   'valid_accuracy': 0.030299759,
#   'valid_loss': 0.030299759},
#  {'epoch': 13,
#   'train_loss': 0.029177155,
#   'valid_accuracy': 0.030240813,
#   'valid_loss': 0.030240813},
#  {'epoch': 14,
#   'train_loss': 0.029123524,
#   'valid_accuracy': 0.030219933,
#   'valid_loss': 0.030219933},
#  {'epoch': 15,
#   'train_loss': 0.029063584,
#   'valid_accuracy': 0.03018154,
#   'valid_loss': 0.03018154},
#  {'epoch': 16,
#   'train_loss': 0.029034279,
#   'valid_accuracy': 0.030118337,
#   'valid_loss': 0.030118337},
#  {'epoch': 17,
#   'train_loss': 0.028996326,
#   'valid_accuracy': 0.030093623,
#   'valid_loss': 0.030093623},
#  {'epoch': 18,
#   'train_loss': 0.028940465,
#   'valid_accuracy': 0.030049132,
#   'valid_loss': 0.030049132},
#  {'epoch': 19,
#   'train_loss': 0.028888257,
#   'valid_accuracy': 0.030002352,
#   'valid_loss': 0.030002352},
#  {'epoch': 20,
#   'train_loss': 0.028841747,
#   'valid_accuracy': 0.030004807,
#   'valid_loss': 0.030004807},
#  {'epoch': 21,
#   'train_loss': 0.028788052,
#   'valid_accuracy': 0.029926347,
#   'valid_loss': 0.029926347},
#  {'epoch': 22,
#   'train_loss': 0.028750114,
#   'valid_accuracy': 0.029881192,
#   'valid_loss': 0.029881192},
#  {'epoch': 23,
#   'train_loss': 0.028710043,
#   'valid_accuracy': 0.029868403,
#   'valid_loss': 0.029868403},
#  {'epoch': 24,
#   'train_loss': 0.028632779,
#   'valid_accuracy': 0.029742459,
#   'valid_loss': 0.029742459},
#  {'epoch': 25,
#   'train_loss': 0.028582737,
#   'valid_accuracy': 0.029731808,
#   'valid_loss': 0.029731808},
#  {'epoch': 26,
#   'train_loss': 0.028541811,
#   'valid_accuracy': 0.029670862,
#   'valid_loss': 0.029670862},
#  {'epoch': 27,
#   'train_loss': 0.028485864,
#   'valid_accuracy': 0.02960185,
#   'valid_loss': 0.02960185},
#  {'epoch': 28,
#   'train_loss': 0.028433507,
#   'valid_accuracy': 0.0296285,
#   'valid_loss': 0.0296285},
#  {'epoch': 29,
#   'train_loss': 0.028397178,
#   'valid_accuracy': 0.029504467,
#   'valid_loss': 0.029504467},
#  {'epoch': 30,
#   'train_loss': 0.028338673,
#   'valid_accuracy': 0.029478746,
#   'valid_loss': 0.029478746},
#  {'epoch': 31,
#   'train_loss': 0.028283492,
#   'valid_accuracy': 0.029414177,
#   'valid_loss': 0.029414177},
#  {'epoch': 32,
#   'train_loss': 0.02825099,
#   'valid_accuracy': 0.029347645,
#   'valid_loss': 0.029347645},
#  {'epoch': 33,
#   'train_loss': 0.028181903,
#   'valid_accuracy': 0.029314928,
#   'valid_loss': 0.029314928},
#  {'epoch': 34,
#   'train_loss': 0.028148958,
#   'valid_accuracy': 0.029266868,
#   'valid_loss': 0.029266868},
#  {'epoch': 35,
#   'train_loss': 0.02810158,
#   'valid_accuracy': 0.029234285,
#   'valid_loss': 0.029234285},
#  {'epoch': 36,
#   'train_loss': 0.028045215,
#   'valid_accuracy': 0.0291686,
#   'valid_loss': 0.0291686},
#  {'epoch': 37,
#   'train_loss': 0.028015954,
#   'valid_accuracy': 0.029127097,
#   'valid_loss': 0.029127097},
#  {'epoch': 38,
#   'train_loss': 0.027970398,
#   'valid_accuracy': 0.029056262,
#   'valid_loss': 0.029056262},
#  {'epoch': 39,
#   'train_loss': 0.027922049,
#   'valid_accuracy': 0.029020127,
#   'valid_loss': 0.029020127},
#  {'epoch': 40,
#   'train_loss': 0.027862161,
#   'valid_accuracy': 0.028966436,
#   'valid_loss': 0.028966436},
#  {'epoch': 41,
#   'train_loss': 0.02780683,
#   'valid_accuracy': 0.02891255,
#   'valid_loss': 0.02891255},
#  {'epoch': 42,
#   'train_loss': 0.027782898,
#   'valid_accuracy': 0.028886257,
#   'valid_loss': 0.028886257},
#  {'epoch': 43,
#   'train_loss': 0.02773596,
#   'valid_accuracy': 0.028822817,
#   'valid_loss': 0.028822817},
#  {'epoch': 44,
#   'train_loss': 0.027667262,
#   'valid_accuracy': 0.028835082,
#   'valid_loss': 0.028835082},
#  {'epoch': 45,
#   'train_loss': 0.02763626,
#   'valid_accuracy': 0.028780174,
#   'valid_loss': 0.028780174},
#  {'epoch': 46,
#   'train_loss': 0.027598046,
#   'valid_accuracy': 0.02869267,
#   'valid_loss': 0.02869267},
#  {'epoch': 47,
#   'train_loss': 0.027547743,
#   'valid_accuracy': 0.028666206,
#   'valid_loss': 0.028666206},
#  {'epoch': 48,
#   'train_loss': 0.027502934,
#   'valid_accuracy': 0.0285853,
#   'valid_loss': 0.0285853},
#  {'epoch': 49,
#   'train_loss': 0.027475679,
#   'valid_accuracy': 0.028605742,
#   'valid_loss': 0.028605742},
#  {'epoch': 50,
#   'train_loss': 0.027419869,
#   'valid_accuracy': 0.028538674,
#   'valid_loss': 0.028538674},
#  {'epoch': 51,
#   'train_loss': 0.027361633,
#   'valid_accuracy': 0.02846978,
#   'valid_loss': 0.02846978},
#  {'epoch': 52,
#   'train_loss': 0.027326206,
#   'valid_accuracy': 0.028466467,
#   'valid_loss': 0.028466467},
#  {'epoch': 53,
#   'train_loss': 0.027278595,
#   'valid_accuracy': 0.028400084,
#   'valid_loss': 0.028400084},
#  {'epoch': 54,
#   'train_loss': 0.027252976,
#   'valid_accuracy': 0.028347878,
#   'valid_loss': 0.028347878},
#  {'epoch': 55,
#   'train_loss': 0.027200704,
#   'valid_accuracy': 0.028327486,
#   'valid_loss': 0.028327486},
#  {'epoch': 56,
#   'train_loss': 0.02716675,
#   'valid_accuracy': 0.02828709,
#   'valid_loss': 0.02828709},
#  {'epoch': 57,
#   'train_loss': 0.027091352,
#   'valid_accuracy': 0.028190598,
#   'valid_loss': 0.028190598},
#  {'epoch': 58,
#   'train_loss': 0.027056415,
#   'valid_accuracy': 0.02813584,
#   'valid_loss': 0.02813584},
#  {'epoch': 59,
#   'train_loss': 0.026992528,
#   'valid_accuracy': 0.028087711,
#   'valid_loss': 0.028087711},
#  {'epoch': 60,
#   'train_loss': 0.026949985,
#   'valid_accuracy': 0.028064208,
#   'valid_loss': 0.028064208},
#  {'epoch': 61,
#   'train_loss': 0.026907293,
#   'valid_accuracy': 0.028026363,
#   'valid_loss': 0.028026363},
#  {'epoch': 62,
#   'train_loss': 0.026847314,
#   'valid_accuracy': 0.027987938,
#   'valid_loss': 0.027987938},
#  {'epoch': 63,
#   'train_loss': 0.026799418,
#   'valid_accuracy': 0.027856173,
#   'valid_loss': 0.027856173},
#  {'epoch': 64,
#   'train_loss': 0.026745064,
#   'valid_accuracy': 0.027882958,
#   'valid_loss': 0.027882958},
#  {'epoch': 65,
#   'train_loss': 0.026701903,
#   'valid_accuracy': 0.027766686,
#   'valid_loss': 0.027766686},
#  {'epoch': 66,
#   'train_loss': 0.026659135,
#   'valid_accuracy': 0.027686745,
#   'valid_loss': 0.027686745},
#  {'epoch': 67,
#   'train_loss': 0.026615817,
#   'valid_accuracy': 0.027666759,
#   'valid_loss': 0.027666759},
#  {'epoch': 68,
#   'train_loss': 0.026557796,
#   'valid_accuracy': 0.027659386,
#   'valid_loss': 0.027659386},
#  {'epoch': 69,
#   'train_loss': 0.026516512,
#   'valid_accuracy': 0.027512113,
#   'valid_loss': 0.027512113},
#  {'epoch': 70,
#   'train_loss': 0.026485296,
#   'valid_accuracy': 0.027461039,
#   'valid_loss': 0.027461039},
#  {'epoch': 71,
#   'train_loss': 0.026383689,
#   'valid_accuracy': 0.027444186,
#   'valid_loss': 0.027444186},
#  {'epoch': 72,
#   'train_loss': 0.02635075,
#   'valid_accuracy': 0.027346522,
#   'valid_loss': 0.027346522},
#  {'epoch': 73,
#   'train_loss': 0.02629764,
#   'valid_accuracy': 0.027294079,
#   'valid_loss': 0.027294079},
#  {'epoch': 74,
#   'train_loss': 0.026250806,
#   'valid_accuracy': 0.027189707,
#   'valid_loss': 0.027189707},
#  {'epoch': 75,
#   'train_loss': 0.026176533,
#   'valid_accuracy': 0.027115079,
#   'valid_loss': 0.027115079},
#  {'epoch': 76,
#   'train_loss': 0.026172044,
#   'valid_accuracy': 0.02711029,
#   'valid_loss': 0.02711029},
#  {'epoch': 77,
#   'train_loss': 0.026093328,
#   'valid_accuracy': 0.027013607,
#   'valid_loss': 0.027013607},
#  {'epoch': 78,
#   'train_loss': 0.026044624,
#   'valid_accuracy': 0.026910672,
#   'valid_loss': 0.026910672},
#  {'epoch': 79,
#   'train_loss': 0.026015984,
#   'valid_accuracy': 0.026890272,
#   'valid_loss': 0.026890272},
#  {'epoch': 80,
#   'train_loss': 0.02597517,
#   'valid_accuracy': 0.026825687,
#   'valid_loss': 0.026825687},
#  {'epoch': 81,
#   'train_loss': 0.025918918,
#   'valid_accuracy': 0.026806578,
#   'valid_loss': 0.026806578},
#  {'epoch': 82,
#   'train_loss': 0.025835836,
#   'valid_accuracy': 0.02677728,
#   'valid_loss': 0.02677728},
#  {'epoch': 83,
#   'train_loss': 0.025820922,
#   'valid_accuracy': 0.026621584,
#   'valid_loss': 0.026621584},
#  {'epoch': 84,
#   'train_loss': 0.025763454,
#   'valid_accuracy': 0.026586808,
#   'valid_loss': 0.026586808},
#  {'epoch': 85,
#   'train_loss': 0.025708862,
#   'valid_accuracy': 0.026542515,
#   'valid_loss': 0.026542515},
#  {'epoch': 86,
#   'train_loss': 0.025641426,
#   'valid_accuracy': 0.026461978,
#   'valid_loss': 0.026461978},
#  {'epoch': 87,
#   'train_loss': 0.025601091,
#   'valid_accuracy': 0.02641039,
#   'valid_loss': 0.02641039},
#  {'epoch': 88,
#   'train_loss': 0.02552598,
#   'valid_accuracy': 0.026415825,
#   'valid_loss': 0.026415825},
#  {'epoch': 89,
#   'train_loss': 0.025524845,
#   'valid_accuracy': 0.02629542,
#   'valid_loss': 0.02629542},
#  {'epoch': 90,
#   'train_loss': 0.025449615,
#   'valid_accuracy': 0.026260834,
#   'valid_loss': 0.026260834},
#  {'epoch': 91,
#   'train_loss': 0.02542571,
#   'valid_accuracy': 0.026118089,
#   'valid_loss': 0.026118089},
#  {'epoch': 92,
#   'train_loss': 0.025340674,
#   'valid_accuracy': 0.026093984,
#   'valid_loss': 0.026093984},
#  {'epoch': 93,
#   'train_loss': 0.025301581,
#   'valid_accuracy': 0.026034089,
#   'valid_loss': 0.026034089},
#  {'epoch': 94,
#   'train_loss': 0.025257876,
#   'valid_accuracy': 0.025906015,
#   'valid_loss': 0.025906015},
#  {'epoch': 95,
#   'train_loss': 0.025194265,
#   'valid_accuracy': 0.025869565,
#   'valid_loss': 0.025869565},
#  {'epoch': 96,
#   'train_loss': 0.025162213,
#   'valid_accuracy': 0.025801457,
#   'valid_loss': 0.025801457},
#  {'epoch': 97,
#   'train_loss': 0.025116585,
#   'valid_accuracy': 0.025772315,
#   'valid_loss': 0.025772315},
#  {'epoch': 98,
#   'train_loss': 0.025074024,
#   'valid_accuracy': 0.025678758,
#   'valid_loss': 0.025678758},
#  {'epoch': 99,
#   'train_loss': 0.02502848,
#   'valid_accuracy': 0.025696946,
#   'valid_loss': 0.025696946},
#  {'epoch': 100,
#   'train_loss': 0.024955831,
#   'valid_accuracy': 0.025657773,
#   'valid_loss': 0.025657773},
#  {'epoch': 101,
#   'train_loss': 0.024884852,
#   'valid_accuracy': 0.025609171,
#   'valid_loss': 0.025609171},
#  {'epoch': 102,
#   'train_loss': 0.024820732,
#   'valid_accuracy': 0.025479661,
#   'valid_loss': 0.025479661},
#  {'epoch': 103,
#   'train_loss': 0.024789933,
#   'valid_accuracy': 0.025426243,
#   'valid_loss': 0.025426243},
#  {'epoch': 104,
#   'train_loss': 0.024743125,
#   'valid_accuracy': 0.025355477,
#   'valid_loss': 0.025355477},
#  {'epoch': 105,
#   'train_loss': 0.024679018,
#   'valid_accuracy': 0.025273254,
#   'valid_loss': 0.025273254},
#  {'epoch': 106,
#   'train_loss': 0.024619948,
#   'valid_accuracy': 0.025151497,
#   'valid_loss': 0.025151497},
#  {'epoch': 107,
#   'train_loss': 0.024584077,
#   'valid_accuracy': 0.025133926,
#   'valid_loss': 0.025133926},
#  {'epoch': 108,
#   'train_loss': 0.024538828,
#   'valid_accuracy': 0.025147615,
#   'valid_loss': 0.025147615},
#  {'epoch': 109,
#   'train_loss': 0.024483219,
#   'valid_accuracy': 0.025020603,
#   'valid_loss': 0.025020603},
#  {'epoch': 110,
#   'train_loss': 0.024448967,
#   'valid_accuracy': 0.024932085,
#   'valid_loss': 0.024932085},
#  {'epoch': 111,
#   'train_loss': 0.024352472,
#   'valid_accuracy': 0.024935445,
#   'valid_loss': 0.024935445},
#  {'epoch': 112,
#   'train_loss': 0.024327442,
#   'valid_accuracy': 0.024796244,
#   'valid_loss': 0.024796244},
#  {'epoch': 113,
#   'train_loss': 0.024262395,
#   'valid_accuracy': 0.024792599,
#   'valid_loss': 0.024792599},
#  {'epoch': 114,
#   'train_loss': 0.024212176,
#   'valid_accuracy': 0.024694165,
#   'valid_loss': 0.024694165},
#  {'epoch': 115,
#   'train_loss': 0.024177307,
#   'valid_accuracy': 0.024628798,
#   'valid_loss': 0.024628798},
#  {'epoch': 116,
#   'train_loss': 0.024097059,
#   'valid_accuracy': 0.024572002,
#   'valid_loss': 0.024572002},
#  {'epoch': 117,
#   'train_loss': 0.024060303,
#   'valid_accuracy': 0.02450308,
#   'valid_loss': 0.02450308},
#  {'epoch': 118,
#   'train_loss': 0.024027741,
#   'valid_accuracy': 0.024527378,
#   'valid_loss': 0.024527378},
#  {'epoch': 119,
#   'train_loss': 0.023907386,
#   'valid_accuracy': 0.024320479,
#   'valid_loss': 0.024320479},
#  {'epoch': 120,
#   'train_loss': 0.023873938,
#   'valid_accuracy': 0.024307096,
#   'valid_loss': 0.024307096},
#  {'epoch': 121,
#   'train_loss': 0.023851704,
#   'valid_accuracy': 0.024208443,
#   'valid_loss': 0.024208443},
#  {'epoch': 122,
#   'train_loss': 0.023766486,
#   'valid_accuracy': 0.024146687,
#   'valid_loss': 0.024146687},
#  {'epoch': 123,
#   'train_loss': 0.023717372,
#   'valid_accuracy': 0.024097294,
#   'valid_loss': 0.024097294},
#  {'epoch': 124,
#   'train_loss': 0.023669839,
#   'valid_accuracy': 0.024087172,
#   'valid_loss': 0.024087172},
#  {'epoch': 125,
#   'train_loss': 0.023595229,
#   'valid_accuracy': 0.023962934,
#   'valid_loss': 0.023962934},
#  {'epoch': 126,
#   'train_loss': 0.023499142,
#   'valid_accuracy': 0.023882441,
#   'valid_loss': 0.023882441},
#  {'epoch': 127,
#   'train_loss': 0.02348078,
#   'valid_accuracy': 0.02388172,
#   'valid_loss': 0.02388172},
#  {'epoch': 128,
#   'train_loss': 0.023429357,
#   'valid_accuracy': 0.023809204,
#   'valid_loss': 0.023809204},
#  {'epoch': 129,
#   'train_loss': 0.02332731,
#   'valid_accuracy': 0.023612533,
#   'valid_loss': 0.023612533},
#  {'epoch': 130,
#   'train_loss': 0.023286127,
#   'valid_accuracy': 0.023518214,
#   'valid_loss': 0.023518214},
#  {'epoch': 131,
#   'train_loss': 0.023263743,
#   'valid_accuracy': 0.023566214,
#   'valid_loss': 0.023566214},
#  {'epoch': 132,
#   'train_loss': 0.023174183,
#   'valid_accuracy': 0.023428055,
#   'valid_loss': 0.023428055},
#  {'epoch': 133,
#   'train_loss': 0.023103718,
#   'valid_accuracy': 0.023411423,
#   'valid_loss': 0.023411423},
#  {'epoch': 134,
#   'train_loss': 0.02306078,
#   'valid_accuracy': 0.023303349,
#   'valid_loss': 0.023303349},
#  {'epoch': 135,
#   'train_loss': 0.02303105,
#   'valid_accuracy': 0.023272676,
#   'valid_loss': 0.023272676},
#  {'epoch': 136,
#   'train_loss': 0.022921575,
#   'valid_accuracy': 0.023182528,
#   'valid_loss': 0.023182528},
#  {'epoch': 137,
#   'train_loss': 0.022897243,
#   'valid_accuracy': 0.023091078,
#   'valid_loss': 0.023091078},
#  {'epoch': 138,
#   'train_loss': 0.022846261,
#   'valid_accuracy': 0.023044011,
#   'valid_loss': 0.023044011},
#  {'epoch': 139,
#   'train_loss': 0.022767317,
#   'valid_accuracy': 0.023012403,
#   'valid_loss': 0.023012403},
#  {'epoch': 140,
#   'train_loss': 0.022735529,
#   'valid_accuracy': 0.022885056,
#   'valid_loss': 0.022885056},
#  {'epoch': 141,
#   'train_loss': 0.022646079,
#   'valid_accuracy': 0.022827674,
#   'valid_loss': 0.022827674},
#  {'epoch': 142,
#   'train_loss': 0.022568377,
#   'valid_accuracy': 0.022749016,
#   'valid_loss': 0.022749016},
#  {'epoch': 143,
#   'train_loss': 0.022531798,
#   'valid_accuracy': 0.022750365,
#   'valid_loss': 0.022750365},
#  {'epoch': 144,
#   'train_loss': 0.022432428,
#   'valid_accuracy': 0.02261903,
#   'valid_loss': 0.02261903},
#  {'epoch': 145,
#   'train_loss': 0.022363171,
#   'valid_accuracy': 0.022478398,
#   'valid_loss': 0.022478398},
#  {'epoch': 146,
#   'train_loss': 0.022328651,
#   'valid_accuracy': 0.022405997,
#   'valid_loss': 0.022405997},
#  {'epoch': 147,
#   'train_loss': 0.022235963,
#   'valid_accuracy': 0.02237449,
#   'valid_loss': 0.02237449},
#  {'epoch': 148,
#   'train_loss': 0.022220757,
#   'valid_accuracy': 0.022323417,
#   'valid_loss': 0.022323417},
#  {'epoch': 149,
#   'train_loss': 0.022127103,
#   'valid_accuracy': 0.022192273,
#   'valid_loss': 0.022192273},
#  {'epoch': 150,
#   'train_loss': 0.022038862,
#   'valid_accuracy': 0.022123627,
#   'valid_loss': 0.022123627},
#  {'epoch': 151,
#   'train_loss': 0.021957802,
#   'valid_accuracy': 0.02209585,
#   'valid_loss': 0.02209585},
#  {'epoch': 152,
#   'train_loss': 0.021908924,
#   'valid_accuracy': 0.022027319,
#   'valid_loss': 0.022027319},
#  {'epoch': 153,
#   'train_loss': 0.021880021,
#   'valid_accuracy': 0.021887777,
#   'valid_loss': 0.021887777},
#  {'epoch': 154,
#   'train_loss': 0.021827839,
#   'valid_accuracy': 0.021829683,
#   'valid_loss': 0.021829683},
#  {'epoch': 155,
#   'train_loss': 0.021773852,
#   'valid_accuracy': 0.021726664,
#   'valid_loss': 0.021726664},
#  {'epoch': 156,
#   'train_loss': 0.021750821,
#   'valid_accuracy': 0.021636864,
#   'valid_loss': 0.021636864},
#  {'epoch': 157,
#   'train_loss': 0.021603465,
#   'valid_accuracy': 0.021591645,
#   'valid_loss': 0.021591645},
#  {'epoch': 158,
#   'train_loss': 0.021606449,
#   'valid_accuracy': 0.021440228,
#   'valid_loss': 0.021440228},
#  {'epoch': 159,
#   'train_loss': 0.021520644,
#   'valid_accuracy': 0.02141493,
#   'valid_loss': 0.02141493},
#  {'epoch': 160,
#   'train_loss': 0.021468649,
#   'valid_accuracy': 0.021286746,
#   'valid_loss': 0.021286746},
#  {'epoch': 161,
#   'train_loss': 0.021390298,
#   'valid_accuracy': 0.021197386,
#   'valid_loss': 0.021197386},
#  {'epoch': 162,
#   'train_loss': 0.021333197,
#   'valid_accuracy': 0.021172389,
#   'valid_loss': 0.021172389},
#  {'epoch': 163,
#   'train_loss': 0.021243939,
#   'valid_accuracy': 0.021077331,
#   'valid_loss': 0.021077331},
#  {'epoch': 164,
#   'train_loss': 0.021174902,
#   'valid_accuracy': 0.02100217,
#   'valid_loss': 0.02100217},
#  {'epoch': 165,
#   'train_loss': 0.021130113,
#   'valid_accuracy': 0.021005813,
#   'valid_loss': 0.021005813},
#  {'epoch': 166,
#   'train_loss': 0.021068249,
#   'valid_accuracy': 0.020923842,
#   'valid_loss': 0.020923842},
#  {'epoch': 167,
#   'train_loss': 0.021021744,
#   'valid_accuracy': 0.020845512,
#   'valid_loss': 0.020845512},
#  {'epoch': 168,
#   'train_loss': 0.020950057,
#   'valid_accuracy': 0.020740101,
#   'valid_loss': 0.020740101},
#  {'epoch': 169,
#   'train_loss': 0.02084502,
#   'valid_accuracy': 0.020564331,
#   'valid_loss': 0.020564331},
#  {'epoch': 170,
#   'train_loss': 0.020784359,
#   'valid_accuracy': 0.020490831,
#   'valid_loss': 0.020490831},
#  {'epoch': 171,
#   'train_loss': 0.020776182,
#   'valid_accuracy': 0.020450832,
#   'valid_loss': 0.020450832},
#  {'epoch': 172,
#   'train_loss': 0.020748468,
#   'valid_accuracy': 0.020332357,
#   'valid_loss': 0.020332357},
#  {'epoch': 173,
#   'train_loss': 0.020663554,
#   'valid_accuracy': 0.020302625,
#   'valid_loss': 0.020302625},
#  {'epoch': 174,
#   'train_loss': 0.020575354,
#   'valid_accuracy': 0.020232359,
#   'valid_loss': 0.020232359},
#  {'epoch': 175,
#   'train_loss': 0.020536501,
#   'valid_accuracy': 0.020114506,
#   'valid_loss': 0.020114506},
#  {'epoch': 176,
#   'train_loss': 0.0204884,
#   'valid_accuracy': 0.020037323,
#   'valid_loss': 0.020037323},
#  {'epoch': 177,
#   'train_loss': 0.020388341,
#   'valid_accuracy': 0.019989435,
#   'valid_loss': 0.019989435},
#  {'epoch': 178,
#   'train_loss': 0.020363588,
#   'valid_accuracy': 0.019917503,
#   'valid_loss': 0.019917503},
#  {'epoch': 179,
#   'train_loss': 0.020309314,
#   'valid_accuracy': 0.019863181,
#   'valid_loss': 0.019863181},
#  {'epoch': 180,
#   'train_loss': 0.020234613,
#   'valid_accuracy': 0.019729901,
#   'valid_loss': 0.019729901},
#  {'epoch': 181,
#   'train_loss': 0.020200519,
#   'valid_accuracy': 0.019563552,
#   'valid_loss': 0.019563552},
#  {'epoch': 182,
#   'train_loss': 0.020099105,
#   'valid_accuracy': 0.019652907,
#   'valid_loss': 0.019652907},
#  {'epoch': 183,
#   'train_loss': 0.020067759,
#   'valid_accuracy': 0.019521194,
#   'valid_loss': 0.019521194},
#  {'epoch': 184,
#   'train_loss': 0.020023661,
#   'valid_accuracy': 0.019520944,
#   'valid_loss': 0.019520944},
#  {'epoch': 185,
#   'train_loss': 0.019981883,
#   'valid_accuracy': 0.019306954,
#   'valid_loss': 0.019306954},
#  {'epoch': 186,
#   'train_loss': 0.019844184,
#   'valid_accuracy': 0.019308338,
#   'valid_loss': 0.019308338},
#  {'epoch': 187,
#   'train_loss': 0.019809822,
#   'valid_accuracy': 0.019247467,
#   'valid_loss': 0.019247467},
#  {'epoch': 188,
#   'train_loss': 0.019745586,
#   'valid_accuracy': 0.019202437,
#   'valid_loss': 0.019202437},
#  {'epoch': 189,
#   'train_loss': 0.019694565,
#   'valid_accuracy': 0.019193133,
#   'valid_loss': 0.019193133},
#  {'epoch': 190,
#   'train_loss': 0.01966274,
#   'valid_accuracy': 0.01903788,
#   'valid_loss': 0.01903788},
#  {'epoch': 191,
#   'train_loss': 0.019604962,
#   'valid_accuracy': 0.018906603,
#   'valid_loss': 0.018906603},
#  {'epoch': 192,
#   'train_loss': 0.019564265,
#   'valid_accuracy': 0.018904625,
#   'valid_loss': 0.018904625},
#  {'epoch': 193,
#   'train_loss': 0.019443797,
#   'valid_accuracy': 0.018793641,
#   'valid_loss': 0.018793641},
#  {'epoch': 194,
#   'train_loss': 0.019457694,
#   'valid_accuracy': 0.018700242,
#   'valid_loss': 0.018700242},
#  {'epoch': 195,
#   'train_loss': 0.019370666,
#   'valid_accuracy': 0.018689396,
#   'valid_loss': 0.018689396},
#  {'epoch': 196,
#   'train_loss': 0.019328309,
#   'valid_accuracy': 0.018581701,
#   'valid_loss': 0.018581701},
#  {'epoch': 197,
#   'train_loss': 0.019263929,
#   'valid_accuracy': 0.018544182,
#   'valid_loss': 0.018544182},
#  {'epoch': 198,
#   'train_loss': 0.019210558,
#   'valid_accuracy': 0.018486483,
#   'valid_loss': 0.018486483},
#  {'epoch': 199,
#   'train_loss': 0.019145625,
#   'valid_accuracy': 0.018391026,
#   'valid_loss': 0.018391026},
#  {'epoch': 200,
#   'train_loss': 0.019144265,
#   'valid_accuracy': 0.018420666,
#   'valid_loss': 0.018420666},
#  {'epoch': 201,
#   'train_loss': 0.019097332,
#   'valid_accuracy': 0.01824099,
#   'valid_loss': 0.01824099},
#  {'epoch': 202,
#   'train_loss': 0.018993447,
#   'valid_accuracy': 0.018230937,
#   'valid_loss': 0.018230937},
#  {'epoch': 203,
#   'train_loss': 0.018948551,
#   'valid_accuracy': 0.018163053,
#   'valid_loss': 0.018163053},
#  {'epoch': 204,
#   'train_loss': 0.018877776,
#   'valid_accuracy': 0.018035574,
#   'valid_loss': 0.018035574},
#  {'epoch': 205,
#   'train_loss': 0.018773379,
#   'valid_accuracy': 0.017960131,
#   'valid_loss': 0.017960131},
#  {'epoch': 206,
#   'train_loss': 0.018724656,
#   'valid_accuracy': 0.017905146,
#   'valid_loss': 0.017905146},
#  {'epoch': 207,
#   'train_loss': 0.018781682,
#   'valid_accuracy': 0.017892169,
#   'valid_loss': 0.017892169},
#  {'epoch': 208,
#   'train_loss': 0.018687706,
#   'valid_accuracy': 0.017785178,
#   'valid_loss': 0.017785178},
#  {'epoch': 209,
#   'train_loss': 0.018646946,
#   'valid_accuracy': 0.017731842,
#   'valid_loss': 0.017731842},
#  {'epoch': 210,
#   'train_loss': 0.018590324,
#   'valid_accuracy': 0.017646009,
#   'valid_loss': 0.017646009},
#  {'epoch': 211,
#   'train_loss': 0.018512914,
#   'valid_accuracy': 0.017569453,
#   'valid_loss': 0.017569453},
#  {'epoch': 212,
#   'train_loss': 0.018463135,
#   'valid_accuracy': 0.017444054,
#   'valid_loss': 0.017444054},
#  {'epoch': 213,
#   'train_loss': 0.018412193,
#   'valid_accuracy': 0.017505329,
#   'valid_loss': 0.017505329},
#  {'epoch': 214,
#   'train_loss': 0.018376522,
#   'valid_accuracy': 0.017559133,
#   'valid_loss': 0.017559133},
#  {'epoch': 215,
#   'train_loss': 0.018289914,
#   'valid_accuracy': 0.017354647,
#   'valid_loss': 0.017354647},
#  {'epoch': 216,
#   'train_loss': 0.018204952,
#   'valid_accuracy': 0.017390827,
#   'valid_loss': 0.017390827},
#  {'epoch': 217,
#   'train_loss': 0.018192491,
#   'valid_accuracy': 0.017230472,
#   'valid_loss': 0.017230472},
#  {'epoch': 218,
#   'train_loss': 0.018179834,
#   'valid_accuracy': 0.017212931,
#   'valid_loss': 0.017212931},
#  {'epoch': 219,
#   'train_loss': 0.018112827,
#   'valid_accuracy': 0.017111657,
#   'valid_loss': 0.017111657},
#  {'epoch': 220,
#   'train_loss': 0.018069349,
#   'valid_accuracy': 0.016999871,
#   'valid_loss': 0.016999871},
#  {'epoch': 221,
#   'train_loss': 0.017987162,
#   'valid_accuracy': 0.016964994,
#   'valid_loss': 0.016964994},
#  {'epoch': 222,
#   'train_loss': 0.01794323,
#   'valid_accuracy': 0.016925316,
#   'valid_loss': 0.016925316},
#  {'epoch': 223,
#   'train_loss': 0.017867185,
#   'valid_accuracy': 0.016884135,
#   'valid_loss': 0.016884135},
#  {'epoch': 224,
#   'train_loss': 0.017897144,
#   'valid_accuracy': 0.01676389,
#   'valid_loss': 0.01676389},
#  {'epoch': 225,
#   'train_loss': 0.017807629,
#   'valid_accuracy': 0.016715743,
#   'valid_loss': 0.016715743},
#  {'epoch': 226,
#   'train_loss': 0.017824119,
#   'valid_accuracy': 0.016683063,
#   'valid_loss': 0.016683063},
#  {'epoch': 227,
#   'train_loss': 0.017684162,
#   'valid_accuracy': 0.016593978,
#   'valid_loss': 0.016593978},
#  {'epoch': 228,
#   'train_loss': 0.017724214,
#   'valid_accuracy': 0.016620513,
#   'valid_loss': 0.016620513},
#  {'epoch': 229,
#   'train_loss': 0.017653096,
#   'valid_accuracy': 0.016471459,
#   'valid_loss': 0.016471459},
#  {'epoch': 230,
#   'train_loss': 0.017626263,
#   'valid_accuracy': 0.016584057,
#   'valid_loss': 0.016584057},
#  {'epoch': 231,
#   'train_loss': 0.017527185,
#   'valid_accuracy': 0.016422193,
#   'valid_loss': 0.016422193},
#  {'epoch': 232,
#   'train_loss': 0.017500112,
#   'valid_accuracy': 0.016329216,
#   'valid_loss': 0.016329216},
#  {'epoch': 233,
#   'train_loss': 0.017444916,
#   'valid_accuracy': 0.016352898,
#   'valid_loss': 0.016352898},
#  {'epoch': 234,
#   'train_loss': 0.017441833,
#   'valid_accuracy': 0.016300749,
#   'valid_loss': 0.016300749},
#  {'epoch': 235,
#   'train_loss': 0.017369132,
#   'valid_accuracy': 0.016238786,
#   'valid_loss': 0.016238786},
#  {'epoch': 236,
#   'train_loss': 0.017310364,
#   'valid_accuracy': 0.016162986,
#   'valid_loss': 0.016162986},
#  {'epoch': 237,
#   'train_loss': 0.017281177,
#   'valid_accuracy': 0.016185649,
#   'valid_loss': 0.016185649},
#  {'epoch': 238,
#   'train_loss': 0.017226567,
#   'valid_accuracy': 0.016031373,
#   'valid_loss': 0.016031373},
#  {'epoch': 239,
#   'train_loss': 0.017162826,
#   'valid_accuracy': 0.01603391,
#   'valid_loss': 0.01603391},
#  {'epoch': 240,
#   'train_loss': 0.017127503,
#   'valid_accuracy': 0.01593804,
#   'valid_loss': 0.01593804},
#  {'epoch': 241,
#   'train_loss': 0.017096382,
#   'valid_accuracy': 0.015919672,
#   'valid_loss': 0.015919672},
#  {'epoch': 242,
#   'train_loss': 0.017112622,
#   'valid_accuracy': 0.015947914,
#   'valid_loss': 0.015947914},
#  {'epoch': 243,
#   'train_loss': 0.017065989,
#   'valid_accuracy': 0.015807131,
#   'valid_loss': 0.015807131},
#  {'epoch': 244,
#   'train_loss': 0.01697804,
#   'valid_accuracy': 0.015722677,
#   'valid_loss': 0.015722677},
#  {'epoch': 245,
#   'train_loss': 0.016956888,
#   'valid_accuracy': 0.015777169,
#   'valid_loss': 0.015777169},
#  {'epoch': 246,
#   'train_loss': 0.016916713,
#   'valid_accuracy': 0.015694069,
#   'valid_loss': 0.015694069},
#  {'epoch': 247,
#   'train_loss': 0.016824059,
#   'valid_accuracy': 0.015595863,
#   'valid_loss': 0.015595863},
#  {'epoch': 248,
#   'train_loss': 0.016834749,
#   'valid_accuracy': 0.015513371,
#   'valid_loss': 0.015513371},
#  {'epoch': 249,
#   'train_loss': 0.016756551,
#   'valid_accuracy': 0.015662618,
#   'valid_loss': 0.015662618},
#  {'epoch': 250,
#   'train_loss': 0.016703561,
#   'valid_accuracy': 0.015456297,
#   'valid_loss': 0.015456297},
#  {'epoch': 251,
#   'train_loss': 0.016689377,
#   'valid_accuracy': 0.015464776,
#   'valid_loss': 0.015464776},
#  {'epoch': 252,
#   'train_loss': 0.016614985,
#   'valid_accuracy': 0.015403064,
#   'valid_loss': 0.015403064},
#  {'epoch': 253,
#   'train_loss': 0.01666761,
#   'valid_accuracy': 0.015474172,
#   'valid_loss': 0.015474172},
#  {'epoch': 254,
#   'train_loss': 0.016669724,
#   'valid_accuracy': 0.015389704,
#   'valid_loss': 0.015389704},
#  {'epoch': 255,
#   'train_loss': 0.016517339,
#   'valid_accuracy': 0.015290349,
#   'valid_loss': 0.015290349},
#  {'epoch': 256,
#   'train_loss': 0.016527116,
#   'valid_accuracy': 0.015346498,
#   'valid_loss': 0.015346498},
#  {'epoch': 257,
#   'train_loss': 0.016456854,
#   'valid_accuracy': 0.015232803,
#   'valid_loss': 0.015232803},
#  {'epoch': 258,
#   'train_loss': 0.016404448,
#   'valid_accuracy': 0.015152149,
#   'valid_loss': 0.015152149},
#  {'epoch': 259,
#   'train_loss': 0.016408581,
#   'valid_accuracy': 0.015151698,
#   'valid_loss': 0.015151698},
#  {'epoch': 260,
#   'train_loss': 0.016387573,
#   'valid_accuracy': 0.01511774,
#   'valid_loss': 0.01511774},
#  {'epoch': 261,
#   'train_loss': 0.016363032,
#   'valid_accuracy': 0.015040641,
#   'valid_loss': 0.015040641},
#  {'epoch': 262,
#   'train_loss': 0.016290138,
#   'valid_accuracy': 0.014942133,
#   'valid_loss': 0.014942133},
#  {'epoch': 263,
#   'train_loss': 0.016294273,
#   'valid_accuracy': 0.014982936,
#   'valid_loss': 0.014982936},
#  {'epoch': 264,
#   'train_loss': 0.016237838,
#   'valid_accuracy': 0.0149123,
#   'valid_loss': 0.0149123},
#  {'epoch': 265,
#   'train_loss': 0.016119016,
#   'valid_accuracy': 0.014893119,
#   'valid_loss': 0.014893119},
#  {'epoch': 266,
#   'train_loss': 0.016184025,
#   'valid_accuracy': 0.014759907,
#   'valid_loss': 0.014759907},
#  {'epoch': 267,
#   'train_loss': 0.016124217,
#   'valid_accuracy': 0.014879365,
#   'valid_loss': 0.014879365},
#  {'epoch': 268,
#   'train_loss': 0.016085846,
#   'valid_accuracy': 0.014814289,
#   'valid_loss': 0.014814289},
#  {'epoch': 269,
#   'train_loss': 0.016008399,
#   'valid_accuracy': 0.014717305,
#   'valid_loss': 0.014717305},
#  {'epoch': 270,
#   'train_loss': 0.015986633,
#   'valid_accuracy': 0.014667416,
#   'valid_loss': 0.014667416},
#  {'epoch': 271,
#   'train_loss': 0.015998909,
#   'valid_accuracy': 0.014737012,
#   'valid_loss': 0.014737012},
#  {'epoch': 272,
#   'train_loss': 0.015975038,
#   'valid_accuracy': 0.014620983,
#   'valid_loss': 0.014620983},
#  {'epoch': 273,
#   'train_loss': 0.015883943,
#   'valid_accuracy': 0.014615838,
#   'valid_loss': 0.014615838},
#  {'epoch': 274,
#   'train_loss': 0.015885588,
#   'valid_accuracy': 0.014614346,
#   'valid_loss': 0.014614346},
#  {'epoch': 275,
#   'train_loss': 0.015879126,
#   'valid_accuracy': 0.014517717,
#   'valid_loss': 0.014517717},
#  {'epoch': 276,
#   'train_loss': 0.015831502,
#   'valid_accuracy': 0.014556687,
#   'valid_loss': 0.014556687},
#  {'epoch': 277,
#   'train_loss': 0.015811995,
#   'valid_accuracy': 0.014468031,
#   'valid_loss': 0.014468031},
#  {'epoch': 278,
#   'train_loss': 0.015804544,
#   'valid_accuracy': 0.014457629,
#   'valid_loss': 0.014457629},
#  {'epoch': 279,
#   'train_loss': 0.015771199,
#   'valid_accuracy': 0.014318362,
#   'valid_loss': 0.014318362},
#  {'epoch': 280,
#   'train_loss': 0.01563449,
#   'valid_accuracy': 0.014337869,
#   'valid_loss': 0.014337869},
#  {'epoch': 281,
#   'train_loss': 0.015637336,
#   'valid_accuracy': 0.014359269,
#   'valid_loss': 0.014359269},
#  {'epoch': 282,
#   'train_loss': 0.015643822,
#   'valid_accuracy': 0.014312353,
#   'valid_loss': 0.014312353},
#  {'epoch': 283,
#   'train_loss': 0.015650304,
#   'valid_accuracy': 0.014296875,
#   'valid_loss': 0.014296875},
#  {'epoch': 284,
#   'train_loss': 0.015599397,
#   'valid_accuracy': 0.014190231,
#   'valid_loss': 0.014190231},
#  {'epoch': 285,
#   'train_loss': 0.015523101,
#   'valid_accuracy': 0.014163313,
#   'valid_loss': 0.014163313},
#  {'epoch': 286,
#   'train_loss': 0.015539872,
#   'valid_accuracy': 0.014198794,
#   'valid_loss': 0.014198794},
#  {'epoch': 287,
#   'train_loss': 0.015516121,
#   'valid_accuracy': 0.014192609,
#   'valid_loss': 0.014192609},
#  {'epoch': 288,
#   'train_loss': 0.01544044,
#   'valid_accuracy': 0.01410892,
#   'valid_loss': 0.01410892},
#  {'epoch': 289,
#   'train_loss': 0.015415055,
#   'valid_accuracy': 0.014109882,
#   'valid_loss': 0.014109882},
#  {'epoch': 290,
#   'train_loss': 0.015410249,
#   'valid_accuracy': 0.014005472,
#   'valid_loss': 0.014005472},
#  {'epoch': 291,
#   'train_loss': 0.015373169,
#   'valid_accuracy': 0.014077401,
#   'valid_loss': 0.014077401},
#  {'epoch': 292,
#   'train_loss': 0.015333898,
#   'valid_accuracy': 0.013999636,
#   'valid_loss': 0.013999636},
#  {'epoch': 293,
#   'train_loss': 0.015350887,
#   'valid_accuracy': 0.013987608,
#   'valid_loss': 0.013987608},
#  {'epoch': 294,
#   'train_loss': 0.015266721,
#   'valid_accuracy': 0.013958697,
#   'valid_loss': 0.013958697},
#  {'epoch': 295,
#   'train_loss': 0.015187197,
#   'valid_accuracy': 0.013958039,
#   'valid_loss': 0.013958039},
#  {'epoch': 296,
#   'train_loss': 0.015273062,
#   'valid_accuracy': 0.013845215,
#   'valid_loss': 0.013845215},
#  {'epoch': 297,
#   'train_loss': 0.01514635,
#   'valid_accuracy': 0.013884189,
#   'valid_loss': 0.013884189},
#  {'epoch': 298,
#   'train_loss': 0.015124495,
#   'valid_accuracy': 0.01384118,
#   'valid_loss': 0.01384118},
#  {'epoch': 299,
#   'train_loss': 0.015155903,
#   'valid_accuracy': 0.013780844,
#   'valid_loss': 0.013780844},
#  {'epoch': 300,
#   'train_loss': 0.015127538,
#   'valid_accuracy': 0.013831281,
#   'valid_loss': 0.013831281},
#  {'epoch': 301,
#   'train_loss': 0.015126186,
#   'valid_accuracy': 0.013727277,
#   'valid_loss': 0.013727277},
#  {'epoch': 302,
#   'train_loss': 0.015069872,
#   'valid_accuracy': 0.01371114,
#   'valid_loss': 0.01371114},
#  {'epoch': 303,
#   'train_loss': 0.015030278,
#   'valid_accuracy': 0.013756506,
#   'valid_loss': 0.013756506},
#  {'epoch': 304,
#   'train_loss': 0.01502612,
#   'valid_accuracy': 0.013699252,
#   'valid_loss': 0.013699252},
#  {'epoch': 305,
#   'train_loss': 0.015064195,
#   'valid_accuracy': 0.013750741,
#   'valid_loss': 0.013750741},
#  {'epoch': 306,
#   'train_loss': 0.015000411,
#   'valid_accuracy': 0.013594327,
#   'valid_loss': 0.013594327},
#  {'epoch': 307,
#   'train_loss': 0.014946084,
#   'valid_accuracy': 0.013657058,
#   'valid_loss': 0.013657058},
#  {'epoch': 308,
#   'train_loss': 0.014918452,
#   'valid_accuracy': 0.013632269,
#   'valid_loss': 0.013632269},
#  {'epoch': 309,
#   'train_loss': 0.014877041,
#   'valid_accuracy': 0.013586321,
#   'valid_loss': 0.013586321},
#  {'epoch': 310,
#   'train_loss': 0.014863401,
#   'valid_accuracy': 0.013434259,
#   'valid_loss': 0.013434259},
#  {'epoch': 311,
#   'train_loss': 0.014840716,
#   'valid_accuracy': 0.013450236,
#   'valid_loss': 0.013450236},
#  {'epoch': 312,
#   'train_loss': 0.014857337,
#   'valid_accuracy': 0.013537106,
#   'valid_loss': 0.013537106},
#  {'epoch': 313,
#   'train_loss': 0.01483324,
#   'valid_accuracy': 0.013415948,
#   'valid_loss': 0.013415948},
#  {'epoch': 314,
#   'train_loss': 0.01480387,
#   'valid_accuracy': 0.013348715,
#   'valid_loss': 0.013348715},
#  {'epoch': 315,
#   'train_loss': 0.014778253,
#   'valid_accuracy': 0.013417282,
#   'valid_loss': 0.013417282},
#  {'epoch': 316,
#   'train_loss': 0.014758398,
#   'valid_accuracy': 0.013521099,
#   'valid_loss': 0.013521099},
#  {'epoch': 317,
#   'train_loss': 0.014706864,
#   'valid_accuracy': 0.013296678,
#   'valid_loss': 0.013296678},
#  {'epoch': 318,
#   'train_loss': 0.014667511,
#   'valid_accuracy': 0.013302348,
#   'valid_loss': 0.013302348},
#  {'epoch': 319,
#   'train_loss': 0.014714777,
#   'valid_accuracy': 0.013344696,
#   'valid_loss': 0.013344696},
#  {'epoch': 320,
#   'train_loss': 0.014690893,
#   'valid_accuracy': 0.013263679,
#   'valid_loss': 0.013263679},
#  {'epoch': 321,
#   'train_loss': 0.014583859,
#   'valid_accuracy': 0.013234672,
#   'valid_loss': 0.013234672},
#  {'epoch': 322,
#   'train_loss': 0.014609206,
#   'valid_accuracy': 0.013271685,
#   'valid_loss': 0.013271685},
#  {'epoch': 323,
#   'train_loss': 0.014536365,
#   'valid_accuracy': 0.013171231,
#   'valid_loss': 0.013171231},
#  {'epoch': 324,
#   'train_loss': 0.014536685,
#   'valid_accuracy': 0.013230996,
#   'valid_loss': 0.013230996},
#  {'epoch': 325,
#   'train_loss': 0.014520501,
#   'valid_accuracy': 0.013221965,
#   'valid_loss': 0.013221965},
#  {'epoch': 326,
#   'train_loss': 0.014512874,
#   'valid_accuracy': 0.01315495,
#   'valid_loss': 0.01315495},
#  {'epoch': 327,
#   'train_loss': 0.014483695,
#   'valid_accuracy': 0.013120075,
#   'valid_loss': 0.013120075},
#  {'epoch': 328,
#   'train_loss': 0.014444662,
#   'valid_accuracy': 0.013170337,
#   'valid_loss': 0.013170337},
#  {'epoch': 329,
#   'train_loss': 0.014515468,
#   'valid_accuracy': 0.013133029,
#   'valid_loss': 0.013133029},
#  {'epoch': 330,
#   'train_loss': 0.014459501,
#   'valid_accuracy': 0.013109355,
#   'valid_loss': 0.013109355},
#  {'epoch': 331,
#   'train_loss': 0.014383296,
#   'valid_accuracy': 0.01304671,
#   'valid_loss': 0.01304671},
#  {'epoch': 332,
#   'train_loss': 0.014427471,
#   'valid_accuracy': 0.01304208,
#   'valid_loss': 0.01304208},
#  {'epoch': 333,
#   'train_loss': 0.014305554,
#   'valid_accuracy': 0.013033917,
#   'valid_loss': 0.013033917},
#  {'epoch': 334,
#   'train_loss': 0.014354873,
#   'valid_accuracy': 0.012974987,
#   'valid_loss': 0.012974987},
#  {'epoch': 335,
#   'train_loss': 0.014341147,
#   'valid_accuracy': 0.012997923,
#   'valid_loss': 0.012997923},
#  {'epoch': 336,
#   'train_loss': 0.014304484,
#   'valid_accuracy': 0.012914596,
#   'valid_loss': 0.012914596},
#  {'epoch': 337,
#   'train_loss': 0.014266701,
#   'valid_accuracy': 0.013033791,
#   'valid_loss': 0.013033791},
#  {'epoch': 338,
#   'train_loss': 0.014308766,
#   'valid_accuracy': 0.012945628,
#   'valid_loss': 0.012945628},
#  {'epoch': 339,
#   'train_loss': 0.014232017,
#   'valid_accuracy': 0.012864361,
#   'valid_loss': 0.012864361},
#  {'epoch': 340,
#   'train_loss': 0.014254983,
#   'valid_accuracy': 0.012910213,
#   'valid_loss': 0.012910213},
#  {'epoch': 341,
#   'train_loss': 0.014230157,
#   'valid_accuracy': 0.012884047,
#   'valid_loss': 0.012884047},
#  {'epoch': 342,
#   'train_loss': 0.014139133,
#   'valid_accuracy': 0.012839473,
#   'valid_loss': 0.012839473},
#  {'epoch': 343,
#   'train_loss': 0.01417647,
#   'valid_accuracy': 0.012931017,
#   'valid_loss': 0.012931017},
#  {'epoch': 344,
#   'train_loss': 0.014118268,
#   'valid_accuracy': 0.012892508,
#   'valid_loss': 0.012892508},
#  {'epoch': 345,
#   'train_loss': 0.01418177,
#   'valid_accuracy': 0.012864714,
#   'valid_loss': 0.012864714},
#  {'epoch': 346,
#   'train_loss': 0.014076934,
#   'valid_accuracy': 0.012856917,
#   'valid_loss': 0.012856917},
#  {'epoch': 347,
#   'train_loss': 0.014099381,
#   'valid_accuracy': 0.012767054,
#   'valid_loss': 0.012767054},
#  {'epoch': 348,
#   'train_loss': 0.014079493,
#   'valid_accuracy': 0.012729659,
#   'valid_loss': 0.012729659},
#  {'epoch': 349,
#   'train_loss': 0.014021073,
#   'valid_accuracy': 0.012741981,
#   'valid_loss': 0.012741981},
#  {'epoch': 350,
#   'train_loss': 0.013982353,
#   'valid_accuracy': 0.012679631,
#   'valid_loss': 0.012679631},
#  {'epoch': 351,
#   'train_loss': 0.014053897,
#   'valid_accuracy': 0.012729713,
#   'valid_loss': 0.012729713},
#  {'epoch': 352,
#   'train_loss': 0.014008692,
#   'valid_accuracy': 0.012612143,
#   'valid_loss': 0.012612143},
#  {'epoch': 353,
#   'train_loss': 0.01393426,
#   'valid_accuracy': 0.012645512,
#   'valid_loss': 0.012645512},
#  {'epoch': 354,
#   'train_loss': 0.013956195,
#   'valid_accuracy': 0.012655994,
#   'valid_loss': 0.012655994},
#  {'epoch': 355,
#   'train_loss': 0.01390765,
#   'valid_accuracy': 0.012571859,
#   'valid_loss': 0.012571859},
#  {'epoch': 356,
#   'train_loss': 0.013951734,
#   'valid_accuracy': 0.012593201,
#   'valid_loss': 0.012593201},
#  {'epoch': 357,
#   'train_loss': 0.013946502,
#   'valid_accuracy': 0.012551301,
#   'valid_loss': 0.012551301},
#  {'epoch': 358,
#   'train_loss': 0.013932287,
#   'valid_accuracy': 0.012548982,
#   'valid_loss': 0.012548982},
#  {'epoch': 359,
#   'train_loss': 0.013867772,
#   'valid_accuracy': 0.012570521,
#   'valid_loss': 0.012570521},
#  {'epoch': 360,
#   'train_loss': 0.013804223,
#   'valid_accuracy': 0.012530051,
#   'valid_loss': 0.012530051},
#  {'epoch': 361,
#   'train_loss': 0.013837609,
#   'valid_accuracy': 0.012491292,
#   'valid_loss': 0.012491292},
#  {'epoch': 362,
#   'train_loss': 0.013831389,
#   'valid_accuracy': 0.012487079,
#   'valid_loss': 0.012487079},
#  {'epoch': 363,
#   'train_loss': 0.013790795,
#   'valid_accuracy': 0.012477289,
#   'valid_loss': 0.012477289},
#  {'epoch': 364,
#   'train_loss': 0.01377845,
#   'valid_accuracy': 0.012485137,
#   'valid_loss': 0.012485137},
#  {'epoch': 365,
#   'train_loss': 0.013727601,
#   'valid_accuracy': 0.012480457,
#   'valid_loss': 0.012480457},
#  {'epoch': 366,
#   'train_loss': 0.01383056,
#   'valid_accuracy': 0.012479647,
#   'valid_loss': 0.012479647},
#  {'epoch': 367,
#   'train_loss': 0.01380377,
#   'valid_accuracy': 0.012441352,
#   'valid_loss': 0.012441352},
#  {'epoch': 368,
#   'train_loss': 0.013652658,
#   'valid_accuracy': 0.012326209,
#   'valid_loss': 0.012326209},
#  {'epoch': 369,
#   'train_loss': 0.013725436,
#   'valid_accuracy': 0.012441903,
#   'valid_loss': 0.012441903},
#  {'epoch': 370,
#   'train_loss': 0.01367036,
#   'valid_accuracy': 0.01231152,
#   'valid_loss': 0.01231152},
#  {'epoch': 371,
#   'train_loss': 0.013717592,
#   'valid_accuracy': 0.012333771,
#   'valid_loss': 0.012333771},
#  {'epoch': 372,
#   'train_loss': 0.013674198,
#   'valid_accuracy': 0.012370032,
#   'valid_loss': 0.012370032},
#  {'epoch': 373,
#   'train_loss': 0.013649917,
#   'valid_accuracy': 0.012365852,
#   'valid_loss': 0.012365852},
#  {'epoch': 374,
#   'train_loss': 0.013625796,
#   'valid_accuracy': 0.012333354,
#   'valid_loss': 0.012333354},
#  {'epoch': 375,
#   'train_loss': 0.013622358,
#   'valid_accuracy': 0.012278408,
#   'valid_loss': 0.012278408},
#  {'epoch': 376,
#   'train_loss': 0.013594647,
#   'valid_accuracy': 0.012329388,
#   'valid_loss': 0.012329388},
#  {'epoch': 377,
#   'train_loss': 0.01357435,
#   'valid_accuracy': 0.012314888,
#   'valid_loss': 0.012314888},
#  {'epoch': 378,
#   'train_loss': 0.013536765,
#   'valid_accuracy': 0.012224999,
#   'valid_loss': 0.012224999},
#  {'epoch': 379,
#   'train_loss': 0.013524457,
#   'valid_accuracy': 0.012180635,
#   'valid_loss': 0.012180635},
#  {'epoch': 380,
#   'train_loss': 0.01351694,
#   'valid_accuracy': 0.012253193,
#   'valid_loss': 0.012253193},
#  {'epoch': 381,
#   'train_loss': 0.01348771,
#   'valid_accuracy': 0.012226799,
#   'valid_loss': 0.012226799},
#  {'epoch': 382,
#   'train_loss': 0.0135093,
#   'valid_accuracy': 0.012170298,
#   'valid_loss': 0.012170298},
#  {'epoch': 383,
#   'train_loss': 0.013468497,
#   'valid_accuracy': 0.012191067,
#   'valid_loss': 0.012191067},
#  {'epoch': 384,
#   'train_loss': 0.01343742,
#   'valid_accuracy': 0.012125636,
#   'valid_loss': 0.012125636},
#  {'epoch': 385,
#   'train_loss': 0.013428025,
#   'valid_accuracy': 0.012137417,
#   'valid_loss': 0.012137417},
#  {'epoch': 386,
#   'train_loss': 0.013427322,
#   'valid_accuracy': 0.012144827,
#   'valid_loss': 0.012144827},
#  {'epoch': 387,
#   'train_loss': 0.013423589,
#   'valid_accuracy': 0.012071546,
#   'valid_loss': 0.012071546},
#  {'epoch': 388,
#   'train_loss': 0.013407558,
#   'valid_accuracy': 0.012049824,
#   'valid_loss': 0.012049824},
#  {'epoch': 389,
#   'train_loss': 0.013432451,
#   'valid_accuracy': 0.012055531,
#   'valid_loss': 0.012055531},
#  {'epoch': 390,
#   'train_loss': 0.013347206,
#   'valid_accuracy': 0.012050563,
#   'valid_loss': 0.012050563},
#  {'epoch': 391,
#   'train_loss': 0.01340093,
#   'valid_accuracy': 0.012175941,
#   'valid_loss': 0.012175941},
#  {'epoch': 392,
#   'train_loss': 0.013280182,
#   'valid_accuracy': 0.012048628,
#   'valid_loss': 0.012048628},
#  {'epoch': 393,
#   'train_loss': 0.013290006,
#   'valid_accuracy': 0.012080711,
#   'valid_loss': 0.012080711},
#  {'epoch': 394,
#   'train_loss': 0.013288549,
#   'valid_accuracy': 0.012026547,
#   'valid_loss': 0.012026547},
#  {'epoch': 395,
#   'train_loss': 0.013300242,
#   'valid_accuracy': 0.01195046,
#   'valid_loss': 0.01195046},
#  {'epoch': 396,
#   'train_loss': 0.013260103,
#   'valid_accuracy': 0.011941712,
#   'valid_loss': 0.011941712},
#  {'epoch': 397,
#   'train_loss': 0.013265303,
#   'valid_accuracy': 0.01200174,
#   'valid_loss': 0.01200174},
#  {'epoch': 398,
#   'train_loss': 0.013220901,
#   'valid_accuracy': 0.011906515,
#   'valid_loss': 0.011906515},
#  {'epoch': 399,
#   'train_loss': 0.013221004,
#   'valid_accuracy': 0.011930433,
#   'valid_loss': 0.011930433},
#  {'epoch': 400,
#   'train_loss': 0.013258323,
#   'valid_accuracy': 0.011964838,
#   'valid_loss': 0.011964838},
#  {'epoch': 401,
#   'train_loss': 0.013217825,
#   'valid_accuracy': 0.011942937,
#   'valid_loss': 0.011942937},
#  {'epoch': 402,
#   'train_loss': 0.013174775,
#   'valid_accuracy': 0.011888273,
#   'valid_loss': 0.011888273},
#  {'epoch': 403,
#   'train_loss': 0.013217157,
#   'valid_accuracy': 0.011878569,
#   'valid_loss': 0.011878569},
#  {'epoch': 404,
#   'train_loss': 0.013164646,
#   'valid_accuracy': 0.011881451,
#   'valid_loss': 0.011881451},
#  {'epoch': 405,
#   'train_loss': 0.013120061,
#   'valid_accuracy': 0.011888617,
#   'valid_loss': 0.011888617},
#  {'epoch': 406,
#   'train_loss': 0.013126644,
#   'valid_accuracy': 0.011834581,
#   'valid_loss': 0.011834581},
#  {'epoch': 407,
#   'train_loss': 0.013096489,
#   'valid_accuracy': 0.011809262,
#   'valid_loss': 0.011809262},
#  {'epoch': 408,
#   'train_loss': 0.013085354,
#   'valid_accuracy': 0.011838534,
#   'valid_loss': 0.011838534},
#  {'epoch': 409,
#   'train_loss': 0.013069,
#   'valid_accuracy': 0.011861076,
#   'valid_loss': 0.011861076},
#  {'epoch': 410,
#   'train_loss': 0.013055075,
#   'valid_accuracy': 0.011854958,
#   'valid_loss': 0.011854958},
#  {'epoch': 411,
#   'train_loss': 0.013040561,
#   'valid_accuracy': 0.011912467,
#   'valid_loss': 0.011912467},
#  {'epoch': 412,
#   'train_loss': 0.013012841,
#   'valid_accuracy': 0.011713426,
#   'valid_loss': 0.011713426},
#  {'epoch': 413,
#   'train_loss': 0.013028706,
#   'valid_accuracy': 0.011745582,
#   'valid_loss': 0.011745582},
#  {'epoch': 414,
#   'train_loss': 0.013000866,
#   'valid_accuracy': 0.011746152,
#   'valid_loss': 0.011746152},
#  {'epoch': 415,
#   'train_loss': 0.013063506,
#   'valid_accuracy': 0.011734284,
#   'valid_loss': 0.011734284},
#  {'epoch': 416,
#   'train_loss': 0.012950771,
#   'valid_accuracy': 0.011864097,
#   'valid_loss': 0.011864097},
#  {'epoch': 417,
#   'train_loss': 0.01298367,
#   'valid_accuracy': 0.011748797,
#   'valid_loss': 0.011748797},
#  {'epoch': 418,
#   'train_loss': 0.012962591,
#   'valid_accuracy': 0.011725673,
#   'valid_loss': 0.011725673},
#  {'epoch': 419,
#   'train_loss': 0.012927629,
#   'valid_accuracy': 0.011702772,
#   'valid_loss': 0.011702772},
#  {'epoch': 420,
#   'train_loss': 0.012869514,
#   'valid_accuracy': 0.011622411,
#   'valid_loss': 0.011622411},
#  {'epoch': 421,
#   'train_loss': 0.0128688,
#   'valid_accuracy': 0.011618533,
#   'valid_loss': 0.011618533},
#  {'epoch': 422,
#   'train_loss': 0.012919853,
#   'valid_accuracy': 0.011658636,
#   'valid_loss': 0.011658636},
#  {'epoch': 423,
#   'train_loss': 0.012911581,
#   'valid_accuracy': 0.011595481,
#   'valid_loss': 0.011595481},
#  {'epoch': 424,
#   'train_loss': 0.012891394,
#   'valid_accuracy': 0.011637642,
#   'valid_loss': 0.011637642},
#  {'epoch': 425,
#   'train_loss': 0.012805032,
#   'valid_accuracy': 0.011610356,
#   'valid_loss': 0.011610356},
#  {'epoch': 426,
#   'train_loss': 0.012828904,
#   'valid_accuracy': 0.0115667,
#   'valid_loss': 0.0115667},
#  {'epoch': 427,
#   'train_loss': 0.012856588,
#   'valid_accuracy': 0.011604879,
#   'valid_loss': 0.011604879},
#  {'epoch': 428,
#   'train_loss': 0.012840153,
#   'valid_accuracy': 0.011611702,
#   'valid_loss': 0.011611702},
#  {'epoch': 429,
#   'train_loss': 0.012841356,
#   'valid_accuracy': 0.011615852,
#   'valid_loss': 0.011615852},
#  {'epoch': 430,
#   'train_loss': 0.01279586,
#   'valid_accuracy': 0.011528603,
#   'valid_loss': 0.011528603},
#  {'epoch': 431,
#   'train_loss': 0.012775252,
#   'valid_accuracy': 0.011473984,
#   'valid_loss': 0.011473984},
#  {'epoch': 432,
#   'train_loss': 0.012778567,
#   'valid_accuracy': 0.011568684,
#   'valid_loss': 0.011568684},
#  {'epoch': 433,
#   'train_loss': 0.012758679,
#   'valid_accuracy': 0.011461383,
#   'valid_loss': 0.011461383},
#  {'epoch': 434,
#   'train_loss': 0.012746181,
#   'valid_accuracy': 0.011486382,
#   'valid_loss': 0.011486382},
#  {'epoch': 435,
#   'train_loss': 0.012772269,
#   'valid_accuracy': 0.01157357,
#   'valid_loss': 0.01157357},
#  {'epoch': 436,
#   'train_loss': 0.012710057,
#   'valid_accuracy': 0.011418045,
#   'valid_loss': 0.011418045},
#  {'epoch': 437,
#   'train_loss': 0.012730763,
#   'valid_accuracy': 0.011454187,
#   'valid_loss': 0.011454187},
#  {'epoch': 438,
#   'train_loss': 0.012697349,
#   'valid_accuracy': 0.011381343,
#   'valid_loss': 0.011381343},
#  {'epoch': 439,
#   'train_loss': 0.012696084,
#   'valid_accuracy': 0.011490609,
#   'valid_loss': 0.011490609},
#  {'epoch': 440,
#   'train_loss': 0.012633701,
#   'valid_accuracy': 0.011386346,
#   'valid_loss': 0.011386346},
#  {'epoch': 441,
#   'train_loss': 0.012633556,
#   'valid_accuracy': 0.011470148,
#   'valid_loss': 0.011470148},
#  {'epoch': 442,
#   'train_loss': 0.012640118,
#   'valid_accuracy': 0.011346377,
#   'valid_loss': 0.011346377},
#  {'epoch': 443,
#   'train_loss': 0.012551269,
#   'valid_accuracy': 0.011400671,
#   'valid_loss': 0.011400671},
#  {'epoch': 444,
#   'train_loss': 0.012627172,
#   'valid_accuracy': 0.011394032,
#   'valid_loss': 0.011394032},
#  {'epoch': 445,
#   'train_loss': 0.012606627,
#   'valid_accuracy': 0.01142815,
#   'valid_loss': 0.01142815},
#  {'epoch': 446,
#   'train_loss': 0.012572817,
#   'valid_accuracy': 0.011375527,
#   'valid_loss': 0.011375527},
#  {'epoch': 447,
#   'train_loss': 0.012571427,
#   'valid_accuracy': 0.011388291,
# ...
#  {'epoch': 3326,
#   'train_loss': 0.0032474811,
#   'valid_accuracy': 0.0063467217,
#   'valid_loss': 0.0063467217},
#  {'epoch': 3327,
#   'train_loss': 0.0032575484,
#   'valid_accuracy': 0.0063764104,
#   'valid_loss': 0.0063764104},
#  {'epoch': 3328,
#   'train_loss': 0.0032339243,
#   'valid_accuracy': 0.0063706189,
#   'valid_loss': 0.0063706189},
#  {'epoch': 3329,
#   'train_loss': 0.0031952355,
#   'valid_accuracy': 0.0063500865,
#   'valid_loss': 0.0063500865},
#  {'epoch': 3330,
#   'train_loss': 0.0032414494,
#   'valid_accuracy': 0.0063781692,
#   'valid_loss': 0.0063781692},
#  {'epoch': 3331,
#   'train_loss': 0.0032286241,
#   'valid_accuracy': 0.0063378322,
#   'valid_loss': 0.0063378322},
#  {'epoch': 3332,
#   'train_loss': 0.0032343264,
#   'valid_accuracy': 0.0063937209,
#   'valid_loss': 0.0063937209},
#  {'epoch': 3333,
#   'train_loss': 0.0032384414,
#   'valid_accuracy': 0.0063965167,
#   'valid_loss': 0.0063965167},
#  {'epoch': 3334,
#   'train_loss': 0.003209528,
#   'valid_accuracy': 0.0063791508,
#   'valid_loss': 0.0063791508},
#  {'epoch': 3335,
#   'train_loss': 0.0031844252,
#   'valid_accuracy': 0.006406669,
#   'valid_loss': 0.006406669},
#  {'epoch': 3336,
#   'train_loss': 0.0032048516,
#   'valid_accuracy': 0.0063803471,
#   'valid_loss': 0.0063803471},
#  {'epoch': 3337,
#   'train_loss': 0.0032592174,
#   'valid_accuracy': 0.0063419999,
#   'valid_loss': 0.0063419999},
#  {'epoch': 3338,
#   'train_loss': 0.0031937289,
#   'valid_accuracy': 0.006391454,
#   'valid_loss': 0.006391454},
#  {'epoch': 3339,
#   'train_loss': 0.0032277764,
#   'valid_accuracy': 0.0063852551,
#   'valid_loss': 0.0063852551},
#  {'epoch': 3340,
#   'train_loss': 0.0032140762,
#   'valid_accuracy': 0.0063982853,
#   'valid_loss': 0.0063982853},
#  {'epoch': 3341,
#   'train_loss': 0.0031906695,
#   'valid_accuracy': 0.0063774888,
#   'valid_loss': 0.0063774888},
#  {'epoch': 3342,
#   'train_loss': 0.0032634623,
#   'valid_accuracy': 0.0063419123,
#   'valid_loss': 0.0063419123},
#  {'epoch': 3343,
#   'train_loss': 0.0032214904,
#   'valid_accuracy': 0.0064367773,
#   'valid_loss': 0.0064367773},
#  {'epoch': 3344,
#   'train_loss': 0.0032088612,
#   'valid_accuracy': 0.0063844472,
#   'valid_loss': 0.0063844472},
#  {'epoch': 3345,
#   'train_loss': 0.0032123476,
#   'valid_accuracy': 0.0064067077,
#   'valid_loss': 0.0064067077},
#  {'epoch': 3346,
#   'train_loss': 0.0031529407,
#   'valid_accuracy': 0.0064034062,
#   'valid_loss': 0.0064034062},
#  {'epoch': 3347,
#   'train_loss': 0.0032337161,
#   'valid_accuracy': 0.0063699395,
#   'valid_loss': 0.0063699395},
#  {'epoch': 3348,
#   'train_loss': 0.0032198336,
#   'valid_accuracy': 0.0063884929,
#   'valid_loss': 0.0063884929},
#  {'epoch': 3349,
#   'train_loss': 0.0032225756,
#   'valid_accuracy': 0.0064067179,
#   'valid_loss': 0.0064067179},
#  {'epoch': 3350,
#   'train_loss': 0.0032093017,
#   'valid_accuracy': 0.0063666324,
#   'valid_loss': 0.0063666324},
#  {'epoch': 3351,
#   'train_loss': 0.003219154,
#   'valid_accuracy': 0.0063897786,
#   'valid_loss': 0.0063897786},
#  {'epoch': 3352,
#   'train_loss': 0.0031930772,
#   'valid_accuracy': 0.006398079,
#   'valid_loss': 0.006398079},
#  {'epoch': 3353,
#   'train_loss': 0.0031434812,
#   'valid_accuracy': 0.0063820947,
#   'valid_loss': 0.0063820947},
#  {'epoch': 3354,
#   'train_loss': 0.003161632,
#   'valid_accuracy': 0.006371425,
#   'valid_loss': 0.006371425},
#  {'epoch': 3355,
#   'train_loss': 0.0032071427,
#   'valid_accuracy': 0.0063916263,
#   'valid_loss': 0.0063916263},
#  {'epoch': 3356,
#   'train_loss': 0.0032446831,
#   'valid_accuracy': 0.0063702296,
#   'valid_loss': 0.0063702296},
#  {'epoch': 3357,
#   'train_loss': 0.0032855745,
#   'valid_accuracy': 0.0063705286,
#   'valid_loss': 0.0063705286},
#  {'epoch': 3358,
#   'train_loss': 0.0031819164,
#   'valid_accuracy': 0.0063430117,
#   'valid_loss': 0.0063430117},
#  {'epoch': 3359,
#   'train_loss': 0.0032436694,
#   'valid_accuracy': 0.0063889944,
#   'valid_loss': 0.0063889944},
#  {'epoch': 3360,
#   'train_loss': 0.0031910965,
#   'valid_accuracy': 0.0063705826,
#   'valid_loss': 0.0063705826},
#  {'epoch': 3361,
#   'train_loss': 0.0032008758,
#   'valid_accuracy': 0.0063618063,
#   'valid_loss': 0.0063618063},
#  {'epoch': 3362,
#   'train_loss': 0.0031705792,
#   'valid_accuracy': 0.0063643488,
#   'valid_loss': 0.0063643488},
#  {'epoch': 3363,
#   'train_loss': 0.00324834,
#   'valid_accuracy': 0.0064079901,
#   'valid_loss': 0.0064079901},
#  {'epoch': 3364,
#   'train_loss': 0.003143772,
#   'valid_accuracy': 0.006377263,
#   'valid_loss': 0.006377263},
#  {'epoch': 3365,
#   'train_loss': 0.0032150829,
#   'valid_accuracy': 0.0063388902,
#   'valid_loss': 0.0063388902},
#  {'epoch': 3366,
#   'train_loss': 0.003172447,
#   'valid_accuracy': 0.0063641202,
#   'valid_loss': 0.0063641202},
#  {'epoch': 3367,
#   'train_loss': 0.0032541156,
#   'valid_accuracy': 0.0064251223,
#   'valid_loss': 0.0064251223},
#  {'epoch': 3368,
#   'train_loss': 0.0031796948,
#   'valid_accuracy': 0.0064166952,
#   'valid_loss': 0.0064166952},
#  {'epoch': 3369,
#   'train_loss': 0.0031769308,
#   'valid_accuracy': 0.0063936813,
#   'valid_loss': 0.0063936813},
#  {'epoch': 3370,
#   'train_loss': 0.0031775325,
#   'valid_accuracy': 0.006393821,
#   'valid_loss': 0.006393821},
#  {'epoch': 3371,
#   'train_loss': 0.0031404707,
#   'valid_accuracy': 0.0063596172,
#   'valid_loss': 0.0063596172},
#  {'epoch': 3372,
#   'train_loss': 0.0031915328,
#   'valid_accuracy': 0.0063600307,
#   'valid_loss': 0.0063600307},
#  {'epoch': 3373,
#   'train_loss': 0.0031983159,
#   'valid_accuracy': 0.0063581392,
#   'valid_loss': 0.0063581392},
#  {'epoch': 3374,
#   'train_loss': 0.0031574089,
#   'valid_accuracy': 0.0063872486,
#   'valid_loss': 0.0063872486},
#  {'epoch': 3375,
#   'train_loss': 0.003166286,
#   'valid_accuracy': 0.0063868193,
#   'valid_loss': 0.0063868193},
#  {'epoch': 3376,
#   'train_loss': 0.0031921358,
#   'valid_accuracy': 0.0063676657,
#   'valid_loss': 0.0063676657},
#  {'epoch': 3377,
#   'train_loss': 0.0031400649,
#   'valid_accuracy': 0.0063755587,
#   'valid_loss': 0.0063755587},
#  {'epoch': 3378,
#   'train_loss': 0.0032376347,
#   'valid_accuracy': 0.0063811862,
#   'valid_loss': 0.0063811862},
#  {'epoch': 3379,
#   'train_loss': 0.00315079,
#   'valid_accuracy': 0.0064108074,
#   'valid_loss': 0.0064108074},
#  {'epoch': 3380,
#   'train_loss': 0.0032508124,
#   'valid_accuracy': 0.0063844114,
#   'valid_loss': 0.0063844114},
#  {'epoch': 3381,
#   'train_loss': 0.0031642199,
#   'valid_accuracy': 0.0063860007,
#   'valid_loss': 0.0063860007},
#  {'epoch': 3382,
#   'train_loss': 0.0031325803,
#   'valid_accuracy': 0.0063730967,
#   'valid_loss': 0.0063730967},
#  {'epoch': 3383,
#   'train_loss': 0.0031405832,
#   'valid_accuracy': 0.0064161518,
#   'valid_loss': 0.0064161518},
#  {'epoch': 3384,
#   'train_loss': 0.0031751094,
#   'valid_accuracy': 0.0063933837,
#   'valid_loss': 0.0063933837},
#  {'epoch': 3385,
#   'train_loss': 0.0031575696,
#   'valid_accuracy': 0.0064036553,
#   'valid_loss': 0.0064036553},
#  {'epoch': 3386,
#   'train_loss': 0.0031113625,
#   'valid_accuracy': 0.0063947476,
#   'valid_loss': 0.0063947476},
#  {'epoch': 3387,
#   'train_loss': 0.0032584574,
#   'valid_accuracy': 0.0063991114,
#   'valid_loss': 0.0063991114},
#  {'epoch': 3388,
#   'train_loss': 0.0032189477,
#   'valid_accuracy': 0.0064002918,
#   'valid_loss': 0.0064002918},
#  {'epoch': 3389,
#   'train_loss': 0.0031816533,
#   'valid_accuracy': 0.0063865585,
#   'valid_loss': 0.0063865585},
#  {'epoch': 3390,
#   'train_loss': 0.0031601461,
#   'valid_accuracy': 0.0063545885,
#   'valid_loss': 0.0063545885},
#  {'epoch': 3391,
#   'train_loss': 0.0032017541,
#   'valid_accuracy': 0.0063939677,
#   'valid_loss': 0.0063939677},
#  {'epoch': 3392,
#   'train_loss': 0.0031654658,
#   'valid_accuracy': 0.0063796248,
#   'valid_loss': 0.0063796248},
#  {'epoch': 3393,
#   'train_loss': 0.0031808354,
#   'valid_accuracy': 0.0064264224,
#   'valid_loss': 0.0064264224},
#  {'epoch': 3394,
#   'train_loss': 0.0031623989,
#   'valid_accuracy': 0.0063567776,
#   'valid_loss': 0.0063567776},
#  {'epoch': 3395,
#   'train_loss': 0.0031196065,
#   'valid_accuracy': 0.0063333283,
#   'valid_loss': 0.0063333283},
#  {'epoch': 3396,
#   'train_loss': 0.0031662832,
#   'valid_accuracy': 0.006362753,
#   'valid_loss': 0.006362753},
#  {'epoch': 3397,
#   'train_loss': 0.0031747892,
#   'valid_accuracy': 0.0063484269,
#   'valid_loss': 0.0063484269},
#  {'epoch': 3398,
#   'train_loss': 0.0031502927,
#   'valid_accuracy': 0.0063499208,
#   'valid_loss': 0.0063499208},
#  {'epoch': 3399,
#   'train_loss': 0.0032687152,
#   'valid_accuracy': 0.0063388501,
#   'valid_loss': 0.0063388501},
#  {'epoch': 3400,
#   'train_loss': 0.0031890743,
#   'valid_accuracy': 0.0063853511,
#   'valid_loss': 0.0063853511},
#  {'epoch': 3401,
#   'train_loss': 0.003149135,
#   'valid_accuracy': 0.0063584833,
#   'valid_loss': 0.0063584833},
#  {'epoch': 3402,
#   'train_loss': 0.0032231871,
#   'valid_accuracy': 0.0063972389,
#   'valid_loss': 0.0063972389},
#  {'epoch': 3403,
#   'train_loss': 0.0031717725,
#   'valid_accuracy': 0.0063675321,
#   'valid_loss': 0.0063675321},
#  {'epoch': 3404,
#   'train_loss': 0.0031768843,
#   'valid_accuracy': 0.0063744257,
#   'valid_loss': 0.0063744257},
#  {'epoch': 3405,
#   'train_loss': 0.0031894939,
#   'valid_accuracy': 0.0063404064,
#   'valid_loss': 0.0063404064},
#  {'epoch': 3406,
#   'train_loss': 0.0030705945,
#   'valid_accuracy': 0.0063502779,
#   'valid_loss': 0.0063502779},
#  {'epoch': 3407,
#   'train_loss': 0.0032006775,
#   'valid_accuracy': 0.0063746539,
#   'valid_loss': 0.0063746539},
#  {'epoch': 3408,
#   'train_loss': 0.0031553225,
#   'valid_accuracy': 0.006361099,
#   'valid_loss': 0.006361099},
#  {'epoch': 3409,
#   'train_loss': 0.0031640152,
#   'valid_accuracy': 0.0063765231,
#   'valid_loss': 0.0063765231},
#  {'epoch': 3410,
#   'train_loss': 0.0031502363,
#   'valid_accuracy': 0.0063751349,
#   'valid_loss': 0.0063751349},
#  {'epoch': 3411,
#   'train_loss': 0.0031719576,
#   'valid_accuracy': 0.0063464264,
#   'valid_loss': 0.0063464264},
#  {'epoch': 3412,
#   'train_loss': 0.0031651421,
#   'valid_accuracy': 0.0063370517,
#   'valid_loss': 0.0063370517},
#  {'epoch': 3413,
#   'train_loss': 0.0031274748,
#   'valid_accuracy': 0.0063759205,
#   'valid_loss': 0.0063759205},
#  {'epoch': 3414,
#   'train_loss': 0.0032388591,
#   'valid_accuracy': 0.0063542402,
#   'valid_loss': 0.0063542402},
#  {'epoch': 3415,
#   'train_loss': 0.0031411764,
#   'valid_accuracy': 0.0063832756,
#   'valid_loss': 0.0063832756},
#  {'epoch': 3416,
#   'train_loss': 0.0030965884,
#   'valid_accuracy': 0.0063811941,
#   'valid_loss': 0.0063811941},
#  {'epoch': 3417,
#   'train_loss': 0.0031851823,
#   'valid_accuracy': 0.0063934312,
#   'valid_loss': 0.0063934312},
#  {'epoch': 3418,
#   'train_loss': 0.0031942485,
#   'valid_accuracy': 0.0063735866,
#   'valid_loss': 0.0063735866},
#  {'epoch': 3419,
#   'train_loss': 0.0031449434,
#   'valid_accuracy': 0.0063962727,
#   'valid_loss': 0.0063962727},
#  {'epoch': 3420,
#   'train_loss': 0.0032148496,
#   'valid_accuracy': 0.0063805114,
#   'valid_loss': 0.0063805114},
#  {'epoch': 3421,
#   'train_loss': 0.0031876534,
#   'valid_accuracy': 0.0063476148,
#   'valid_loss': 0.0063476148},
#  {'epoch': 3422,
#   'train_loss': 0.0031266522,
#   'valid_accuracy': 0.0063596102,
#   'valid_loss': 0.0063596102},
#  {'epoch': 3423,
#   'train_loss': 0.0031153867,
#   'valid_accuracy': 0.0063639842,
#   'valid_loss': 0.0063639842},
#  {'epoch': 3424,
#   'train_loss': 0.0031864154,
#   'valid_accuracy': 0.0063777268,
#   'valid_loss': 0.0063777268},
#  {'epoch': 3425,
#   'train_loss': 0.0031224014,
#   'valid_accuracy': 0.0063624349,
#   'valid_loss': 0.0063624349},
#  {'epoch': 3426,
#   'train_loss': 0.0031503346,
#   'valid_accuracy': 0.0063988701,
#   'valid_loss': 0.0063988701},
#  {'epoch': 3427,
#   'train_loss': 0.0032163467,
#   'valid_accuracy': 0.0064145685,
#   'valid_loss': 0.0064145685},
#  {'epoch': 3428,
#   'train_loss': 0.003076928,
#   'valid_accuracy': 0.0063199839,
#   'valid_loss': 0.0063199839},
#  {'epoch': 3429,
#   'train_loss': 0.0030978769,
#   'valid_accuracy': 0.0064190221,
#   'valid_loss': 0.0064190221},
#  {'epoch': 3430,
#   'train_loss': 0.0031721101,
#   'valid_accuracy': 0.0063903476,
#   'valid_loss': 0.0063903476},
#  {'epoch': 3431,
#   'train_loss': 0.0031257425,
#   'valid_accuracy': 0.0063544302,
#   'valid_loss': 0.0063544302},
#  {'epoch': 3432,
#   'train_loss': 0.0031481232,
#   'valid_accuracy': 0.0063769785,
#   'valid_loss': 0.0063769785},
#  {'epoch': 3433,
#   'train_loss': 0.0031608967,
#   'valid_accuracy': 0.006396316,
#   'valid_loss': 0.006396316},
#  {'epoch': 3434,
#   'train_loss': 0.003089004,
#   'valid_accuracy': 0.0063949535,
#   'valid_loss': 0.0063949535},
#  {'epoch': 3435,
#   'train_loss': 0.0031373044,
#   'valid_accuracy': 0.006365845,
#   'valid_loss': 0.006365845},
#  {'epoch': 3436,
#   'train_loss': 0.0031544322,
#   'valid_accuracy': 0.0064061061,
#   'valid_loss': 0.0064061061},
#  {'epoch': 3437,
#   'train_loss': 0.0031644683,
#   'valid_accuracy': 0.0063446951,
#   'valid_loss': 0.0063446951},
#  {'epoch': 3438,
#   'train_loss': 0.0031216263,
#   'valid_accuracy': 0.0063961199,
#   'valid_loss': 0.0063961199},
#  {'epoch': 3439,
#   'train_loss': 0.0031565125,
#   'valid_accuracy': 0.0063645658,
#   'valid_loss': 0.0063645658},
#  {'epoch': 3440,
#   'train_loss': 0.0031566978,
#   'valid_accuracy': 0.0063818684,
#   'valid_loss': 0.0063818684},
#  {'epoch': 3441,
#   'train_loss': 0.0031052358,
#   'valid_accuracy': 0.0063822074,
#   'valid_loss': 0.0063822074},
#  {'epoch': 3442,
#   'train_loss': 0.0031996416,
#   'valid_accuracy': 0.0063846768,
#   'valid_loss': 0.0063846768},
#  {'epoch': 3443,
#   'train_loss': 0.0031288241,
#   'valid_accuracy': 0.0063494206,
#   'valid_loss': 0.0063494206},
#  {'epoch': 3444,
#   'train_loss': 0.0031330159,
#   'valid_accuracy': 0.0063643148,
#   'valid_loss': 0.0063643148},
#  {'epoch': 3445,
#   'train_loss': 0.0031246806,
#   'valid_accuracy': 0.0063502779,
#   'valid_loss': 0.0063502779},
#  {'epoch': 3446,
#   'train_loss': 0.0030902699,
#   'valid_accuracy': 0.0063813296,
#   'valid_loss': 0.0063813296},
#  {'epoch': 3447,
#   'train_loss': 0.0031548697,
#   'valid_accuracy': 0.0063487934,
#   'valid_loss': 0.0063487934},
#  {'epoch': 3448,
#   'train_loss': 0.0031380174,
#   'valid_accuracy': 0.0063604442,
#   'valid_loss': 0.0063604442},
#  {'epoch': 3449,
#   'train_loss': 0.0031228983,
#   'valid_accuracy': 0.0063391477,
#   'valid_loss': 0.0063391477},
#  {'epoch': 3450,
#   'train_loss': 0.003132561,
#   'valid_accuracy': 0.0063725836,
#   'valid_loss': 0.0063725836},
#  {'epoch': 3451,
#   'train_loss': 0.003173535,
#   'valid_accuracy': 0.0063778744,
#   'valid_loss': 0.0063778744},
#  {'epoch': 3452,
#   'train_loss': 0.0031649442,
#   'valid_accuracy': 0.006357979,
#   'valid_loss': 0.006357979},
#  {'epoch': 3453,
#   'train_loss': 0.00318954,
#   'valid_accuracy': 0.0063409219,
#   'valid_loss': 0.0063409219},
#  {'epoch': 3454,
#   'train_loss': 0.0031392693,
#   'valid_accuracy': 0.0063639884,
#   'valid_loss': 0.0063639884},
#  {'epoch': 3455,
#   'train_loss': 0.0031569165,
#   'valid_accuracy': 0.0063705891,
#   'valid_loss': 0.0063705891},
#  {'epoch': 3456,
#   'train_loss': 0.0031004008,
#   'valid_accuracy': 0.0063569993,
#   'valid_loss': 0.0063569993},
#  {'epoch': 3457,
#   'train_loss': 0.003136121,
#   'valid_accuracy': 0.0063618561,
#   'valid_loss': 0.0063618561},
#  {'epoch': 3458,
#   'train_loss': 0.0030939493,
#   'valid_accuracy': 0.0063713649,
#   'valid_loss': 0.0063713649},
#  {'epoch': 3459,
#   'train_loss': 0.0031531295,
#   'valid_accuracy': 0.0063701528,
#   'valid_loss': 0.0063701528},
#  {'epoch': 3460,
#   'train_loss': 0.0032060295,
#   'valid_accuracy': 0.0063522807,
#   'valid_loss': 0.0063522807},
#  {'epoch': 3461,
#   'train_loss': 0.0030983333,
#   'valid_accuracy': 0.0063658934,
#   'valid_loss': 0.0063658934},
#  {'epoch': 3462,
#   'train_loss': 0.0031355633,
#   'valid_accuracy': 0.0063623097,
#   'valid_loss': 0.0063623097},
#  {'epoch': 3463,
#   'train_loss': 0.0031481721,
#   'valid_accuracy': 0.0063406271,
#   'valid_loss': 0.0063406271},
#  {'epoch': 3464,
#   'train_loss': 0.0031507695,
#   'valid_accuracy': 0.0063503664,
#   'valid_loss': 0.0063503664},
#  {'epoch': 3465,
#   'train_loss': 0.0030746758,
#   'valid_accuracy': 0.0063841357,
#   'valid_loss': 0.0063841357},
#  {'epoch': 3466,
#   'train_loss': 0.0031888729,
#   'valid_accuracy': 0.0063326946,
#   'valid_loss': 0.0063326946},
#  {'epoch': 3467,
#   'train_loss': 0.0030876973,
#   'valid_accuracy': 0.0063558626,
#   'valid_loss': 0.0063558626},
#  {'epoch': 3468,
#   'train_loss': 0.0031470468,
#   'valid_accuracy': 0.0063667288,
#   'valid_loss': 0.0063667288}]

# %%
train_loss_6 = np.array([i["train_loss"] for i in specialists.train_history_])
valid_loss_6 = np.array([i["valid_loss"] for i in specialists.train_history_])
pyplot.plot(train_loss_6, linewidth=3, label="train")
pyplot.plot(valid_loss_6, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(0.1e-2, 3.2e-2)
# pyplot.yscale("log")
pyplot.show()

# %% [markdown]
# ## submit test data

# %%
import pandas as pd

xx_test, yy_test = load_svmlight_file("./phase1/new/aug_test2_50.dat")

# %%
xx_test.shape

# %%
xx_test = np.array(xx_test.todense()).reshape(-1,)
# xx_train = xx_train.dtype(np.float32)
xx_test = np.float32(xx_test)
xx_test = xx_test.reshape(7372,2500)

xx_test = xx_test.astype(np.float32)

def one_hot(x,n):
    if type(x) == list:
            x = np.array(x)
    x = x.flatten()
    o_h = np.zeros((len(x),n))
    o_h[np.arange(len(x)),x] = 1
    return o_h

yy_test = yy_test.astype(int32)    
yy_test = one_hot(yy_test, 32)
yy_test = yy_test.astype(np.float32)

Xt, yt = transform_6(xx_test, yy_test)
result = net7.predict(Xt)
result = np.array(map((lambda x: np.argmax(x)), result))
result.astype(int)

# %%
df_submission = pd.DataFrame( result.astype(int) ,columns=None)

df_submission.to_csv('./Lasagne_7th_test1_0.dat', index=None)
