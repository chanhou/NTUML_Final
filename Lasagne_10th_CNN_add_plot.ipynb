# %% [markdown]
# ## Lasagne code try and edit

# %% [markdown]
# ## input our data

# %%
import numpy as np
import math
import scipy.linalg as sp
from sklearn.datasets import load_svmlight_file

# %%
xx_train, y = load_svmlight_file("./phase1/new/aug_train_50_big.dat")
# print type(xx_train)
print xx_train.shape
xx_train = np.array(xx_train.todense()).reshape(-1,)
# xx_train = xx_train.dtype(np.float32)
xx_train = np.float32(xx_train)
xx_train = xx_train.reshape(24696,2500)
# print xx_train.shape
print type(xx_train)
# Out:
# (24696, 2500)
# <type 'numpy.ndarray'>

# %%
sizee = 50

# %%
# pylab.ion()
# pylab.imshow(xxxx[0],cmap=cm.gray)
x = xx_train.reshape(24696,sizee**2)
x = x.astype(np.float32)

print x.shape
print type(x)
# Out:
# (24696, 2500)
# <type 'numpy.ndarray'>

# %%
def one_hot(x,n):
    if type(x) == list:
            x = np.array(x)
    x = x.flatten()
    o_h = np.zeros((len(x),n))
    o_h[np.arange(len(x)),x] = 1
    return o_h

y = y.astype(int32)    
y = one_hot(y, 32)
y = y.astype(np.float32)

print y.shape
# Out:
# (24696, 32)

# %% [markdown]
# ## split data

# %%
from sklearn import cross_validation as cv
from sklearn import svm
from sklearn import metrics
from sklearn import grid_search as gs

# %%
X_train, X_test, y_train, y_test = cv.train_test_split(x, y, test_size=0.2)

# %%
print X_train.shape
print X_test.shape
print y_train.shape
print y_test.shape

# %% [markdown]
# ## First model of Lasagne with single hidden layer

# %%
# add to kfkd.py
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet

net1 = NeuralNet(
    layers=[  # three layers: one hidden layer
        ('input', layers.InputLayer),
        ('hidden', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    # layer parameters:
    input_shape=(128, 2500),  # 128 images per batch times 100x100 input pixels
    hidden_num_units=300,  # number of units in hidden layer
    output_nonlinearity=None,  # output layer uses identity function
    output_num_units=32,  # 30 target values

    # optimization method:
    upate=nesterov_momentum,
    update_learning_rate=0.01,
    update_momentum=0.9,

    # regression=False,  # flag to indicate we're dealing with regression problem
    regression=True,  # flag to indicate we're dealing with regression problem
    max_epochs=1000,  # we want to train this many epochs
    verbose=1,
    )
# Out:
# Using gpu device 0: GRID K520

# %%
# %time net1.fit(X_train, y_train)

# %%
train_loss = np.array([i["train_loss"] for i in net1.train_history_])
valid_loss = np.array([i["valid_loss"] for i in net1.train_history_])
pyplot.plot(train_loss, linewidth=3, label="train")
pyplot.plot(valid_loss, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(2.5e-2, 0.32e-1)
# pyplot.yscale("log")
pyplot.show()

# %%
from sklearn import metrics

# overfit result, should use validation result
y_pred = net1.predict(X_test)
# print y_pred[1]
# np.argmax(y_pred[i]),np.argmax(y[i])
y_pred = np.array(map((lambda x: np.argmax(x)), y_pred))
yyy = np.array(map((lambda x: np.argmax(x)), y_test))

print metrics.classification_report((yyy), (y_pred))

# %% [markdown]
# ## NET 6 in the rock

# %%
import theano
from lasagne import layers
from lasagne.updates import nesterov_momentum
from nolearn.lasagne import NeuralNet

def float32(k):
    return np.cast['float32'](k)

class AdjustVariable(object):
    def __init__(self, name, start=0.03, stop=0.001):
        self.name = name
        self.start, self.stop = start, stop
        self.ls = None

    def __call__(self, nn, train_history):
        if self.ls is None:
            self.ls = np.linspace(self.start, self.stop, nn.max_epochs)

        epoch = train_history[-1]['epoch']
        new_value = float32(self.ls[epoch - 1])
        getattr(nn, self.name).set_value(new_value)

class EarlyStopping(object):
    def __init__(self, patience=100):
        self.patience = patience
        self.best_valid = np.inf
        self.best_valid_epoch = 0
        self.best_weights = None

    def __call__(self, nn, train_history):
        current_valid = train_history[-1]['valid_loss']
        current_epoch = train_history[-1]['epoch']
        if current_valid < self.best_valid:
            self.best_valid = current_valid
            self.best_valid_epoch = current_epoch
            self.best_weights = [w.get_value() for w in nn.get_all_params()]
        elif self.best_valid_epoch + self.patience < current_epoch:
            print("Early stopping.")
            print("Best valid loss was {:.6f} at epoch {}.".format(
                self.best_valid, self.best_valid_epoch))
            nn.load_weights_from(self.best_weights)
            raise StopIteration()
        
# use the cuda-convnet implementations of conv and max-pool layer
Conv2DLayer = layers.cuda_convnet.Conv2DCCLayer
MaxPool2DLayer = layers.cuda_convnet.MaxPool2DCCLayer

net7 = NeuralNet(
    layers=[
        ('input', layers.InputLayer),
        ('conv1', Conv2DLayer),
        ('pool1', MaxPool2DLayer),
        ('dropout1', layers.DropoutLayer),  # !
        ('conv2', Conv2DLayer),
        ('pool2', MaxPool2DLayer),
        ('dropout2', layers.DropoutLayer),  # !
        ('conv3', Conv2DLayer),
        ('pool3', MaxPool2DLayer),
        ('dropout3', layers.DropoutLayer),  # !
        ('conv4', Conv2DLayer),###
        ('pool4', MaxPool2DLayer),###
        ('dropout4', layers.DropoutLayer),  # !###
        ('hidden5', layers.DenseLayer),
        ('dropout5', layers.DropoutLayer),  # !
        ('hidden6', layers.DenseLayer),
        ('output', layers.DenseLayer),
        ],
    input_shape=(128, 1, 50,50),
    conv1_num_filters=32, conv1_filter_size=(3, 3), pool1_ds=(2, 2),
    # dropout1_p=0.1, # !
    dropout1_p=0.1,  # !
    conv2_num_filters=64, conv2_filter_size=(2, 2), pool2_ds=(2, 2),
    # dropout2_p=0.2,  # !
    dropout2_p=0.2,  # !
    conv3_num_filters=128, conv3_filter_size=(2, 2), pool3_ds=(2, 2),
    # dropout3_p=0.3,  # !
    dropout3_p=0.3,  # !
    conv4_num_filters=256, conv4_filter_size=(2, 2), pool4_ds=(2, 2), ######
    # dropout3_p=0.3,  # !
    dropout4_p=0.4,  # !#########
    hidden5_num_units=1000,
    # hidden4_num_units=1000,  # !
    dropout5_p=0.5,  # !
    hidden6_num_units=1000,
    # hidden5_num_units=1000,  # !
    output_num_units=32, output_nonlinearity=None,

    update_learning_rate=theano.shared(float32(0.03)),
    update_momentum=theano.shared(float32(0.9)),

    regression=True,
#     batch_iterator=FlipBatchIterator(batch_size=128),
    on_epoch_finished=[
        AdjustVariable('update_learning_rate', start=0.03, stop=0.0001),
        AdjustVariable('update_momentum', start=0.9, stop=0.999),
        EarlyStopping(patience=200),
        ],
    # max_epochs=3000,
    max_epochs=10000,
    verbose=1,
    )
# Out:
# Using gpu device 0: GRID K520

# %%
def transform_6(X,y):
    X = X.reshape(-1, 50,50, 1)
    X = X.transpose(0, 3, 1, 2)
    return X, y

# X_train = X_train.reshape(-1,1,sizee,sizee)
# X_test = X_test.reshape(-1, 1,sizee,sizee)
# X_train.shape

# %%
import sys
sys.setrecursionlimit(10000)

X_6, y_6 = transform_6(X_train, y_train)
# %time net7.fit(X_6, y_6)

import cPickle as pickle
with open('Lasagne_10th_CNN_add.pickle', 'wb') as f:
    pickle.dump(net7, f, -1)

# %% [markdown]
# # start from here!!!!!!!!!!!!!!!!!!!!!
#
# ## load model from Lasagne_6th_drop_change_extend.pickle extend with test1 answer

# %%
import cPickle as pickle
with open('./Lasagne_10th_CNN_add.pickle', 'rb') as f:
    net7 = pickle.load(f)

# %%
# from sklearn.base import clone
# model2 = clone(net7)
# model2.load_weights_from(model)

# %%
# model

# %%
train_loss_6 = np.array([i["train_loss"] for i in net7.train_history_])
valid_loss_6 = np.array([i["valid_loss"] for i in net7.train_history_])
pyplot.plot(train_loss_6, linewidth=3, label="train")
pyplot.plot(valid_loss_6, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(0.1e-2, 3.2e-2)
# pyplot.yscale("log")
pyplot.show()

# %%
net7.train_history_
# Out:
# [{'epoch': 1,
#   'train_loss': 0.030962896,
#   'valid_accuracy': 0.030215835,
#   'valid_loss': 0.030215835},
#  {'epoch': 2,
#   'train_loss': 0.030198196,
#   'valid_accuracy': 0.03017959,
#   'valid_loss': 0.03017959},
#  {'epoch': 3,
#   'train_loss': 0.030073151,
#   'valid_accuracy': 0.03015542,
#   'valid_loss': 0.03015542},
#  {'epoch': 4,
#   'train_loss': 0.029970897,
#   'valid_accuracy': 0.030142818,
#   'valid_loss': 0.030142818},
#  {'epoch': 5,
#   'train_loss': 0.029866204,
#   'valid_accuracy': 0.030105766,
#   'valid_loss': 0.030105766},
#  {'epoch': 6,
#   'train_loss': 0.029769445,
#   'valid_accuracy': 0.030095266,
#   'valid_loss': 0.030095266},
#  {'epoch': 7,
#   'train_loss': 0.029665323,
#   'valid_accuracy': 0.030054966,
#   'valid_loss': 0.030054966},
#  {'epoch': 8,
#   'train_loss': 0.029584298,
#   'valid_accuracy': 0.030009786,
#   'valid_loss': 0.030009786},
#  {'epoch': 9,
#   'train_loss': 0.02950683,
#   'valid_accuracy': 0.029993387,
#   'valid_loss': 0.029993387},
#  {'epoch': 10,
#   'train_loss': 0.029443935,
#   'valid_accuracy': 0.029954733,
#   'valid_loss': 0.029954733},
#  {'epoch': 11,
#   'train_loss': 0.029390784,
#   'valid_accuracy': 0.029934406,
#   'valid_loss': 0.029934406},
#  {'epoch': 12,
#   'train_loss': 0.029344371,
#   'valid_accuracy': 0.02994659,
#   'valid_loss': 0.02994659},
#  {'epoch': 13,
#   'train_loss': 0.029305497,
#   'valid_accuracy': 0.029887104,
#   'valid_loss': 0.029887104},
#  {'epoch': 14,
#   'train_loss': 0.029253185,
#   'valid_accuracy': 0.029857034,
#   'valid_loss': 0.029857034},
#  {'epoch': 15,
#   'train_loss': 0.029221673,
#   'valid_accuracy': 0.029822916,
#   'valid_loss': 0.029822916},
#  {'epoch': 16,
#   'train_loss': 0.029197315,
#   'valid_accuracy': 0.029786419,
#   'valid_loss': 0.029786419},
#  {'epoch': 17,
#   'train_loss': 0.02916074,
#   'valid_accuracy': 0.029765278,
#   'valid_loss': 0.029765278},
#  {'epoch': 18,
#   'train_loss': 0.029122896,
#   'valid_accuracy': 0.029718895,
#   'valid_loss': 0.029718895},
#  {'epoch': 19,
#   'train_loss': 0.029079404,
#   'valid_accuracy': 0.029689174,
#   'valid_loss': 0.029689174},
#  {'epoch': 20,
#   'train_loss': 0.029060066,
#   'valid_accuracy': 0.029641276,
#   'valid_loss': 0.029641276},
#  {'epoch': 21,
#   'train_loss': 0.029004106,
#   'valid_accuracy': 0.029608684,
#   'valid_loss': 0.029608684},
#  {'epoch': 22,
#   'train_loss': 0.028986236,
#   'valid_accuracy': 0.029556107,
#   'valid_loss': 0.029556107},
#  {'epoch': 23,
#   'train_loss': 0.028946986,
#   'valid_accuracy': 0.0295389,
#   'valid_loss': 0.0295389},
#  {'epoch': 24,
#   'train_loss': 0.028906463,
#   'valid_accuracy': 0.02946688,
#   'valid_loss': 0.02946688},
#  {'epoch': 25,
#   'train_loss': 0.028877074,
#   'valid_accuracy': 0.029456545,
#   'valid_loss': 0.029456545},
#  {'epoch': 26,
#   'train_loss': 0.028840736,
#   'valid_accuracy': 0.029380735,
#   'valid_loss': 0.029380735},
#  {'epoch': 27,
#   'train_loss': 0.028794836,
#   'valid_accuracy': 0.02937795,
#   'valid_loss': 0.02937795},
#  {'epoch': 28,
#   'train_loss': 0.028760042,
#   'valid_accuracy': 0.029323667,
#   'valid_loss': 0.029323667},
#  {'epoch': 29,
#   'train_loss': 0.028700391,
#   'valid_accuracy': 0.029292289,
#   'valid_loss': 0.029292289},
#  {'epoch': 30,
#   'train_loss': 0.028666992,
#   'valid_accuracy': 0.029244456,
#   'valid_loss': 0.029244456},
#  {'epoch': 31,
#   'train_loss': 0.028632032,
#   'valid_accuracy': 0.02919814,
#   'valid_loss': 0.02919814},
#  {'epoch': 32,
#   'train_loss': 0.028597096,
#   'valid_accuracy': 0.029155603,
#   'valid_loss': 0.029155603},
#  {'epoch': 33,
#   'train_loss': 0.028562088,
#   'valid_accuracy': 0.029103884,
#   'valid_loss': 0.029103884},
#  {'epoch': 34,
#   'train_loss': 0.028520042,
#   'valid_accuracy': 0.029049335,
#   'valid_loss': 0.029049335},
#  {'epoch': 35,
#   'train_loss': 0.028478088,
#   'valid_accuracy': 0.029053031,
#   'valid_loss': 0.029053031},
#  {'epoch': 36,
#   'train_loss': 0.028442038,
#   'valid_accuracy': 0.028984107,
#   'valid_loss': 0.028984107},
#  {'epoch': 37,
#   'train_loss': 0.028392093,
#   'valid_accuracy': 0.028976206,
#   'valid_loss': 0.028976206},
#  {'epoch': 38,
#   'train_loss': 0.028364846,
#   'valid_accuracy': 0.0289427,
#   'valid_loss': 0.0289427},
#  {'epoch': 39,
#   'train_loss': 0.028330185,
#   'valid_accuracy': 0.028884973,
#   'valid_loss': 0.028884973},
#  {'epoch': 40,
#   'train_loss': 0.028301032,
#   'valid_accuracy': 0.028874932,
#   'valid_loss': 0.028874932},
#  {'epoch': 41,
#   'train_loss': 0.028275061,
#   'valid_accuracy': 0.028825283,
#   'valid_loss': 0.028825283},
#  {'epoch': 42,
#   'train_loss': 0.028224066,
#   'valid_accuracy': 0.028819786,
#   'valid_loss': 0.028819786},
#  {'epoch': 43,
#   'train_loss': 0.028218435,
#   'valid_accuracy': 0.028757049,
#   'valid_loss': 0.028757049},
#  {'epoch': 44,
#   'train_loss': 0.028163956,
#   'valid_accuracy': 0.028749909,
#   'valid_loss': 0.028749909},
#  {'epoch': 45,
#   'train_loss': 0.02815841,
#   'valid_accuracy': 0.028713617,
#   'valid_loss': 0.028713617},
#  {'epoch': 46,
#   'train_loss': 0.028138351,
#   'valid_accuracy': 0.028703421,
#   'valid_loss': 0.028703421},
#  {'epoch': 47,
#   'train_loss': 0.028088335,
#   'valid_accuracy': 0.028667245,
#   'valid_loss': 0.028667245},
#  {'epoch': 48,
#   'train_loss': 0.028064415,
#   'valid_accuracy': 0.028603707,
#   'valid_loss': 0.028603707},
#  {'epoch': 49,
#   'train_loss': 0.02803508,
#   'valid_accuracy': 0.028616462,
#   'valid_loss': 0.028616462},
#  {'epoch': 50,
#   'train_loss': 0.027994052,
#   'valid_accuracy': 0.028571105,
#   'valid_loss': 0.028571105},
#  {'epoch': 51,
#   'train_loss': 0.027968613,
#   'valid_accuracy': 0.028560057,
#   'valid_loss': 0.028560057},
#  {'epoch': 52,
#   'train_loss': 0.02793875,
#   'valid_accuracy': 0.028530892,
#   'valid_loss': 0.028530892},
#  {'epoch': 53,
#   'train_loss': 0.027897976,
#   'valid_accuracy': 0.028495407,
#   'valid_loss': 0.028495407},
#  {'epoch': 54,
#   'train_loss': 0.027874731,
#   'valid_accuracy': 0.02847827,
#   'valid_loss': 0.02847827},
#  {'epoch': 55,
#   'train_loss': 0.027846638,
#   'valid_accuracy': 0.028426146,
#   'valid_loss': 0.028426146},
#  {'epoch': 56,
#   'train_loss': 0.027807372,
#   'valid_accuracy': 0.028423747,
#   'valid_loss': 0.028423747},
#  {'epoch': 57,
#   'train_loss': 0.027776642,
#   'valid_accuracy': 0.028381042,
#   'valid_loss': 0.028381042},
#  {'epoch': 58,
#   'train_loss': 0.027737891,
#   'valid_accuracy': 0.028342199,
#   'valid_loss': 0.028342199},
#  {'epoch': 59,
#   'train_loss': 0.027698072,
#   'valid_accuracy': 0.028322125,
#   'valid_loss': 0.028322125},
#  {'epoch': 60,
#   'train_loss': 0.027664525,
#   'valid_accuracy': 0.028302792,
#   'valid_loss': 0.028302792},
#  {'epoch': 61,
#   'train_loss': 0.027631311,
#   'valid_accuracy': 0.028243333,
#   'valid_loss': 0.028243333},
#  {'epoch': 62,
#   'train_loss': 0.027612327,
#   'valid_accuracy': 0.028218171,
#   'valid_loss': 0.028218171},
#  {'epoch': 63,
#   'train_loss': 0.027563656,
#   'valid_accuracy': 0.028150411,
#   'valid_loss': 0.028150411},
#  {'epoch': 64,
#   'train_loss': 0.02753124,
#   'valid_accuracy': 0.028093815,
#   'valid_loss': 0.028093815},
#  {'epoch': 65,
#   'train_loss': 0.027492264,
#   'valid_accuracy': 0.028069798,
#   'valid_loss': 0.028069798},
#  {'epoch': 66,
#   'train_loss': 0.027441742,
#   'valid_accuracy': 0.02804954,
#   'valid_loss': 0.02804954},
#  {'epoch': 67,
#   'train_loss': 0.027418986,
#   'valid_accuracy': 0.027984347,
#   'valid_loss': 0.027984347},
#  {'epoch': 68,
#   'train_loss': 0.027357357,
#   'valid_accuracy': 0.027959181,
#   'valid_loss': 0.027959181},
#  {'epoch': 69,
#   'train_loss': 0.027341541,
#   'valid_accuracy': 0.027891627,
#   'valid_loss': 0.027891627},
#  {'epoch': 70,
#   'train_loss': 0.027274411,
#   'valid_accuracy': 0.027874356,
#   'valid_loss': 0.027874356},
#  {'epoch': 71,
#   'train_loss': 0.027258867,
#   'valid_accuracy': 0.027817775,
#   'valid_loss': 0.027817775},
#  {'epoch': 72,
#   'train_loss': 0.027205084,
#   'valid_accuracy': 0.027780004,
#   'valid_loss': 0.027780004},
#  {'epoch': 73,
#   'train_loss': 0.027149385,
#   'valid_accuracy': 0.027717995,
#   'valid_loss': 0.027717995},
#  {'epoch': 74,
#   'train_loss': 0.02712659,
#   'valid_accuracy': 0.027732225,
#   'valid_loss': 0.027732225},
#  {'epoch': 75,
#   'train_loss': 0.02708325,
#   'valid_accuracy': 0.027657341,
#   'valid_loss': 0.027657341},
#  {'epoch': 76,
#   'train_loss': 0.027041184,
#   'valid_accuracy': 0.027600832,
#   'valid_loss': 0.027600832},
#  {'epoch': 77,
#   'train_loss': 0.026997721,
#   'valid_accuracy': 0.027517781,
#   'valid_loss': 0.027517781},
#  {'epoch': 78,
#   'train_loss': 0.026943441,
#   'valid_accuracy': 0.027511667,
#   'valid_loss': 0.027511667},
#  {'epoch': 79,
#   'train_loss': 0.026907573,
#   'valid_accuracy': 0.027435765,
#   'valid_loss': 0.027435765},
#  {'epoch': 80,
#   'train_loss': 0.026864184,
#   'valid_accuracy': 0.027387995,
#   'valid_loss': 0.027387995},
#  {'epoch': 81,
#   'train_loss': 0.026831014,
#   'valid_accuracy': 0.027360171,
#   'valid_loss': 0.027360171},
#  {'epoch': 82,
#   'train_loss': 0.026785592,
#   'valid_accuracy': 0.027256945,
#   'valid_loss': 0.027256945},
#  {'epoch': 83,
#   'train_loss': 0.026726728,
#   'valid_accuracy': 0.027247585,
#   'valid_loss': 0.027247585},
#  {'epoch': 84,
#   'train_loss': 0.026697984,
#   'valid_accuracy': 0.027190605,
#   'valid_loss': 0.027190605},
#  {'epoch': 85,
#   'train_loss': 0.026644306,
#   'valid_accuracy': 0.027130947,
#   'valid_loss': 0.027130947},
#  {'epoch': 86,
#   'train_loss': 0.02658275,
#   'valid_accuracy': 0.027042838,
#   'valid_loss': 0.027042838},
#  {'epoch': 87,
#   'train_loss': 0.026542565,
#   'valid_accuracy': 0.027020911,
#   'valid_loss': 0.027020911},
#  {'epoch': 88,
#   'train_loss': 0.026514644,
#   'valid_accuracy': 0.0269731,
#   'valid_loss': 0.0269731},
#  {'epoch': 89,
#   'train_loss': 0.026491063,
#   'valid_accuracy': 0.026914716,
#   'valid_loss': 0.026914716},
#  {'epoch': 90,
#   'train_loss': 0.026429966,
#   'valid_accuracy': 0.026835265,
#   'valid_loss': 0.026835265},
#  {'epoch': 91,
#   'train_loss': 0.026381308,
#   'valid_accuracy': 0.026820851,
#   'valid_loss': 0.026820851},
#  {'epoch': 92,
#   'train_loss': 0.026338043,
#   'valid_accuracy': 0.026724067,
#   'valid_loss': 0.026724067},
#  {'epoch': 93,
#   'train_loss': 0.026282381,
#   'valid_accuracy': 0.02669012,
#   'valid_loss': 0.02669012},
#  {'epoch': 94,
#   'train_loss': 0.026250642,
#   'valid_accuracy': 0.02658307,
#   'valid_loss': 0.02658307},
#  {'epoch': 95,
#   'train_loss': 0.026194667,
#   'valid_accuracy': 0.026579533,
#   'valid_loss': 0.026579533},
#  {'epoch': 96,
#   'train_loss': 0.02613876,
#   'valid_accuracy': 0.026496319,
#   'valid_loss': 0.026496319},
#  {'epoch': 97,
#   'train_loss': 0.026098851,
#   'valid_accuracy': 0.026437201,
#   'valid_loss': 0.026437201},
#  {'epoch': 98,
#   'train_loss': 0.026049109,
#   'valid_accuracy': 0.026390238,
#   'valid_loss': 0.026390238},
#  {'epoch': 99,
#   'train_loss': 0.026035324,
#   'valid_accuracy': 0.026299864,
#   'valid_loss': 0.026299864},
#  {'epoch': 100,
#   'train_loss': 0.025958043,
#   'valid_accuracy': 0.02625908,
#   'valid_loss': 0.02625908},
#  {'epoch': 101,
#   'train_loss': 0.025927048,
#   'valid_accuracy': 0.0262144,
#   'valid_loss': 0.0262144},
#  {'epoch': 102,
#   'train_loss': 0.025902197,
#   'valid_accuracy': 0.026160374,
#   'valid_loss': 0.026160374},
#  {'epoch': 103,
#   'train_loss': 0.025824104,
#   'valid_accuracy': 0.026065616,
#   'valid_loss': 0.026065616},
#  {'epoch': 104,
#   'train_loss': 0.025780298,
#   'valid_accuracy': 0.0260188,
#   'valid_loss': 0.0260188},
#  {'epoch': 105,
#   'train_loss': 0.025720857,
#   'valid_accuracy': 0.0259765,
#   'valid_loss': 0.0259765},
#  {'epoch': 106,
#   'train_loss': 0.025678679,
#   'valid_accuracy': 0.025903596,
#   'valid_loss': 0.025903596},
#  {'epoch': 107,
#   'train_loss': 0.025644561,
#   'valid_accuracy': 0.025877148,
#   'valid_loss': 0.025877148},
#  {'epoch': 108,
#   'train_loss': 0.025603525,
#   'valid_accuracy': 0.025824256,
#   'valid_loss': 0.025824256},
#  {'epoch': 109,
#   'train_loss': 0.025527116,
#   'valid_accuracy': 0.025700245,
#   'valid_loss': 0.025700245},
#  {'epoch': 110,
#   'train_loss': 0.025476739,
#   'valid_accuracy': 0.025610825,
#   'valid_loss': 0.025610825},
#  {'epoch': 111,
#   'train_loss': 0.025396744,
#   'valid_accuracy': 0.025593007,
#   'valid_loss': 0.025593007},
#  {'epoch': 112,
#   'train_loss': 0.025365079,
#   'valid_accuracy': 0.025509641,
#   'valid_loss': 0.025509641},
#  {'epoch': 113,
#   'train_loss': 0.025354028,
#   'valid_accuracy': 0.025451804,
#   'valid_loss': 0.025451804},
#  {'epoch': 114,
#   'train_loss': 0.025284447,
#   'valid_accuracy': 0.025336048,
#   'valid_loss': 0.025336048},
#  {'epoch': 115,
#   'train_loss': 0.025227619,
#   'valid_accuracy': 0.02533309,
#   'valid_loss': 0.02533309},
#  {'epoch': 116,
#   'train_loss': 0.025189728,
#   'valid_accuracy': 0.025280062,
#   'valid_loss': 0.025280062},
#  {'epoch': 117,
#   'train_loss': 0.025156872,
#   'valid_accuracy': 0.025177944,
#   'valid_loss': 0.025177944},
#  {'epoch': 118,
#   'train_loss': 0.025069304,
#   'valid_accuracy': 0.025102843,
#   'valid_loss': 0.025102843},
#  {'epoch': 119,
#   'train_loss': 0.025013741,
#   'valid_accuracy': 0.025085507,
#   'valid_loss': 0.025085507},
#  {'epoch': 120,
#   'train_loss': 0.024986492,
#   'valid_accuracy': 0.024984837,
#   'valid_loss': 0.024984837},
#  {'epoch': 121,
#   'train_loss': 0.024920659,
#   'valid_accuracy': 0.024940588,
#   'valid_loss': 0.024940588},
#  {'epoch': 122,
#   'train_loss': 0.02490188,
#   'valid_accuracy': 0.024882242,
#   'valid_loss': 0.024882242},
#  {'epoch': 123,
#   'train_loss': 0.024817754,
#   'valid_accuracy': 0.024760015,
#   'valid_loss': 0.024760015},
#  {'epoch': 124,
#   'train_loss': 0.024804499,
#   'valid_accuracy': 0.024744958,
#   'valid_loss': 0.024744958},
#  {'epoch': 125,
#   'train_loss': 0.024743892,
#   'valid_accuracy': 0.024658369,
#   'valid_loss': 0.024658369},
#  {'epoch': 126,
#   'train_loss': 0.024652602,
#   'valid_accuracy': 0.024589831,
#   'valid_loss': 0.024589831},
#  {'epoch': 127,
#   'train_loss': 0.024591394,
#   'valid_accuracy': 0.024482738,
#   'valid_loss': 0.024482738},
#  {'epoch': 128,
#   'train_loss': 0.024534218,
#   'valid_accuracy': 0.024431378,
#   'valid_loss': 0.024431378},
#  {'epoch': 129,
#   'train_loss': 0.024510626,
#   'valid_accuracy': 0.024338556,
#   'valid_loss': 0.024338556},
#  {'epoch': 130,
#   'train_loss': 0.024424562,
#   'valid_accuracy': 0.024300827,
#   'valid_loss': 0.024300827},
#  {'epoch': 131,
#   'train_loss': 0.024388075,
#   'valid_accuracy': 0.024167379,
#   'valid_loss': 0.024167379},
#  {'epoch': 132,
#   'train_loss': 0.024347028,
#   'valid_accuracy': 0.024159774,
#   'valid_loss': 0.024159774},
#  {'epoch': 133,
#   'train_loss': 0.02431174,
#   'valid_accuracy': 0.024074031,
#   'valid_loss': 0.024074031},
#  {'epoch': 134,
#   'train_loss': 0.024209442,
#   'valid_accuracy': 0.023969291,
#   'valid_loss': 0.023969291},
#  {'epoch': 135,
#   'train_loss': 0.024173701,
#   'valid_accuracy': 0.023880461,
#   'valid_loss': 0.023880461},
#  {'epoch': 136,
#   'train_loss': 0.024082746,
#   'valid_accuracy': 0.023810741,
#   'valid_loss': 0.023810741},
#  {'epoch': 137,
#   'train_loss': 0.024015261,
#   'valid_accuracy': 0.023771591,
#   'valid_loss': 0.023771591},
#  {'epoch': 138,
#   'train_loss': 0.023953676,
#   'valid_accuracy': 0.023616614,
#   'valid_loss': 0.023616614},
#  {'epoch': 139,
#   'train_loss': 0.023912705,
#   'valid_accuracy': 0.0235663,
#   'valid_loss': 0.0235663},
#  {'epoch': 140,
#   'train_loss': 0.023844035,
#   'valid_accuracy': 0.0235015,
#   'valid_loss': 0.0235015},
#  {'epoch': 141,
#   'train_loss': 0.023795592,
#   'valid_accuracy': 0.023407191,
#   'valid_loss': 0.023407191},
#  {'epoch': 142,
#   'train_loss': 0.023723753,
#   'valid_accuracy': 0.023364563,
#   'valid_loss': 0.023364563},
#  {'epoch': 143,
#   'train_loss': 0.023653336,
#   'valid_accuracy': 0.023223393,
#   'valid_loss': 0.023223393},
#  {'epoch': 144,
#   'train_loss': 0.023574889,
#   'valid_accuracy': 0.023151454,
#   'valid_loss': 0.023151454},
#  {'epoch': 145,
#   'train_loss': 0.023529276,
#   'valid_accuracy': 0.023059087,
#   'valid_loss': 0.023059087},
#  {'epoch': 146,
#   'train_loss': 0.023416741,
#   'valid_accuracy': 0.022908704,
#   'valid_loss': 0.022908704},
#  {'epoch': 147,
#   'train_loss': 0.023380946,
#   'valid_accuracy': 0.022825399,
#   'valid_loss': 0.022825399},
#  {'epoch': 148,
#   'train_loss': 0.023316959,
#   'valid_accuracy': 0.022791239,
#   'valid_loss': 0.022791239},
#  {'epoch': 149,
#   'train_loss': 0.023252545,
#   'valid_accuracy': 0.022698075,
#   'valid_loss': 0.022698075},
#  {'epoch': 150,
#   'train_loss': 0.023173949,
#   'valid_accuracy': 0.022642557,
#   'valid_loss': 0.022642557},
#  {'epoch': 151,
#   'train_loss': 0.023137866,
#   'valid_accuracy': 0.022494961,
#   'valid_loss': 0.022494961},
#  {'epoch': 152,
#   'train_loss': 0.023096975,
#   'valid_accuracy': 0.022450684,
#   'valid_loss': 0.022450684},
#  {'epoch': 153,
#   'train_loss': 0.022994963,
#   'valid_accuracy': 0.02233948,
#   'valid_loss': 0.02233948},
#  {'epoch': 154,
#   'train_loss': 0.02289569,
#   'valid_accuracy': 0.022293532,
#   'valid_loss': 0.022293532},
#  {'epoch': 155,
#   'train_loss': 0.022838254,
#   'valid_accuracy': 0.022128429,
#   'valid_loss': 0.022128429},
#  {'epoch': 156,
#   'train_loss': 0.022771984,
#   'valid_accuracy': 0.022049503,
#   'valid_loss': 0.022049503},
#  {'epoch': 157,
#   'train_loss': 0.022728432,
#   'valid_accuracy': 0.02190939,
#   'valid_loss': 0.02190939},
#  {'epoch': 158,
#   'train_loss': 0.02266483,
#   'valid_accuracy': 0.021816066,
#   'valid_loss': 0.021816066},
#  {'epoch': 159,
#   'train_loss': 0.0226091,
#   'valid_accuracy': 0.021771211,
#   'valid_loss': 0.021771211},
#  {'epoch': 160,
#   'train_loss': 0.022524238,
#   'valid_accuracy': 0.021678535,
#   'valid_loss': 0.021678535},
#  {'epoch': 161,
#   'train_loss': 0.022446202,
#   'valid_accuracy': 0.021626692,
#   'valid_loss': 0.021626692},
#  {'epoch': 162,
#   'train_loss': 0.022425307,
#   'valid_accuracy': 0.021558411,
#   'valid_loss': 0.021558411},
#  {'epoch': 163,
#   'train_loss': 0.022284295,
#   'valid_accuracy': 0.02141995,
#   'valid_loss': 0.02141995},
#  {'epoch': 164,
#   'train_loss': 0.022166273,
#   'valid_accuracy': 0.021287413,
#   'valid_loss': 0.021287413},
#  {'epoch': 165,
#   'train_loss': 0.022165231,
#   'valid_accuracy': 0.021251941,
#   'valid_loss': 0.021251941},
#  {'epoch': 166,
#   'train_loss': 0.022096945,
#   'valid_accuracy': 0.021094806,
#   'valid_loss': 0.021094806},
#  {'epoch': 167,
#   'train_loss': 0.021977808,
#   'valid_accuracy': 0.021044167,
#   'valid_loss': 0.021044167},
#  {'epoch': 168,
#   'train_loss': 0.021983085,
#   'valid_accuracy': 0.020884261,
#   'valid_loss': 0.020884261},
#  {'epoch': 169,
#   'train_loss': 0.021892641,
#   'valid_accuracy': 0.020902544,
#   'valid_loss': 0.020902544},
#  {'epoch': 170,
#   'train_loss': 0.021844212,
#   'valid_accuracy': 0.02074264,
#   'valid_loss': 0.02074264},
#  {'epoch': 171,
#   'train_loss': 0.021770403,
#   'valid_accuracy': 0.02066352,
#   'valid_loss': 0.02066352},
#  {'epoch': 172,
#   'train_loss': 0.021660279,
#   'valid_accuracy': 0.020615345,
#   'valid_loss': 0.020615345},
#  {'epoch': 173,
#   'train_loss': 0.021605005,
#   'valid_accuracy': 0.020535948,
#   'valid_loss': 0.020535948},
#  {'epoch': 174,
#   'train_loss': 0.021542776,
#   'valid_accuracy': 0.02049724,
#   'valid_loss': 0.02049724},
#  {'epoch': 175,
#   'train_loss': 0.02142063,
#   'valid_accuracy': 0.020283543,
#   'valid_loss': 0.020283543},
#  {'epoch': 176,
#   'train_loss': 0.021401366,
#   'valid_accuracy': 0.020184264,
#   'valid_loss': 0.020184264},
#  {'epoch': 177,
#   'train_loss': 0.021333054,
#   'valid_accuracy': 0.020089671,
#   'valid_loss': 0.020089671},
#  {'epoch': 178,
#   'train_loss': 0.021269185,
#   'valid_accuracy': 0.020054871,
#   'valid_loss': 0.020054871},
#  {'epoch': 179,
#   'train_loss': 0.021221854,
#   'valid_accuracy': 0.019974532,
#   'valid_loss': 0.019974532},
#  {'epoch': 180,
#   'train_loss': 0.021126712,
#   'valid_accuracy': 0.019817892,
#   'valid_loss': 0.019817892},
#  {'epoch': 181,
#   'train_loss': 0.021089498,
#   'valid_accuracy': 0.019853415,
#   'valid_loss': 0.019853415},
#  {'epoch': 182,
#   'train_loss': 0.020996047,
#   'valid_accuracy': 0.019650398,
#   'valid_loss': 0.019650398},
#  {'epoch': 183,
#   'train_loss': 0.020936538,
#   'valid_accuracy': 0.019594282,
#   'valid_loss': 0.019594282},
#  {'epoch': 184,
#   'train_loss': 0.020913102,
#   'valid_accuracy': 0.019571174,
#   'valid_loss': 0.019571174},
#  {'epoch': 185,
#   'train_loss': 0.020777252,
#   'valid_accuracy': 0.019437158,
#   'valid_loss': 0.019437158},
#  {'epoch': 186,
#   'train_loss': 0.020719286,
#   'valid_accuracy': 0.019381259,
#   'valid_loss': 0.019381259},
#  {'epoch': 187,
#   'train_loss': 0.020686066,
#   'valid_accuracy': 0.0192423,
#   'valid_loss': 0.0192423},
#  {'epoch': 188,
#   'train_loss': 0.020596741,
#   'valid_accuracy': 0.01915889,
#   'valid_loss': 0.01915889},
#  {'epoch': 189,
#   'train_loss': 0.020532375,
#   'valid_accuracy': 0.019072672,
#   'valid_loss': 0.019072672},
#  {'epoch': 190,
#   'train_loss': 0.020490849,
#   'valid_accuracy': 0.018989338,
#   'valid_loss': 0.018989338},
#  {'epoch': 191,
#   'train_loss': 0.020371519,
#   'valid_accuracy': 0.01889018,
#   'valid_loss': 0.01889018},
#  {'epoch': 192,
#   'train_loss': 0.020304913,
#   'valid_accuracy': 0.018765787,
#   'valid_loss': 0.018765787},
#  {'epoch': 193,
#   'train_loss': 0.02026432,
#   'valid_accuracy': 0.018637164,
#   'valid_loss': 0.018637164},
#  {'epoch': 194,
#   'train_loss': 0.020145399,
#   'valid_accuracy': 0.018606322,
#   'valid_loss': 0.018606322},
#  {'epoch': 195,
#   'train_loss': 0.020165071,
#   'valid_accuracy': 0.018556211,
#   'valid_loss': 0.018556211},
#  {'epoch': 196,
#   'train_loss': 0.020055601,
#   'valid_accuracy': 0.018502228,
#   'valid_loss': 0.018502228},
#  {'epoch': 197,
#   'train_loss': 0.019998141,
#   'valid_accuracy': 0.018514076,
#   'valid_loss': 0.018514076},
#  {'epoch': 198,
#   'train_loss': 0.019930897,
#   'valid_accuracy': 0.01832266,
#   'valid_loss': 0.01832266},
#  {'epoch': 199,
#   'train_loss': 0.019872863,
#   'valid_accuracy': 0.01825601,
#   'valid_loss': 0.01825601},
#  {'epoch': 200,
#   'train_loss': 0.019817233,
#   'valid_accuracy': 0.018116232,
#   'valid_loss': 0.018116232},
#  {'epoch': 201,
#   'train_loss': 0.019705588,
#   'valid_accuracy': 0.018109852,
#   'valid_loss': 0.018109852},
#  {'epoch': 202,
#   'train_loss': 0.019684497,
#   'valid_accuracy': 0.017970493,
#   'valid_loss': 0.017970493},
#  {'epoch': 203,
#   'train_loss': 0.019619826,
#   'valid_accuracy': 0.017897407,
#   'valid_loss': 0.017897407},
#  {'epoch': 204,
#   'train_loss': 0.019540399,
#   'valid_accuracy': 0.017804924,
#   'valid_loss': 0.017804924},
#  {'epoch': 205,
#   'train_loss': 0.01948691,
#   'valid_accuracy': 0.017738454,
#   'valid_loss': 0.017738454},
#  {'epoch': 206,
#   'train_loss': 0.01940866,
#   'valid_accuracy': 0.017607791,
#   'valid_loss': 0.017607791},
#  {'epoch': 207,
#   'train_loss': 0.019381054,
#   'valid_accuracy': 0.017602846,
#   'valid_loss': 0.017602846},
#  {'epoch': 208,
#   'train_loss': 0.019290486,
#   'valid_accuracy': 0.017509762,
#   'valid_loss': 0.017509762},
#  {'epoch': 209,
#   'train_loss': 0.019229218,
#   'valid_accuracy': 0.017390419,
#   'valid_loss': 0.017390419},
#  {'epoch': 210,
#   'train_loss': 0.019158244,
#   'valid_accuracy': 0.017365934,
#   'valid_loss': 0.017365934},
#  {'epoch': 211,
#   'train_loss': 0.019103354,
#   'valid_accuracy': 0.017172856,
#   'valid_loss': 0.017172856},
#  {'epoch': 212,
#   'train_loss': 0.018980278,
#   'valid_accuracy': 0.01718956,
#   'valid_loss': 0.01718956},
#  {'epoch': 213,
#   'train_loss': 0.018925533,
#   'valid_accuracy': 0.017124895,
#   'valid_loss': 0.017124895},
#  {'epoch': 214,
#   'train_loss': 0.018946907,
#   'valid_accuracy': 0.017024554,
#   'valid_loss': 0.017024554},
#  {'epoch': 215,
#   'train_loss': 0.018836485,
#   'valid_accuracy': 0.016934238,
#   'valid_loss': 0.016934238},
#  {'epoch': 216,
#   'train_loss': 0.018785508,
#   'valid_accuracy': 0.016931713,
#   'valid_loss': 0.016931713},
#  {'epoch': 217,
#   'train_loss': 0.018688681,
#   'valid_accuracy': 0.016857089,
#   'valid_loss': 0.016857089},
#  {'epoch': 218,
#   'train_loss': 0.018709198,
#   'valid_accuracy': 0.016763343,
#   'valid_loss': 0.016763343},
#  {'epoch': 219,
#   'train_loss': 0.018556926,
#   'valid_accuracy': 0.016618183,
#   'valid_loss': 0.016618183},
#  {'epoch': 220,
#   'train_loss': 0.018563855,
#   'valid_accuracy': 0.016549706,
#   'valid_loss': 0.016549706},
#  {'epoch': 221,
#   'train_loss': 0.018475493,
#   'valid_accuracy': 0.016565673,
#   'valid_loss': 0.016565673},
#  {'epoch': 222,
#   'train_loss': 0.01842685,
#   'valid_accuracy': 0.016448034,
#   'valid_loss': 0.016448034},
#  {'epoch': 223,
#   'train_loss': 0.01836776,
#   'valid_accuracy': 0.016370714,
#   'valid_loss': 0.016370714},
#  {'epoch': 224,
#   'train_loss': 0.018314993,
#   'valid_accuracy': 0.016281946,
#   'valid_loss': 0.016281946},
#  {'epoch': 225,
#   'train_loss': 0.018246103,
#   'valid_accuracy': 0.016202271,
#   'valid_loss': 0.016202271},
#  {'epoch': 226,
#   'train_loss': 0.018190408,
#   'valid_accuracy': 0.016201781,
#   'valid_loss': 0.016201781},
#  {'epoch': 227,
#   'train_loss': 0.018154792,
#   'valid_accuracy': 0.016143365,
#   'valid_loss': 0.016143365},
#  {'epoch': 228,
#   'train_loss': 0.018093603,
#   'valid_accuracy': 0.01599947,
#   'valid_loss': 0.01599947},
#  {'epoch': 229,
#   'train_loss': 0.017998263,
#   'valid_accuracy': 0.015987894,
#   'valid_loss': 0.015987894},
#  {'epoch': 230,
#   'train_loss': 0.01800295,
#   'valid_accuracy': 0.016019171,
#   'valid_loss': 0.016019171},
#  {'epoch': 231,
#   'train_loss': 0.01788787,
#   'valid_accuracy': 0.015877498,
#   'valid_loss': 0.015877498},
#  {'epoch': 232,
#   'train_loss': 0.01788584,
#   'valid_accuracy': 0.015769219,
#   'valid_loss': 0.015769219},
#  {'epoch': 233,
#   'train_loss': 0.017854007,
#   'valid_accuracy': 0.015686572,
#   'valid_loss': 0.015686572},
#  {'epoch': 234,
#   'train_loss': 0.017734846,
#   'valid_accuracy': 0.01557046,
#   'valid_loss': 0.01557046},
#  {'epoch': 235,
#   'train_loss': 0.017646488,
#   'valid_accuracy': 0.015619342,
#   'valid_loss': 0.015619342},
#  {'epoch': 236,
#   'train_loss': 0.017687388,
#   'valid_accuracy': 0.015605728,
#   'valid_loss': 0.015605728},
#  {'epoch': 237,
#   'train_loss': 0.017604413,
#   'valid_accuracy': 0.015424244,
#   'valid_loss': 0.015424244},
#  {'epoch': 238,
#   'train_loss': 0.017475588,
#   'valid_accuracy': 0.015319505,
#   'valid_loss': 0.015319505},
#  {'epoch': 239,
#   'train_loss': 0.017508233,
#   'valid_accuracy': 0.015340747,
#   'valid_loss': 0.015340747},
#  {'epoch': 240,
#   'train_loss': 0.017482309,
#   'valid_accuracy': 0.015276661,
#   'valid_loss': 0.015276661},
#  {'epoch': 241,
#   'train_loss': 0.017363753,
#   'valid_accuracy': 0.015173314,
#   'valid_loss': 0.015173314},
#  {'epoch': 242,
#   'train_loss': 0.017324114,
#   'valid_accuracy': 0.015197239,
#   'valid_loss': 0.015197239},
#  {'epoch': 243,
#   'train_loss': 0.017261988,
#   'valid_accuracy': 0.015131718,
#   'valid_loss': 0.015131718},
#  {'epoch': 244,
#   'train_loss': 0.017212439,
#   'valid_accuracy': 0.014976807,
#   'valid_loss': 0.014976807},
#  {'epoch': 245,
#   'train_loss': 0.01712054,
#   'valid_accuracy': 0.015008873,
#   'valid_loss': 0.015008873},
#  {'epoch': 246,
#   'train_loss': 0.017127836,
#   'valid_accuracy': 0.014858751,
#   'valid_loss': 0.014858751},
#  {'epoch': 247,
#   'train_loss': 0.01702893,
#   'valid_accuracy': 0.014918234,
#   'valid_loss': 0.014918234},
#  {'epoch': 248,
#   'train_loss': 0.0169449,
#   'valid_accuracy': 0.014776883,
#   'valid_loss': 0.014776883},
#  {'epoch': 249,
#   'train_loss': 0.016958127,
#   'valid_accuracy': 0.014711385,
#   'valid_loss': 0.014711385},
#  {'epoch': 250,
#   'train_loss': 0.016919214,
#   'valid_accuracy': 0.014686332,
#   'valid_loss': 0.014686332},
#  {'epoch': 251,
#   'train_loss': 0.016862102,
#   'valid_accuracy': 0.014607044,
#   'valid_loss': 0.014607044},
#  {'epoch': 252,
#   'train_loss': 0.016753713,
#   'valid_accuracy': 0.014505439,
#   'valid_loss': 0.014505439},
#  {'epoch': 253,
#   'train_loss': 0.016736371,
#   'valid_accuracy': 0.014575801,
#   'valid_loss': 0.014575801},
#  {'epoch': 254,
#   'train_loss': 0.016747791,
#   'valid_accuracy': 0.014481218,
#   'valid_loss': 0.014481218},
#  {'epoch': 255,
#   'train_loss': 0.016684046,
#   'valid_accuracy': 0.014345594,
#   'valid_loss': 0.014345594},
#  {'epoch': 256,
#   'train_loss': 0.016579835,
#   'valid_accuracy': 0.014392404,
#   'valid_loss': 0.014392404},
#  {'epoch': 257,
#   'train_loss': 0.01658975,
#   'valid_accuracy': 0.014245889,
#   'valid_loss': 0.014245889},
#  {'epoch': 258,
#   'train_loss': 0.016485495,
#   'valid_accuracy': 0.014166007,
#   'valid_loss': 0.014166007},
#  {'epoch': 259,
#   'train_loss': 0.016468599,
#   'valid_accuracy': 0.014227349,
#   'valid_loss': 0.014227349},
#  {'epoch': 260,
#   'train_loss': 0.016362919,
#   'valid_accuracy': 0.01415461,
#   'valid_loss': 0.01415461},
#  {'epoch': 261,
#   'train_loss': 0.016385501,
#   'valid_accuracy': 0.014115502,
#   'valid_loss': 0.014115502},
#  {'epoch': 262,
#   'train_loss': 0.016280461,
#   'valid_accuracy': 0.014095328,
#   'valid_loss': 0.014095328},
#  {'epoch': 263,
#   'train_loss': 0.016318141,
#   'valid_accuracy': 0.014088631,
#   'valid_loss': 0.014088631},
#  {'epoch': 264,
#   'train_loss': 0.016269896,
#   'valid_accuracy': 0.013860629,
#   'valid_loss': 0.013860629},
#  {'epoch': 265,
#   'train_loss': 0.01622222,
#   'valid_accuracy': 0.01387877,
#   'valid_loss': 0.01387877},
#  {'epoch': 266,
#   'train_loss': 0.016194623,
#   'valid_accuracy': 0.013860388,
#   'valid_loss': 0.013860388},
#  {'epoch': 267,
#   'train_loss': 0.016154647,
#   'valid_accuracy': 0.013752737,
#   'valid_loss': 0.013752737},
#  {'epoch': 268,
#   'train_loss': 0.016106319,
#   'valid_accuracy': 0.01374904,
#   'valid_loss': 0.01374904},
#  {'epoch': 269,
#   'train_loss': 0.016064296,
#   'valid_accuracy': 0.01368077,
#   'valid_loss': 0.01368077},
#  {'epoch': 270,
#   'train_loss': 0.015979066,
#   'valid_accuracy': 0.013572742,
#   'valid_loss': 0.013572742},
#  {'epoch': 271,
#   'train_loss': 0.016012896,
#   'valid_accuracy': 0.013622536,
#   'valid_loss': 0.013622536},
#  {'epoch': 272,
#   'train_loss': 0.015918557,
#   'valid_accuracy': 0.013580021,
#   'valid_loss': 0.013580021},
#  {'epoch': 273,
#   'train_loss': 0.015852334,
#   'valid_accuracy': 0.013500609,
#   'valid_loss': 0.013500609},
#  {'epoch': 274,
#   'train_loss': 0.01586175,
#   'valid_accuracy': 0.013531363,
#   'valid_loss': 0.013531363},
#  {'epoch': 275,
#   'train_loss': 0.015853198,
#   'valid_accuracy': 0.013464758,
#   'valid_loss': 0.013464758},
#  {'epoch': 276,
#   'train_loss': 0.015773701,
#   'valid_accuracy': 0.013394999,
#   'valid_loss': 0.013394999},
#  {'epoch': 277,
#   'train_loss': 0.015764169,
#   'valid_accuracy': 0.013482466,
#   'valid_loss': 0.013482466},
#  {'epoch': 278,
#   'train_loss': 0.015691519,
#   'valid_accuracy': 0.013312972,
#   'valid_loss': 0.013312972},
#  {'epoch': 279,
#   'train_loss': 0.015616551,
#   'valid_accuracy': 0.013252852,
#   'valid_loss': 0.013252852},
#  {'epoch': 280,
#   'train_loss': 0.015636919,
#   'valid_accuracy': 0.013249393,
#   'valid_loss': 0.013249393},
#  {'epoch': 281,
#   'train_loss': 0.015555179,
#   'valid_accuracy': 0.013207507,
#   'valid_loss': 0.013207507},
#  {'epoch': 282,
#   'train_loss': 0.015614082,
#   'valid_accuracy': 0.013248148,
#   'valid_loss': 0.013248148},
#  {'epoch': 283,
#   'train_loss': 0.015531436,
#   'valid_accuracy': 0.013196204,
#   'valid_loss': 0.013196204},
#  {'epoch': 284,
#   'train_loss': 0.01541869,
#   'valid_accuracy': 0.013202529,
#   'valid_loss': 0.013202529},
#  {'epoch': 285,
#   'train_loss': 0.015511693,
#   'valid_accuracy': 0.013042641,
#   'valid_loss': 0.013042641},
#  {'epoch': 286,
#   'train_loss': 0.015424573,
#   'valid_accuracy': 0.013067706,
#   'valid_loss': 0.013067706},
#  {'epoch': 287,
#   'train_loss': 0.015372178,
#   'valid_accuracy': 0.013040664,
#   'valid_loss': 0.013040664},
#  {'epoch': 288,
#   'train_loss': 0.01541585,
#   'valid_accuracy': 0.013023834,
#   'valid_loss': 0.013023834},
#  {'epoch': 289,
#   'train_loss': 0.015331553,
#   'valid_accuracy': 0.012964346,
#   'valid_loss': 0.012964346},
#  {'epoch': 290,
#   'train_loss': 0.015299719,
#   'valid_accuracy': 0.01294365,
#   'valid_loss': 0.01294365},
#  {'epoch': 291,
#   'train_loss': 0.0152586,
#   'valid_accuracy': 0.012893811,
#   'valid_loss': 0.012893811},
#  {'epoch': 292,
#   'train_loss': 0.015188751,
#   'valid_accuracy': 0.01276547,
#   'valid_loss': 0.01276547},
#  {'epoch': 293,
#   'train_loss': 0.015184034,
#   'valid_accuracy': 0.012779752,
#   'valid_loss': 0.012779752},
#  {'epoch': 294,
#   'train_loss': 0.015116944,
#   'valid_accuracy': 0.012787979,
#   'valid_loss': 0.012787979},
#  {'epoch': 295,
#   'train_loss': 0.015093593,
#   'valid_accuracy': 0.012710846,
#   'valid_loss': 0.012710846},
#  {'epoch': 296,
#   'train_loss': 0.015054096,
#   'valid_accuracy': 0.012719419,
#   'valid_loss': 0.012719419},
#  {'epoch': 297,
#   'train_loss': 0.015020037,
#   'valid_accuracy': 0.012690956,
#   'valid_loss': 0.012690956},
#  {'epoch': 298,
#   'train_loss': 0.015014498,
#   'valid_accuracy': 0.012635165,
#   'valid_loss': 0.012635165},
#  {'epoch': 299,
#   'train_loss': 0.014965246,
#   'valid_accuracy': 0.012599116,
#   'valid_loss': 0.012599116},
#  {'epoch': 300,
#   'train_loss': 0.014962449,
#   'valid_accuracy': 0.012585675,
#   'valid_loss': 0.012585675},
#  {'epoch': 301,
#   'train_loss': 0.014897316,
#   'valid_accuracy': 0.012624346,
#   'valid_loss': 0.012624346},
#  {'epoch': 302,
#   'train_loss': 0.014885891,
#   'valid_accuracy': 0.012559533,
#   'valid_loss': 0.012559533},
#  {'epoch': 303,
#   'train_loss': 0.014827374,
#   'valid_accuracy': 0.012505031,
#   'valid_loss': 0.012505031},
#  {'epoch': 304,
#   'train_loss': 0.014822159,
#   'valid_accuracy': 0.01251116,
#   'valid_loss': 0.01251116},
#  {'epoch': 305,
#   'train_loss': 0.014810348,
#   'valid_accuracy': 0.012478461,
#   'valid_loss': 0.012478461},
#  {'epoch': 306,
#   'train_loss': 0.014825747,
#   'valid_accuracy': 0.012511149,
#   'valid_loss': 0.012511149},
#  {'epoch': 307,
#   'train_loss': 0.014720623,
#   'valid_accuracy': 0.012401382,
#   'valid_loss': 0.012401382},
#  {'epoch': 308,
#   'train_loss': 0.014676189,
#   'valid_accuracy': 0.012439368,
#   'valid_loss': 0.012439368},
#  {'epoch': 309,
#   'train_loss': 0.014650488,
#   'valid_accuracy': 0.012385787,
#   'valid_loss': 0.012385787},
#  {'epoch': 310,
#   'train_loss': 0.01467701,
#   'valid_accuracy': 0.012325534,
#   'valid_loss': 0.012325534},
#  {'epoch': 311,
#   'train_loss': 0.014706158,
#   'valid_accuracy': 0.012340685,
#   'valid_loss': 0.012340685},
#  {'epoch': 312,
#   'train_loss': 0.014583038,
#   'valid_accuracy': 0.012239343,
#   'valid_loss': 0.012239343},
#  {'epoch': 313,
#   'train_loss': 0.014509057,
#   'valid_accuracy': 0.012267681,
#   'valid_loss': 0.012267681},
#  {'epoch': 314,
#   'train_loss': 0.014496062,
#   'valid_accuracy': 0.012165322,
#   'valid_loss': 0.012165322},
#  {'epoch': 315,
#   'train_loss': 0.014513408,
#   'valid_accuracy': 0.012218937,
#   'valid_loss': 0.012218937},
#  {'epoch': 316,
#   'train_loss': 0.014459653,
#   'valid_accuracy': 0.012246862,
#   'valid_loss': 0.012246862},
#  {'epoch': 317,
#   'train_loss': 0.014426994,
#   'valid_accuracy': 0.012091942,
#   'valid_loss': 0.012091942},
#  {'epoch': 318,
#   'train_loss': 0.014465986,
#   'valid_accuracy': 0.012110373,
#   'valid_loss': 0.012110373},
#  {'epoch': 319,
#   'train_loss': 0.014351299,
#   'valid_accuracy': 0.012081831,
#   'valid_loss': 0.012081831},
#  {'epoch': 320,
#   'train_loss': 0.014405994,
#   'valid_accuracy': 0.012087834,
#   'valid_loss': 0.012087834},
#  {'epoch': 321,
#   'train_loss': 0.014334251,
#   'valid_accuracy': 0.012165194,
#   'valid_loss': 0.012165194},
#  {'epoch': 322,
#   'train_loss': 0.014361924,
#   'valid_accuracy': 0.012040786,
#   'valid_loss': 0.012040786},
#  {'epoch': 323,
#   'train_loss': 0.014223273,
#   'valid_accuracy': 0.011991153,
#   'valid_loss': 0.011991153},
#  {'epoch': 324,
#   'train_loss': 0.014319323,
#   'valid_accuracy': 0.012031051,
#   'valid_loss': 0.012031051},
#  {'epoch': 325,
#   'train_loss': 0.014207157,
#   'valid_accuracy': 0.011930977,
#   'valid_loss': 0.011930977},
#  {'epoch': 326,
#   'train_loss': 0.014267772,
#   'valid_accuracy': 0.012017993,
#   'valid_loss': 0.012017993},
#  {'epoch': 327,
#   'train_loss': 0.014267249,
#   'valid_accuracy': 0.011900643,
#   'valid_loss': 0.011900643},
#  {'epoch': 328,
#   'train_loss': 0.01422652,
#   'valid_accuracy': 0.011904515,
#   'valid_loss': 0.011904515},
#  {'epoch': 329,
#   'train_loss': 0.014193679,
#   'valid_accuracy': 0.011868618,
#   'valid_loss': 0.011868618},
#  {'epoch': 330,
#   'train_loss': 0.014109413,
#   'valid_accuracy': 0.011897276,
#   'valid_loss': 0.011897276},
#  {'epoch': 331,
#   'train_loss': 0.014125246,
#   'valid_accuracy': 0.011867316,
#   'valid_loss': 0.011867316},
#  {'epoch': 332,
#   'train_loss': 0.014092013,
#   'valid_accuracy': 0.011852234,
#   'valid_loss': 0.011852234},
#  {'epoch': 333,
#   'train_loss': 0.014070011,
#   'valid_accuracy': 0.011824703,
#   'valid_loss': 0.011824703},
#  {'epoch': 334,
#   'train_loss': 0.01405906,
#   'valid_accuracy': 0.011776418,
#   'valid_loss': 0.011776418},
#  {'epoch': 335,
#   'train_loss': 0.014016353,
#   'valid_accuracy': 0.011771698,
#   'valid_loss': 0.011771698},
#  {'epoch': 336,
#   'train_loss': 0.014010674,
#   'valid_accuracy': 0.011726266,
#   'valid_loss': 0.011726266},
#  {'epoch': 337,
#   'train_loss': 0.013993381,
#   'valid_accuracy': 0.011678605,
#   'valid_loss': 0.011678605},
#  {'epoch': 338,
#   'train_loss': 0.013958491,
#   'valid_accuracy': 0.011701101,
#   'valid_loss': 0.011701101},
#  {'epoch': 339,
#   'train_loss': 0.013824135,
#   'valid_accuracy': 0.01168709,
#   'valid_loss': 0.01168709},
#  {'epoch': 340,
#   'train_loss': 0.013869906,
#   'valid_accuracy': 0.011737089,
#   'valid_loss': 0.011737089},
#  {'epoch': 341,
#   'train_loss': 0.013920378,
#   'valid_accuracy': 0.011639674,
#   'valid_loss': 0.011639674},
#  {'epoch': 342,
#   'train_loss': 0.013888282,
#   'valid_accuracy': 0.011619898,
#   'valid_loss': 0.011619898},
#  {'epoch': 343,
#   'train_loss': 0.013851893,
#   'valid_accuracy': 0.011570929,
#   'valid_loss': 0.011570929},
#  {'epoch': 344,
#   'train_loss': 0.013828655,
#   'valid_accuracy': 0.011525029,
#   'valid_loss': 0.011525029},
#  {'epoch': 345,
#   'train_loss': 0.013821215,
#   'valid_accuracy': 0.011593206,
#   'valid_loss': 0.011593206},
#  {'epoch': 346,
#   'train_loss': 0.013781488,
#   'valid_accuracy': 0.011525039,
#   'valid_loss': 0.011525039},
#  {'epoch': 347,
#   'train_loss': 0.013730972,
#   'valid_accuracy': 0.011520599,
#   'valid_loss': 0.011520599},
#  {'epoch': 348,
#   'train_loss': 0.013734799,
#   'valid_accuracy': 0.011487949,
#   'valid_loss': 0.011487949},
#  {'epoch': 349,
#   'train_loss': 0.013698266,
#   'valid_accuracy': 0.011462628,
#   'valid_loss': 0.011462628},
#  {'epoch': 350,
#   'train_loss': 0.01365891,
#   'valid_accuracy': 0.011476284,
#   'valid_loss': 0.011476284},
#  {'epoch': 351,
#   'train_loss': 0.013694678,
#   'valid_accuracy': 0.011480257,
#   'valid_loss': 0.011480257},
#  {'epoch': 352,
#   'train_loss': 0.01365275,
#   'valid_accuracy': 0.011445913,
#   'valid_loss': 0.011445913},
#  {'epoch': 353,
#   'train_loss': 0.01367755,
#   'valid_accuracy': 0.011391233,
#   'valid_loss': 0.011391233},
#  {'epoch': 354,
#   'train_loss': 0.0135914,
#   'valid_accuracy': 0.011386869,
#   'valid_loss': 0.011386869},
#  {'epoch': 355,
#   'train_loss': 0.013598173,
#   'valid_accuracy': 0.011387326,
#   'valid_loss': 0.011387326},
#  {'epoch': 356,
#   'train_loss': 0.013577552,
#   'valid_accuracy': 0.011381,
#   'valid_loss': 0.011381},
#  {'epoch': 357,
#   'train_loss': 0.013611072,
#   'valid_accuracy': 0.011339631,
#   'valid_loss': 0.011339631},
#  {'epoch': 358,
#   'train_loss': 0.013553075,
#   'valid_accuracy': 0.011262361,
#   'valid_loss': 0.011262361},
#  {'epoch': 359,
#   'train_loss': 0.013517315,
#   'valid_accuracy': 0.011322299,
#   'valid_loss': 0.011322299},
#  {'epoch': 360,
#   'train_loss': 0.013560718,
#   'valid_accuracy': 0.011230168,
#   'valid_loss': 0.011230168},
#  {'epoch': 361,
#   'train_loss': 0.013445379,
#   'valid_accuracy': 0.0112254,
#   'valid_loss': 0.0112254},
#  {'epoch': 362,
#   'train_loss': 0.013426407,
#   'valid_accuracy': 0.011270382,
#   'valid_loss': 0.011270382},
#  {'epoch': 363,
#   'train_loss': 0.013426675,
#   'valid_accuracy': 0.011193601,
#   'valid_loss': 0.011193601},
#  {'epoch': 364,
#   'train_loss': 0.013412731,
#   'valid_accuracy': 0.011268538,
#   'valid_loss': 0.011268538},
#  {'epoch': 365,
#   'train_loss': 0.013424514,
#   'valid_accuracy': 0.011172259,
#   'valid_loss': 0.011172259},
#  {'epoch': 366,
#   'train_loss': 0.013399072,
#   'valid_accuracy': 0.011170372,
#   'valid_loss': 0.011170372},
#  {'epoch': 367,
#   'train_loss': 0.013329023,
#   'valid_accuracy': 0.011262119,
#   'valid_loss': 0.011262119},
#  {'epoch': 368,
#   'train_loss': 0.013359731,
#   'valid_accuracy': 0.01113655,
#   'valid_loss': 0.01113655},
#  {'epoch': 369,
#   'train_loss': 0.013224755,
#   'valid_accuracy': 0.011183957,
#   'valid_loss': 0.011183957},
#  {'epoch': 370,
#   'train_loss': 0.013316082,
#   'valid_accuracy': 0.011158325,
#   'valid_loss': 0.011158325},
#  {'epoch': 371,
#   'train_loss': 0.013239568,
#   'valid_accuracy': 0.011087758,
#   'valid_loss': 0.011087758},
#  {'epoch': 372,
#   'train_loss': 0.013220388,
#   'valid_accuracy': 0.011056156,
#   'valid_loss': 0.011056156},
#  {'epoch': 373,
#   'train_loss': 0.013249471,
#   'valid_accuracy': 0.011053521,
#   'valid_loss': 0.011053521},
#  {'epoch': 374,
#   'train_loss': 0.013181677,
#   'valid_accuracy': 0.011096507,
#   'valid_loss': 0.011096507},
#  {'epoch': 375,
#   'train_loss': 0.01322742,
#   'valid_accuracy': 0.011052695,
#   'valid_loss': 0.011052695},
#  {'epoch': 376,
#   'train_loss': 0.013200732,
#   'valid_accuracy': 0.011033393,
#   'valid_loss': 0.011033393},
#  {'epoch': 377,
#   'train_loss': 0.013209624,
#   'valid_accuracy': 0.011006902,
#   'valid_loss': 0.011006902},
#  {'epoch': 378,
#   'train_loss': 0.013170804,
#   'valid_accuracy': 0.011028103,
#   'valid_loss': 0.011028103},
#  {'epoch': 379,
#   'train_loss': 0.013108629,
#   'valid_accuracy': 0.01093578,
#   'valid_loss': 0.01093578},
#  {'epoch': 380,
#   'train_loss': 0.013118623,
#   'valid_accuracy': 0.010952491,
#   'valid_loss': 0.010952491},
#  {'epoch': 381,
#   'train_loss': 0.013090611,
#   'valid_accuracy': 0.010894296,
#   'valid_loss': 0.010894296},
#  {'epoch': 382,
#   'train_loss': 0.013058391,
#   'valid_accuracy': 0.010912822,
#   'valid_loss': 0.010912822},
#  {'epoch': 383,
#   'train_loss': 0.013006954,
#   'valid_accuracy': 0.010915874,
#   'valid_loss': 0.010915874},
#  {'epoch': 384,
#   'train_loss': 0.012999011,
#   'valid_accuracy': 0.010847584,
#   'valid_loss': 0.010847584},
#  {'epoch': 385,
#   'train_loss': 0.013013988,
#   'valid_accuracy': 0.010890508,
#   'valid_loss': 0.010890508},
#  {'epoch': 386,
#   'train_loss': 0.013020294,
#   'valid_accuracy': 0.010921826,
#   'valid_loss': 0.010921826},
#  {'epoch': 387,
#   'train_loss': 0.012921536,
#   'valid_accuracy': 0.010897427,
#   'valid_loss': 0.010897427},
#  {'epoch': 388,
#   'train_loss': 0.013003123,
#   'valid_accuracy': 0.010871909,
#   'valid_loss': 0.010871909},
#  {'epoch': 389,
#   'train_loss': 0.012946415,
#   'valid_accuracy': 0.010886356,
#   'valid_loss': 0.010886356},
#  {'epoch': 390,
#   'train_loss': 0.012953977,
#   'valid_accuracy': 0.01084289,
#   'valid_loss': 0.01084289},
#  {'epoch': 391,
#   'train_loss': 0.01290953,
#   'valid_accuracy': 0.010802818,
#   'valid_loss': 0.010802818},
#  {'epoch': 392,
#   'train_loss': 0.012903499,
#   'valid_accuracy': 0.01076246,
#   'valid_loss': 0.01076246},
#  {'epoch': 393,
#   'train_loss': 0.01286283,
#   'valid_accuracy': 0.01075104,
#   'valid_loss': 0.01075104},
#  {'epoch': 394,
#   'train_loss': 0.012892699,
#   'valid_accuracy': 0.010732209,
#   'valid_loss': 0.010732209},
#  {'epoch': 395,
#   'train_loss': 0.012824806,
#   'valid_accuracy': 0.01077697,
#   'valid_loss': 0.01077697},
#  {'epoch': 396,
#   'train_loss': 0.012852648,
#   'valid_accuracy': 0.010721601,
#   'valid_loss': 0.010721601},
#  {'epoch': 397,
#   'train_loss': 0.012802501,
#   'valid_accuracy': 0.01067283,
#   'valid_loss': 0.01067283},
#  {'epoch': 398,
#   'train_loss': 0.012779515,
#   'valid_accuracy': 0.010719359,
#   'valid_loss': 0.010719359},
#  {'epoch': 399,
#   'train_loss': 0.012825247,
#   'valid_accuracy': 0.010657539,
#   'valid_loss': 0.010657539},
#  {'epoch': 400,
#   'train_loss': 0.012741293,
#   'valid_accuracy': 0.010722988,
#   'valid_loss': 0.010722988},
#  {'epoch': 401,
#   'train_loss': 0.01274499,
#   'valid_accuracy': 0.010662964,
#   'valid_loss': 0.010662964},
#  {'epoch': 402,
#   'train_loss': 0.012679662,
#   'valid_accuracy': 0.010587574,
#   'valid_loss': 0.010587574},
#  {'epoch': 403,
#   'train_loss': 0.012728603,
#   'valid_accuracy': 0.010660033,
#   'valid_loss': 0.010660033},
#  {'epoch': 404,
#   'train_loss': 0.012627646,
#   'valid_accuracy': 0.010610325,
#   'valid_loss': 0.010610325},
#  {'epoch': 405,
#   'train_loss': 0.012681303,
#   'valid_accuracy': 0.010642171,
#   'valid_loss': 0.010642171},
#  {'epoch': 406,
#   'train_loss': 0.012653133,
#   'valid_accuracy': 0.010572908,
#   'valid_loss': 0.010572908},
#  {'epoch': 407,
#   'train_loss': 0.012618879,
#   'valid_accuracy': 0.010490765,
#   'valid_loss': 0.010490765},
#  {'epoch': 408,
#   'train_loss': 0.012585622,
#   'valid_accuracy': 0.010545924,
#   'valid_loss': 0.010545924},
#  {'epoch': 409,
#   'train_loss': 0.01263472,
#   'valid_accuracy': 0.010459183,
#   'valid_loss': 0.010459183},
#  {'epoch': 410,
#   'train_loss': 0.012513801,
#   'valid_accuracy': 0.010510688,
#   'valid_loss': 0.010510688},
#  {'epoch': 411,
#   'train_loss': 0.012609254,
#   'valid_accuracy': 0.01054484,
#   'valid_loss': 0.01054484},
#  {'epoch': 412,
#   'train_loss': 0.012573279,
#   'valid_accuracy': 0.010517324,
#   'valid_loss': 0.010517324},
#  {'epoch': 413,
#   'train_loss': 0.012509499,
#   'valid_accuracy': 0.010479007,
#   'valid_loss': 0.010479007},
#  {'epoch': 414,
#   'train_loss': 0.012473268,
#   'valid_accuracy': 0.010461797,
#   'valid_loss': 0.010461797},
#  {'epoch': 415,
#   'train_loss': 0.012540634,
#   'valid_accuracy': 0.010504928,
#   'valid_loss': 0.010504928},
#  {'epoch': 416,
#   'train_loss': 0.012527366,
#   'valid_accuracy': 0.010438493,
#   'valid_loss': 0.010438493},
#  {'epoch': 417,
#   'train_loss': 0.012487721,
#   'valid_accuracy': 0.010432944,
#   'valid_loss': 0.010432944},
#  {'epoch': 418,
#   'train_loss': 0.012489082,
#   'valid_accuracy': 0.010408429,
#   'valid_loss': 0.010408429},
#  {'epoch': 419,
#   'train_loss': 0.012473584,
#   'valid_accuracy': 0.010431983,
#   'valid_loss': 0.010431983},
#  {'epoch': 420,
#   'train_loss': 0.01243835,
#   'valid_accuracy': 0.010409364,
#   'valid_loss': 0.010409364},
#  {'epoch': 421,
#   'train_loss': 0.012420608,
#   'valid_accuracy': 0.010362322,
#   'valid_loss': 0.010362322},
#  {'epoch': 422,
#   'train_loss': 0.01242116,
#   'valid_accuracy': 0.01041446,
#   'valid_loss': 0.01041446},
#  {'epoch': 423,
#   'train_loss': 0.012412708,
#   'valid_accuracy': 0.010449267,
#   'valid_loss': 0.010449267},
#  {'epoch': 424,
#   'train_loss': 0.012389193,
#   'valid_accuracy': 0.010344241,
#   'valid_loss': 0.010344241},
#  {'epoch': 425,
#   'train_loss': 0.012332344,
#   'valid_accuracy': 0.010318819,
#   'valid_loss': 0.010318819},
#  {'epoch': 426,
#   'train_loss': 0.012377753,
#   'valid_accuracy': 0.010355381,
#   'valid_loss': 0.010355381},
#  {'epoch': 427,
#   'train_loss': 0.012330923,
#   'valid_accuracy': 0.010299609,
#   'valid_loss': 0.010299609},
#  {'epoch': 428,
#   'train_loss': 0.012270574,
#   'valid_accuracy': 0.010262734,
#   'valid_loss': 0.010262734},
#  {'epoch': 429,
#   'train_loss': 0.012262127,
#   'valid_accuracy': 0.010344586,
#   'valid_loss': 0.010344586},
#  {'epoch': 430,
#   'train_loss': 0.012309105,
#   'valid_accuracy': 0.010313649,
#   'valid_loss': 0.010313649},
#  {'epoch': 431,
#   'train_loss': 0.012228334,
#   'valid_accuracy': 0.010223792,
#   'valid_loss': 0.010223792},
#  {'epoch': 432,
#   'train_loss': 0.012245437,
#   'valid_accuracy': 0.010200244,
#   'valid_loss': 0.010200244},
#  {'epoch': 433,
#   'train_loss': 0.012148852,
#   'valid_accuracy': 0.010208343,
#   'valid_loss': 0.010208343},
#  {'epoch': 434,
#   'train_loss': 0.012187189,
#   'valid_accuracy': 0.01023687,
#   'valid_loss': 0.01023687},
#  {'epoch': 435,
#   'train_loss': 0.012225248,
#   'valid_accuracy': 0.010208491,
#   'valid_loss': 0.010208491},
#  {'epoch': 436,
#   'train_loss': 0.012185778,
#   'valid_accuracy': 0.010138345,
#   'valid_loss': 0.010138345},
#  {'epoch': 437,
#   'train_loss': 0.012199573,
#   'valid_accuracy': 0.010219262,
#   'valid_loss': 0.010219262},
#  {'epoch': 438,
#   'train_loss': 0.012238108,
#   'valid_accuracy': 0.010182241,
#   'valid_loss': 0.010182241},
#  {'epoch': 439,
#   'train_loss': 0.012154946,
#   'valid_accuracy': 0.010171824,
#   'valid_loss': 0.010171824},
#  {'epoch': 440,
#   'train_loss': 0.01215714,
#   'valid_accuracy': 0.010110014,
#   'valid_loss': 0.010110014},
#  {'epoch': 441,
#   'train_loss': 0.012066026,
#   'valid_accuracy': 0.010164726,
#   'valid_loss': 0.010164726},
#  {'epoch': 442,
#   'train_loss': 0.012152021,
#   'valid_accuracy': 0.010141331,
#   'valid_loss': 0.010141331},
#  {'epoch': 443,
#   'train_loss': 0.012084105,
#   'valid_accuracy': 0.010125248,
#   'valid_loss': 0.010125248},
#  {'epoch': 444,
#   'train_loss': 0.012043775,
#   'valid_accuracy': 0.010126512,
#   'valid_loss': 0.010126512},
#  {'epoch': 445,
#   'train_loss': 0.012072315,
#   'valid_accuracy': 0.0101067,
#   'valid_loss': 0.0101067},
#  {'epoch': 446,
#   'train_loss': 0.012093647,
#   'valid_accuracy': 0.01008298,
#   'valid_loss': 0.01008298},
#  {'epoch': 447,
#   'train_loss': 0.012010906,
#   'valid_accuracy': 0.010029792,
#   'valid_loss': 0.010029792},
#  {'epoch': 448,
# ...
#   'valid_loss': 0.0055479393},
#  {'epoch': 2671,
#   'train_loss': 0.0036151528,
#   'valid_accuracy': 0.0055674133,
#   'valid_loss': 0.0055674133},
#  {'epoch': 2672,
#   'train_loss': 0.0036238637,
#   'valid_accuracy': 0.0055549969,
#   'valid_loss': 0.0055549969},
#  {'epoch': 2673,
#   'train_loss': 0.0035460398,
#   'valid_accuracy': 0.0055991774,
#   'valid_loss': 0.0055991774},
#  {'epoch': 2674,
#   'train_loss': 0.0035529702,
#   'valid_accuracy': 0.0055558947,
#   'valid_loss': 0.0055558947},
#  {'epoch': 2675,
#   'train_loss': 0.0035155858,
#   'valid_accuracy': 0.0055940151,
#   'valid_loss': 0.0055940151},
#  {'epoch': 2676,
#   'train_loss': 0.0035611384,
#   'valid_accuracy': 0.005575947,
#   'valid_loss': 0.005575947},
#  {'epoch': 2677,
#   'train_loss': 0.0035935517,
#   'valid_accuracy': 0.0056041991,
#   'valid_loss': 0.0056041991},
#  {'epoch': 2678,
#   'train_loss': 0.0035478235,
#   'valid_accuracy': 0.0056006056,
#   'valid_loss': 0.0056006056},
#  {'epoch': 2679,
#   'train_loss': 0.0035339675,
#   'valid_accuracy': 0.0055756024,
#   'valid_loss': 0.0055756024},
#  {'epoch': 2680,
#   'train_loss': 0.0034855604,
#   'valid_accuracy': 0.005584192,
#   'valid_loss': 0.005584192},
#  {'epoch': 2681,
#   'train_loss': 0.0036146003,
#   'valid_accuracy': 0.0055712708,
#   'valid_loss': 0.0055712708},
#  {'epoch': 2682,
#   'train_loss': 0.0035625689,
#   'valid_accuracy': 0.0056052068,
#   'valid_loss': 0.0056052068},
#  {'epoch': 2683,
#   'train_loss': 0.003601077,
#   'valid_accuracy': 0.0055934549,
#   'valid_loss': 0.0055934549},
#  {'epoch': 2684,
#   'train_loss': 0.0035777816,
#   'valid_accuracy': 0.005579419,
#   'valid_loss': 0.005579419},
#  {'epoch': 2685,
#   'train_loss': 0.0035649219,
#   'valid_accuracy': 0.005634882,
#   'valid_loss': 0.005634882},
#  {'epoch': 2686,
#   'train_loss': 0.0036039944,
#   'valid_accuracy': 0.0055966312,
#   'valid_loss': 0.0055966312},
#  {'epoch': 2687,
#   'train_loss': 0.0036065555,
#   'valid_accuracy': 0.0056335032,
#   'valid_loss': 0.0056335032},
#  {'epoch': 2688,
#   'train_loss': 0.0035268781,
#   'valid_accuracy': 0.0055438476,
#   'valid_loss': 0.0055438476},
#  {'epoch': 2689,
#   'train_loss': 0.0035477234,
#   'valid_accuracy': 0.0055740112,
#   'valid_loss': 0.0055740112},
#  {'epoch': 2690,
#   'train_loss': 0.0035352996,
#   'valid_accuracy': 0.0055862106,
#   'valid_loss': 0.0055862106},
#  {'epoch': 2691,
#   'train_loss': 0.003556015,
#   'valid_accuracy': 0.005566333,
#   'valid_loss': 0.005566333},
#  {'epoch': 2692,
#   'train_loss': 0.0035313782,
#   'valid_accuracy': 0.0056123319,
#   'valid_loss': 0.0056123319},
#  {'epoch': 2693,
#   'train_loss': 0.0035562646,
#   'valid_accuracy': 0.0055735521,
#   'valid_loss': 0.0055735521},
#  {'epoch': 2694,
#   'train_loss': 0.0035606646,
#   'valid_accuracy': 0.0056129834,
#   'valid_loss': 0.0056129834},
#  {'epoch': 2695,
#   'train_loss': 0.0035305978,
#   'valid_accuracy': 0.0055673281,
#   'valid_loss': 0.0055673281},
#  {'epoch': 2696,
#   'train_loss': 0.00360524,
#   'valid_accuracy': 0.0055753281,
#   'valid_loss': 0.0055753281},
#  {'epoch': 2697,
#   'train_loss': 0.003538162,
#   'valid_accuracy': 0.0055847727,
#   'valid_loss': 0.0055847727},
#  {'epoch': 2698,
#   'train_loss': 0.0035098887,
#   'valid_accuracy': 0.005592837,
#   'valid_loss': 0.005592837},
#  {'epoch': 2699,
#   'train_loss': 0.003531799,
#   'valid_accuracy': 0.0055619613,
#   'valid_loss': 0.0055619613},
#  {'epoch': 2700,
#   'train_loss': 0.0035519339,
#   'valid_accuracy': 0.0055782851,
#   'valid_loss': 0.0055782851},
#  {'epoch': 2701,
#   'train_loss': 0.0035376006,
#   'valid_accuracy': 0.0055870041,
#   'valid_loss': 0.0055870041},
#  {'epoch': 2702,
#   'train_loss': 0.0034904715,
#   'valid_accuracy': 0.0055752089,
#   'valid_loss': 0.0055752089},
#  {'epoch': 2703,
#   'train_loss': 0.0035320327,
#   'valid_accuracy': 0.0055823219,
#   'valid_loss': 0.0055823219},
#  {'epoch': 2704,
#   'train_loss': 0.003550333,
#   'valid_accuracy': 0.0055691744,
#   'valid_loss': 0.0055691744},
#  {'epoch': 2705,
#   'train_loss': 0.0035293971,
#   'valid_accuracy': 0.0055916789,
#   'valid_loss': 0.0055916789},
#  {'epoch': 2706,
#   'train_loss': 0.0034817422,
#   'valid_accuracy': 0.0056014326,
#   'valid_loss': 0.0056014326},
#  {'epoch': 2707,
#   'train_loss': 0.0034709272,
#   'valid_accuracy': 0.0055734185,
#   'valid_loss': 0.0055734185},
#  {'epoch': 2708,
#   'train_loss': 0.0034897309,
#   'valid_accuracy': 0.0055637397,
#   'valid_loss': 0.0055637397},
#  {'epoch': 2709,
#   'train_loss': 0.0035461872,
#   'valid_accuracy': 0.0055455049,
#   'valid_loss': 0.0055455049},
#  {'epoch': 2710,
#   'train_loss': 0.0035158291,
#   'valid_accuracy': 0.0055585257,
#   'valid_loss': 0.0055585257},
#  {'epoch': 2711,
#   'train_loss': 0.0034843388,
#   'valid_accuracy': 0.0055609648,
#   'valid_loss': 0.0055609648},
#  {'epoch': 2712,
#   'train_loss': 0.0035341752,
#   'valid_accuracy': 0.0055676508,
#   'valid_loss': 0.0055676508},
#  {'epoch': 2713,
#   'train_loss': 0.0035317268,
#   'valid_accuracy': 0.0055302498,
#   'valid_loss': 0.0055302498},
#  {'epoch': 2714,
#   'train_loss': 0.0035076845,
#   'valid_accuracy': 0.0056001022,
#   'valid_loss': 0.0056001022},
#  {'epoch': 2715,
#   'train_loss': 0.0035528075,
#   'valid_accuracy': 0.0055849003,
#   'valid_loss': 0.0055849003},
#  {'epoch': 2716,
#   'train_loss': 0.0035442947,
#   'valid_accuracy': 0.005592952,
#   'valid_loss': 0.005592952},
#  {'epoch': 2717,
#   'train_loss': 0.0034929509,
#   'valid_accuracy': 0.0055408822,
#   'valid_loss': 0.0055408822},
#  {'epoch': 2718,
#   'train_loss': 0.0035175569,
#   'valid_accuracy': 0.0055752527,
#   'valid_loss': 0.0055752527},
#  {'epoch': 2719,
#   'train_loss': 0.0035492317,
#   'valid_accuracy': 0.005567323,
#   'valid_loss': 0.005567323},
#  {'epoch': 2720,
#   'train_loss': 0.0035174696,
#   'valid_accuracy': 0.0055524977,
#   'valid_loss': 0.0055524977},
#  {'epoch': 2721,
#   'train_loss': 0.0034921623,
#   'valid_accuracy': 0.0055462397,
#   'valid_loss': 0.0055462397},
#  {'epoch': 2722,
#   'train_loss': 0.0035626197,
#   'valid_accuracy': 0.0055754688,
#   'valid_loss': 0.0055754688},
#  {'epoch': 2723,
#   'train_loss': 0.003470785,
#   'valid_accuracy': 0.0056096623,
#   'valid_loss': 0.0056096623},
#  {'epoch': 2724,
#   'train_loss': 0.0035018343,
#   'valid_accuracy': 0.0055761193,
#   'valid_loss': 0.0055761193},
#  {'epoch': 2725,
#   'train_loss': 0.0034939365,
#   'valid_accuracy': 0.0055820546,
#   'valid_loss': 0.0055820546},
#  {'epoch': 2726,
#   'train_loss': 0.0035054137,
#   'valid_accuracy': 0.005600119,
#   'valid_loss': 0.005600119},
#  {'epoch': 2727,
#   'train_loss': 0.0035580285,
#   'valid_accuracy': 0.0055578984,
#   'valid_loss': 0.0055578984},
#  {'epoch': 2728,
#   'train_loss': 0.0035198731,
#   'valid_accuracy': 0.0055405898,
#   'valid_loss': 0.0055405898},
#  {'epoch': 2729,
#   'train_loss': 0.0035391354,
#   'valid_accuracy': 0.0055690049,
#   'valid_loss': 0.0055690049},
#  {'epoch': 2730,
#   'train_loss': 0.0035161139,
#   'valid_accuracy': 0.0055707581,
#   'valid_loss': 0.0055707581},
#  {'epoch': 2731,
#   'train_loss': 0.0034631342,
#   'valid_accuracy': 0.0055380771,
#   'valid_loss': 0.0055380771},
#  {'epoch': 2732,
#   'train_loss': 0.0035307177,
#   'valid_accuracy': 0.0055427761,
#   'valid_loss': 0.0055427761},
#  {'epoch': 2733,
#   'train_loss': 0.00351,
#   'valid_accuracy': 0.0055523342,
#   'valid_loss': 0.0055523342},
#  {'epoch': 2734,
#   'train_loss': 0.00352591,
#   'valid_accuracy': 0.005597746,
#   'valid_loss': 0.005597746},
#  {'epoch': 2735,
#   'train_loss': 0.00350012,
#   'valid_accuracy': 0.0055517764,
#   'valid_loss': 0.0055517764},
#  {'epoch': 2736,
#   'train_loss': 0.003492719,
#   'valid_accuracy': 0.0055217617,
#   'valid_loss': 0.0055217617},
#  {'epoch': 2737,
#   'train_loss': 0.0034829981,
#   'valid_accuracy': 0.005606378,
#   'valid_loss': 0.005606378},
#  {'epoch': 2738,
#   'train_loss': 0.0034216074,
#   'valid_accuracy': 0.0056468574,
#   'valid_loss': 0.0056468574},
#  {'epoch': 2739,
#   'train_loss': 0.0034580072,
#   'valid_accuracy': 0.0055496162,
#   'valid_loss': 0.0055496162},
#  {'epoch': 2740,
#   'train_loss': 0.0035052856,
#   'valid_accuracy': 0.0055754068,
#   'valid_loss': 0.0055754068},
#  {'epoch': 2741,
#   'train_loss': 0.0035359203,
#   'valid_accuracy': 0.0055455239,
#   'valid_loss': 0.0055455239},
#  {'epoch': 2742,
#   'train_loss': 0.0034965307,
#   'valid_accuracy': 0.0055455859,
#   'valid_loss': 0.0055455859},
#  {'epoch': 2743,
#   'train_loss': 0.0035128517,
#   'valid_accuracy': 0.0055456976,
#   'valid_loss': 0.0055456976},
#  {'epoch': 2744,
#   'train_loss': 0.0034973049,
#   'valid_accuracy': 0.0055704955,
#   'valid_loss': 0.0055704955},
#  {'epoch': 2745,
#   'train_loss': 0.0035269838,
#   'valid_accuracy': 0.0055630556,
#   'valid_loss': 0.0055630556},
#  {'epoch': 2746,
#   'train_loss': 0.0035360432,
#   'valid_accuracy': 0.0055409917,
#   'valid_loss': 0.0055409917},
#  {'epoch': 2747,
#   'train_loss': 0.0035302036,
#   'valid_accuracy': 0.0055571189,
#   'valid_loss': 0.0055571189},
#  {'epoch': 2748,
#   'train_loss': 0.0035114062,
#   'valid_accuracy': 0.0055635525,
#   'valid_loss': 0.0055635525},
#  {'epoch': 2749,
#   'train_loss': 0.003492028,
#   'valid_accuracy': 0.005553578,
#   'valid_loss': 0.005553578},
#  {'epoch': 2750,
#   'train_loss': 0.0034666688,
#   'valid_accuracy': 0.0055448548,
#   'valid_loss': 0.0055448548},
#  {'epoch': 2751,
#   'train_loss': 0.0035302066,
#   'valid_accuracy': 0.0055706836,
#   'valid_loss': 0.0055706836},
#  {'epoch': 2752,
#   'train_loss': 0.0034607402,
#   'valid_accuracy': 0.0055610049,
#   'valid_loss': 0.0055610049},
#  {'epoch': 2753,
#   'train_loss': 0.0035049645,
#   'valid_accuracy': 0.0055711428,
#   'valid_loss': 0.0055711428},
#  {'epoch': 2754,
#   'train_loss': 0.0035061103,
#   'valid_accuracy': 0.0055774031,
#   'valid_loss': 0.0055774031},
#  {'epoch': 2755,
#   'train_loss': 0.0034583565,
#   'valid_accuracy': 0.0055313632,
#   'valid_loss': 0.0055313632},
#  {'epoch': 2756,
#   'train_loss': 0.0034772127,
#   'valid_accuracy': 0.0055780304,
#   'valid_loss': 0.0055780304},
#  {'epoch': 2757,
#   'train_loss': 0.0035562036,
#   'valid_accuracy': 0.0055776443,
#   'valid_loss': 0.0055776443},
#  {'epoch': 2758,
#   'train_loss': 0.0035226061,
#   'valid_accuracy': 0.0055141198,
#   'valid_loss': 0.0055141198},
#  {'epoch': 2759,
#   'train_loss': 0.0034386839,
#   'valid_accuracy': 0.0055667632,
#   'valid_loss': 0.0055667632},
#  {'epoch': 2760,
#   'train_loss': 0.0034274075,
#   'valid_accuracy': 0.0055710226,
#   'valid_loss': 0.0055710226},
#  {'epoch': 2761,
#   'train_loss': 0.0034300997,
#   'valid_accuracy': 0.0055274921,
#   'valid_loss': 0.0055274921},
#  {'epoch': 2762,
#   'train_loss': 0.00347484,
#   'valid_accuracy': 0.0055494118,
#   'valid_loss': 0.0055494118},
#  {'epoch': 2763,
#   'train_loss': 0.003480264,
#   'valid_accuracy': 0.0055743568,
#   'valid_loss': 0.0055743568},
#  {'epoch': 2764,
#   'train_loss': 0.0035646805,
#   'valid_accuracy': 0.0055448716,
#   'valid_loss': 0.0055448716},
#  {'epoch': 2765,
#   'train_loss': 0.003462876,
#   'valid_accuracy': 0.0055980585,
#   'valid_loss': 0.0055980585},
#  {'epoch': 2766,
#   'train_loss': 0.003411941,
#   'valid_accuracy': 0.0055787228,
#   'valid_loss': 0.0055787228},
#  {'epoch': 2767,
#   'train_loss': 0.0034890082,
#   'valid_accuracy': 0.0055366838,
#   'valid_loss': 0.0055366838},
#  {'epoch': 2768,
#   'train_loss': 0.0034346243,
#   'valid_accuracy': 0.0055489764,
#   'valid_loss': 0.0055489764},
#  {'epoch': 2769,
#   'train_loss': 0.0034606529,
#   'valid_accuracy': 0.0055632531,
#   'valid_loss': 0.0055632531},
#  {'epoch': 2770,
#   'train_loss': 0.0034770924,
#   'valid_accuracy': 0.0055907457,
#   'valid_loss': 0.0055907457},
#  {'epoch': 2771,
#   'train_loss': 0.0034623265,
#   'valid_accuracy': 0.0055346885,
#   'valid_loss': 0.0055346885},
#  {'epoch': 2772,
#   'train_loss': 0.0034302503,
#   'valid_accuracy': 0.0055917762,
#   'valid_loss': 0.0055917762},
#  {'epoch': 2773,
#   'train_loss': 0.0034406304,
#   'valid_accuracy': 0.0055537266,
#   'valid_loss': 0.0055537266},
#  {'epoch': 2774,
#   'train_loss': 0.0034838738,
#   'valid_accuracy': 0.0055630347,
#   'valid_loss': 0.0055630347},
#  {'epoch': 2775,
#   'train_loss': 0.0034640238,
#   'valid_accuracy': 0.0055529862,
#   'valid_loss': 0.0055529862},
#  {'epoch': 2776,
#   'train_loss': 0.0034783594,
#   'valid_accuracy': 0.0056176395,
#   'valid_loss': 0.0056176395},
#  {'epoch': 2777,
#   'train_loss': 0.0033850854,
#   'valid_accuracy': 0.0055860481,
#   'valid_loss': 0.0055860481},
#  {'epoch': 2778,
#   'train_loss': 0.0034868428,
#   'valid_accuracy': 0.0055580726,
#   'valid_loss': 0.0055580726},
#  {'epoch': 2779,
#   'train_loss': 0.0035153776,
#   'valid_accuracy': 0.0055888179,
#   'valid_loss': 0.0055888179},
#  {'epoch': 2780,
#   'train_loss': 0.003485031,
#   'valid_accuracy': 0.0055679092,
#   'valid_loss': 0.0055679092},
#  {'epoch': 2781,
#   'train_loss': 0.0034242331,
#   'valid_accuracy': 0.0055357465,
#   'valid_loss': 0.0055357465},
#  {'epoch': 2782,
#   'train_loss': 0.0034456661,
#   'valid_accuracy': 0.0055465708,
#   'valid_loss': 0.0055465708},
#  {'epoch': 2783,
#   'train_loss': 0.003465984,
#   'valid_accuracy': 0.0055396562,
#   'valid_loss': 0.0055396562},
#  {'epoch': 2784,
#   'train_loss': 0.00341726,
#   'valid_accuracy': 0.0055685001,
#   'valid_loss': 0.0055685001},
#  {'epoch': 2785,
#   'train_loss': 0.0034184998,
#   'valid_accuracy': 0.0055330107,
#   'valid_loss': 0.0055330107},
#  {'epoch': 2786,
#   'train_loss': 0.0034629691,
#   'valid_accuracy': 0.0055473316,
#   'valid_loss': 0.0055473316},
#  {'epoch': 2787,
#   'train_loss': 0.0033888356,
#   'valid_accuracy': 0.0055513135,
#   'valid_loss': 0.0055513135},
#  {'epoch': 2788,
#   'train_loss': 0.0034900147,
#   'valid_accuracy': 0.0056044743,
#   'valid_loss': 0.0056044743},
#  {'epoch': 2789,
#   'train_loss': 0.0035043696,
#   'valid_accuracy': 0.005518564,
#   'valid_loss': 0.005518564},
#  {'epoch': 2790,
#   'train_loss': 0.0034443955,
#   'valid_accuracy': 0.0055825105,
#   'valid_loss': 0.0055825105},
#  {'epoch': 2791,
#   'train_loss': 0.0034780893,
#   'valid_accuracy': 0.005602133,
#   'valid_loss': 0.005602133},
#  {'epoch': 2792,
#   'train_loss': 0.0033878845,
#   'valid_accuracy': 0.0055536455,
#   'valid_loss': 0.0055536455},
#  {'epoch': 2793,
#   'train_loss': 0.0034340515,
#   'valid_accuracy': 0.0055621723,
#   'valid_loss': 0.0055621723},
#  {'epoch': 2794,
#   'train_loss': 0.0034366907,
#   'valid_accuracy': 0.0055290856,
#   'valid_loss': 0.0055290856},
#  {'epoch': 2795,
#   'train_loss': 0.0034735806,
#   'valid_accuracy': 0.005556548,
#   'valid_loss': 0.005556548},
#  {'epoch': 2796,
#   'train_loss': 0.0034637644,
#   'valid_accuracy': 0.0055634254,
#   'valid_loss': 0.0055634254},
#  {'epoch': 2797,
#   'train_loss': 0.0034608187,
#   'valid_accuracy': 0.005590667,
#   'valid_loss': 0.005590667},
#  {'epoch': 2798,
#   'train_loss': 0.0034080921,
#   'valid_accuracy': 0.0055367216,
#   'valid_loss': 0.0055367216},
#  {'epoch': 2799,
#   'train_loss': 0.0034179715,
#   'valid_accuracy': 0.0055520758,
#   'valid_loss': 0.0055520758},
#  {'epoch': 2800,
#   'train_loss': 0.0034436684,
#   'valid_accuracy': 0.0055537033,
#   'valid_loss': 0.0055537033},
#  {'epoch': 2801,
#   'train_loss': 0.0033891154,
#   'valid_accuracy': 0.0055217086,
#   'valid_loss': 0.0055217086},
#  {'epoch': 2802,
#   'train_loss': 0.003494442,
#   'valid_accuracy': 0.0055870526,
#   'valid_loss': 0.0055870526},
#  {'epoch': 2803,
#   'train_loss': 0.0034517334,
#   'valid_accuracy': 0.0055637797,
#   'valid_loss': 0.0055637797},
#  {'epoch': 2804,
#   'train_loss': 0.003388783,
#   'valid_accuracy': 0.0055725127,
#   'valid_loss': 0.0055725127},
#  {'epoch': 2805,
#   'train_loss': 0.0034142886,
#   'valid_accuracy': 0.0055388953,
#   'valid_loss': 0.0055388953},
#  {'epoch': 2806,
#   'train_loss': 0.0034413745,
#   'valid_accuracy': 0.0055528469,
#   'valid_loss': 0.0055528469},
#  {'epoch': 2807,
#   'train_loss': 0.0034844414,
#   'valid_accuracy': 0.0055480101,
#   'valid_loss': 0.0055480101},
#  {'epoch': 2808,
#   'train_loss': 0.0034031929,
#   'valid_accuracy': 0.0055911527,
#   'valid_loss': 0.0055911527},
#  {'epoch': 2809,
#   'train_loss': 0.003429634,
#   'valid_accuracy': 0.0055661132,
#   'valid_loss': 0.0055661132},
#  {'epoch': 2810,
#   'train_loss': 0.003434821,
#   'valid_accuracy': 0.0055438089,
#   'valid_loss': 0.0055438089},
#  {'epoch': 2811,
#   'train_loss': 0.0033914451,
#   'valid_accuracy': 0.0055678347,
#   'valid_loss': 0.0055678347},
#  {'epoch': 2812,
#   'train_loss': 0.0034212605,
#   'valid_accuracy': 0.0055629779,
#   'valid_loss': 0.0055629779},
#  {'epoch': 2813,
#   'train_loss': 0.0034160938,
#   'valid_accuracy': 0.0056013921,
#   'valid_loss': 0.0056013921}]

# %%
# net7.dropout1_p = 0.2
# net7.dropout2_p = 0.3
# net7.dropout3_p = 0.4
net7.max_epochs = 2500

# %%
import sys
sys.setrecursionlimit(10000)

X_6, y_6 = transform_6(x, y)
# %time net7.fit(X_6, y_6)

import cPickle as pickle
with open('Lasagne_7th_test1_0.pickle', 'wb') as f:
    pickle.dump(net7, f, -1)

# %%
train_loss_6 = np.array([i["train_loss"] for i in net7.train_history_])
valid_loss_6 = np.array([i["valid_loss"] for i in net7.train_history_])
pyplot.plot(train_loss_6, linewidth=3, label="train")
pyplot.plot(valid_loss_6, linewidth=3, label="valid")
pyplot.grid()
pyplot.legend()
pyplot.xlabel("epoch")
pyplot.ylabel("loss")
pyplot.ylim(0.1e-2, 3.2e-2)
# pyplot.yscale("log")
pyplot.show()

# %%
# from sklearn import metrics

# Xt_6, yt_6 = transform_6(X_test, y_test)

# # overfit result, should use validation result
# y_pred = net7.predict(Xt_6)
# # print y_pred[1]
# # np.argmax(y_pred[i]),np.argmax(y[i])
# y_pred = np.array(map((lambda x: np.argmax(x)), y_pred))
# yyy = np.array(map((lambda x: np.argmax(x)), yt_6))

# print metrics.classification_report((yyy), (y_pred))

# %% [markdown]
# ## load model

# %%
# import cPickle as pickle

# with open('./Lasagne_2nd.pickle', 'rb') as f:
#     specialists = pickle.load(f)

# %% [markdown]
# ## submit test data

# %%
import pandas as pd

xx_test, yy_test = load_svmlight_file("./phase1/new/aug_test2_50.dat")

# %%
xx_test.shape

# %%
xx_test = np.array(xx_test.todense()).reshape(-1,)
# xx_train = xx_train.dtype(np.float32)
xx_test = np.float32(xx_test)
xx_test = xx_test.reshape(7472,2500)

xx_test = xx_test.astype(np.float32)

def one_hot(x,n):
    if type(x) == list:
            x = np.array(x)
    x = x.flatten()
    o_h = np.zeros((len(x),n))
    o_h[np.arange(len(x)),x] = 1
    return o_h

yy_test = yy_test.astype(int32)    
yy_test = one_hot(yy_test, 32)
yy_test = yy_test.astype(np.float32)

Xt, yt = transform_6(xx_test, yy_test)
result = net7.predict(Xt)
result = np.array(map((lambda x: np.argmax(x)), result))
result.astype(int)

# %%
df_submission = pd.DataFrame( result.astype(int) ,columns=None)

df_submission.to_csv('./Lasagne_10th_CNN_add.dat', index=None)
