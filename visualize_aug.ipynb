# %%
import numpy as np
import math
import scipy.linalg as sp
from sklearn.datasets import load_svmlight_file

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# xx_train, yy_train = load_svmlight_file("./phase1/ml14fall_train.dat")
xx_train, yy_train = load_svmlight_file("./phase1/new/aug_train_50_big.dat")

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import matplotlib.cm as cm

# %% [markdown]
# ## TSNE to visualize

# %%
# Create subset and reduce to first 50 dimensions
indices = arange(xx_train.shape[0])
random.shuffle(indices)
n_train_samples = 10000

# X_pca = PCA(n_components=50).fit_transform(X)
# X_train = X_pca[indices[:n_train_samples]]
# y_train = y[indices[:n_train_samples]]

# %%
from sklearn.decomposition import TruncatedSVD

X_reduced = TruncatedSVD(n_components=50, random_state=0).fit_transform(xx_train)
X_train = X_reduced[indices[:n_train_samples]]
y_train = yy_train[indices[:n_train_samples]]

# %%
from sklearn.manifold import TSNE

# X_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_reduced)
X_train_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_train)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 10000
# [t-SNE] Computed conditional probabilities for sample 2000 / 10000
# [t-SNE] Computed conditional probabilities for sample 3000 / 10000
# [t-SNE] Computed conditional probabilities for sample 4000 / 10000
# [t-SNE] Computed conditional probabilities for sample 5000 / 10000
# [t-SNE] Computed conditional probabilities for sample 6000 / 10000
# [t-SNE] Computed conditional probabilities for sample 7000 / 10000
# [t-SNE] Computed conditional probabilities for sample 8000 / 10000
# [t-SNE] Computed conditional probabilities for sample 9000 / 10000
# [t-SNE] Computed conditional probabilities for sample 10000 / 10000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 10: error = 25.9648409, gradient norm = 0.0305100
# [t-SNE] Iteration 20: error = 26.3356257, gradient norm = 0.0468407
# [t-SNE] Iteration 30: error = 25.6064887, gradient norm = 0.0506836
# [t-SNE] Iteration 40: error = 25.1695154, gradient norm = 0.0502339
# [t-SNE] Iteration 50: error = 25.1082963, gradient norm = 0.0489270
# [t-SNE] Iteration 60: error = 23.6615906, gradient norm = 0.0319101
# [t-SNE] Iteration 70: error = 23.8446263, gradient norm = 0.0356079
# [t-SNE] Iteration 80: error = 23.9996167, gradient norm = 0.0425339
# [t-SNE] Iteration 83: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 83 iterations with early exaggeration: 24.038673
# [t-SNE] Iteration 90: error = 4.0463031, gradient norm = 0.0050479
# [t-SNE] Iteration 100: error = 3.6987651, gradient norm = 0.0027487
# [t-SNE] Iteration 110: error = 3.5919994, gradient norm = 0.0018233
# [t-SNE] Iteration 120: error = 3.5468798, gradient norm = 0.0016180
# [t-SNE] Iteration 130: error = 3.5238935, gradient norm = 0.0015504
# [t-SNE] Iteration 140: error = 3.5111782, gradient norm = 0.0015165
# [t-SNE] Iteration 150: error = 3.5038773, gradient norm = 0.0014980
# [t-SNE] Iteration 160: error = 3.4996072, gradient norm = 0.0014872
# [t-SNE] Iteration 170: error = 3.4970850, gradient norm = 0.0014809
# [t-SNE] Iteration 180: error = 3.4955869, gradient norm = 0.0014772
# [t-SNE] Iteration 190: error = 3.4946942, gradient norm = 0.0014749
# [t-SNE] Iteration 200: error = 3.4941612, gradient norm = 0.0014736
# [t-SNE] Iteration 210: error = 3.4938426, gradient norm = 0.0014728
# [t-SNE] Iteration 220: error = 3.4936521, gradient norm = 0.0014723
# [t-SNE] Iteration 230: error = 3.4935380, gradient norm = 0.0014720
# [t-SNE] Iteration 240: error = 3.4934698, gradient norm = 0.0014719
# [t-SNE] Iteration 250: error = 3.4934289, gradient norm = 0.0014718
# [t-SNE] Iteration 260: error = 3.4934045, gradient norm = 0.0014717
# [t-SNE] Iteration 270: error = 3.4933898, gradient norm = 0.0014717
# [t-SNE] Iteration 280: error = 3.4933811, gradient norm = 0.0014716
# [t-SNE] Iteration 290: error = 3.4933758, gradient norm = 0.0014716
# [t-SNE] Iteration 300: error = 3.4933727, gradient norm = 0.0014716
# [t-SNE] Iteration 310: error = 3.4933708, gradient norm = 0.0014716
# [t-SNE] Iteration 318: error difference 0.000000. Finished.
# [t-SNE] Error after 318 iterations: 3.493370

# %%
fig = figure(figsize=(10, 10))
ax = axes(frameon=False)
setp(ax, xticks=(), yticks=())
subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                wspace=0.0, hspace=0.0)
scatter(X_train_embedded[:, 0], X_train_embedded[:, 1],
        c=y_train, marker="x")

# %%
def plot_mnist(X, y, X_embedded, name, min_dist=10.0):
    fig = figure(figsize=(10, 10))
    ax = axes(frameon=False)
    title("\\textbf{MNIST dataset} -- Two-dimensional "
          "embedding of 70,000 handwritten digits with %s" % name)
    setp(ax, xticks=(), yticks=())
    subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                    wspace=0.0, hspace=0.0)
    scatter(X_embedded[:, 0], X_embedded[:, 1],
            c=y, marker="x")

    if min_dist is not None:
        from matplotlib import offsetbox
        shown_images = np.array([[15., 15.]])
        indices = arange(X_embedded.shape[0])
        random.shuffle(indices)
        for i in indices[:5000]:
            dist = np.sum((X_embedded[i] - shown_images) ** 2, 1)
            if np.min(dist) < min_dist:
                continue
            shown_images = np.r_[shown_images, [X_embedded[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(X[i].todense().reshape(50,50),
                                      cmap=cm.gray_r), X_embedded[i])
            ax.add_artist(imagebox)

# %%
plot_mnist(xx_train[indices[:n_train_samples]], y_train, X_train_embedded,
           "t-SNE", min_dist=20.0)
