# %%
import numpy as np
import math
import scipy.linalg as sp
from sklearn.datasets import load_svmlight_file

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# xx_train, yy_train = load_svmlight_file("./phase1/ml14fall_train.dat")
xx_train, yy_train = load_svmlight_file("./phase1/new/aug_train_50_big.dat")

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import matplotlib.cm as cm

# %% [markdown]
# ## TSNE to visualize

# %%
# Create subset and reduce to first 50 dimensions
indices = arange(xx_train.shape[0])
random.shuffle(indices)
n_train_samples = 15000

# X_pca = PCA(n_components=50).fit_transform(X)
# X_train = X_pca[indices[:n_train_samples]]
# y_train = y[indices[:n_train_samples]]

# %%
from sklearn.decomposition import TruncatedSVD

X_reduced = TruncatedSVD(n_components=30, random_state=0).fit_transform(xx_train)
X_train = X_reduced[indices[:n_train_samples]]
y_train = yy_train[indices[:n_train_samples]]

# %%
from sklearn.manifold import TSNE

# X_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_reduced)
X_train_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_train)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# [t-SNE] Computed conditional probabilities for sample 5000 / 15000
# [t-SNE] Computed conditional probabilities for sample 6000 / 15000
# [t-SNE] Computed conditional probabilities for sample 7000 / 15000
# [t-SNE] Computed conditional probabilities for sample 8000 / 15000
# [t-SNE] Computed conditional probabilities for sample 9000 / 15000
# [t-SNE] Computed conditional probabilities for sample 10000 / 15000
# [t-SNE] Computed conditional probabilities for sample 11000 / 15000
# [t-SNE] Computed conditional probabilities for sample 12000 / 15000
# [t-SNE] Computed conditional probabilities for sample 13000 / 15000
# [t-SNE] Computed conditional probabilities for sample 14000 / 15000
# [t-SNE] Computed conditional probabilities for sample 15000 / 15000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 10: error = 27.6502267, gradient norm = 0.0066680
# [t-SNE] Iteration 20: error = 27.7496809, gradient norm = 0.0193086
# [t-SNE] Iteration 30: error = 27.8863018, gradient norm = 0.0271268
# [t-SNE] Iteration 32: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Iteration 40: error = 27.4675339, gradient norm = 0.0156600
# [t-SNE] Iteration 50: error = 25.6755449, gradient norm = 0.0103030
# [t-SNE] Iteration 60: error = 25.0960934, gradient norm = 0.0157834
# [t-SNE] Iteration 70: error = 25.0086670, gradient norm = 0.0211004
# [t-SNE] Iteration 80: error = 25.0121071, gradient norm = 0.0248535
# [t-SNE] Iteration 90: error = 25.0713381, gradient norm = 0.0271939
# [t-SNE] Iteration 100: error = 25.1388471, gradient norm = 0.0289269
# [t-SNE] Error after 100 iterations with early exaggeration: 25.138847
# [t-SNE] Iteration 110: error = 4.3644251, gradient norm = 0.0035655
# [t-SNE] Iteration 120: error = 4.1344471, gradient norm = 0.0022390
# [t-SNE] Iteration 130: error = 4.0469465, gradient norm = 0.0018265
# [t-SNE] Iteration 140: error = 4.0067519, gradient norm = 0.0017002
# [t-SNE] Iteration 150: error = 3.9855430, gradient norm = 0.0016415
# [t-SNE] Iteration 160: error = 3.9736605, gradient norm = 0.0016112
# [t-SNE] Iteration 170: error = 3.9668004, gradient norm = 0.0015942
# [t-SNE] Iteration 180: error = 3.9627773, gradient norm = 0.0015843
# [t-SNE] Iteration 190: error = 3.9603974, gradient norm = 0.0015785
# [t-SNE] Iteration 200: error = 3.9589826, gradient norm = 0.0015750
# [t-SNE] Iteration 210: error = 3.9581390, gradient norm = 0.0015730
# [t-SNE] Iteration 220: error = 3.9576352, gradient norm = 0.0015717
# [t-SNE] Iteration 230: error = 3.9573340, gradient norm = 0.0015710
# [t-SNE] Iteration 240: error = 3.9571538, gradient norm = 0.0015706
# [t-SNE] Iteration 250: error = 3.9570460, gradient norm = 0.0015703
# [t-SNE] Iteration 260: error = 3.9569815, gradient norm = 0.0015702
# [t-SNE] Iteration 270: error = 3.9569428, gradient norm = 0.0015701
# [t-SNE] Iteration 280: error = 3.9569197, gradient norm = 0.0015700
# [t-SNE] Iteration 290: error = 3.9569059, gradient norm = 0.0015700
# [t-SNE] Iteration 300: error = 3.9568976, gradient norm = 0.0015700
# [t-SNE] Iteration 310: error = 3.9568926, gradient norm = 0.0015699
# [t-SNE] Iteration 320: error = 3.9568896, gradient norm = 0.0015699
# [t-SNE] Iteration 330: error = 3.9568879, gradient norm = 0.0015699
# [t-SNE] Iteration 337: error difference 0.000000. Finished.
# [t-SNE] Error after 337 iterations: 3.956887

# %%
fig = figure(figsize=(10, 10))
ax = axes(frameon=False)
setp(ax, xticks=(), yticks=())
subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                wspace=0.0, hspace=0.0)
scatter(X_train_embedded[:, 0], X_train_embedded[:, 1],
        c=y_train, marker="x")

# %%
def plot_mnist(X, y, X_embedded, name, min_dist=10.0):
    fig = figure(figsize=(10, 10))
    ax = axes(frameon=False)
    title("\\textbf{MNIST dataset} -- Two-dimensional "
          "embedding of 70,000 handwritten digits with %s" % name)
    setp(ax, xticks=(), yticks=())
    subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                    wspace=0.0, hspace=0.0)
    scatter(X_embedded[:, 0], X_embedded[:, 1],
            c=y, marker="x")

    if min_dist is not None:
        from matplotlib import offsetbox
        shown_images = np.array([[15., 15.]])
        indices = arange(X_embedded.shape[0])
        random.shuffle(indices)
        for i in indices[:5000]:
            dist = np.sum((X_embedded[i] - shown_images) ** 2, 1)
            if np.min(dist) < min_dist:
                continue
            shown_images = np.r_[shown_images, [X_embedded[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(X[i].todense().reshape(50,50),
                                      cmap=cm.gray_r), X_embedded[i])
            ax.add_artist(imagebox)

# %%
plot_mnist(xx_train[indices[:n_train_samples]], y_train, X_train_embedded,
           "t-SNE", min_dist=20.0)
