# %%
import numpy as np
import math
import scipy.linalg as sp
from sklearn.datasets import load_svmlight_file

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# xx_train, yy_train = load_svmlight_file("./phase1/ml14fall_train.dat")
xx_train, yy_train = load_svmlight_file("./phase1/new/new2/hogtrainsymetry.dat")

# %%
import matplotlib.pyplot as plt
from matplotlib import pylab
import matplotlib.cm as cm

# %% [markdown]
# ## TSNE to visualize

# %%
# Create subset and reduce to first 50 dimensions
indices = arange(xx_train.shape[0])
random.shuffle(indices)
n_train_samples = 15000

# X_pca = PCA(n_components=50).fit_transform(X)
# X_train = X_pca[indices[:n_train_samples]]
# y_train = y[indices[:n_train_samples]]

# %%
from sklearn.decomposition import TruncatedSVD

X_reduced = TruncatedSVD(n_components=50, random_state=0).fit_transform(xx_train)
X_train = X_reduced[indices[:n_train_samples]]
y_train = yy_train[indices[:n_train_samples]]

# %%
from sklearn.manifold import TSNE

# X_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_reduced)
X_train_embedded = TSNE(n_components=2, perplexity=40, verbose=2).fit_transform(X_train)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 15000
# [t-SNE] Computed conditional probabilities for sample 2000 / 15000
# [t-SNE] Computed conditional probabilities for sample 3000 / 15000
# [t-SNE] Computed conditional probabilities for sample 4000 / 15000
# [t-SNE] Computed conditional probabilities for sample 5000 / 15000
# [t-SNE] Computed conditional probabilities for sample 6000 / 15000
# [t-SNE] Computed conditional probabilities for sample 7000 / 15000
# [t-SNE] Computed conditional probabilities for sample 8000 / 15000
# [t-SNE] Computed conditional probabilities for sample 9000 / 15000
# [t-SNE] Computed conditional probabilities for sample 10000 / 15000
# [t-SNE] Computed conditional probabilities for sample 11000 / 15000
# [t-SNE] Computed conditional probabilities for sample 12000 / 15000
# [t-SNE] Computed conditional probabilities for sample 13000 / 15000
# [t-SNE] Computed conditional probabilities for sample 14000 / 15000
# [t-SNE] Computed conditional probabilities for sample 15000 / 15000
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] Iteration 10: error = 28.0561644, gradient norm = 0.0080021
# [t-SNE] Iteration 20: error = 28.2226852, gradient norm = 0.0251005
# [t-SNE] Iteration 30: error = 28.3692252, gradient norm = 0.0315648
# [t-SNE] Iteration 32: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Iteration 40: error = 26.9366703, gradient norm = 0.0185639
# [t-SNE] Iteration 50: error = 24.8644015, gradient norm = 0.0144853
# [t-SNE] Iteration 60: error = 24.4810771, gradient norm = 0.0205811
# [t-SNE] Iteration 70: error = 24.5374836, gradient norm = 0.0255849
# [t-SNE] Iteration 80: error = 24.6053844, gradient norm = 0.0290912
# [t-SNE] Iteration 90: error = 24.7164319, gradient norm = 0.0310463
# [t-SNE] Iteration 92: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 92 iterations with early exaggeration: 24.758782
# [t-SNE] Iteration 100: error = 4.3833545, gradient norm = 0.0042624
# [t-SNE] Iteration 110: error = 4.1109263, gradient norm = 0.0024935
# [t-SNE] Iteration 120: error = 4.0059104, gradient norm = 0.0019413
# [t-SNE] Iteration 130: error = 3.9569195, gradient norm = 0.0017937
# [t-SNE] Iteration 140: error = 3.9313958, gradient norm = 0.0016997
# [t-SNE] Iteration 150: error = 3.9173202, gradient norm = 0.0016625
# [t-SNE] Iteration 160: error = 3.9092257, gradient norm = 0.0016430
# [t-SNE] Iteration 170: error = 3.9044882, gradient norm = 0.0016319
# [t-SNE] Iteration 180: error = 3.9016887, gradient norm = 0.0016253
# [t-SNE] Iteration 190: error = 3.9000255, gradient norm = 0.0016214
# [t-SNE] Iteration 200: error = 3.8990342, gradient norm = 0.0016191
# [t-SNE] Iteration 210: error = 3.8984423, gradient norm = 0.0016177
# [t-SNE] Iteration 220: error = 3.8980885, gradient norm = 0.0016169
# [t-SNE] Iteration 230: error = 3.8978769, gradient norm = 0.0016164
# [t-SNE] Iteration 240: error = 3.8977503, gradient norm = 0.0016161
# [t-SNE] Iteration 250: error = 3.8976745, gradient norm = 0.0016159
# [t-SNE] Iteration 260: error = 3.8976291, gradient norm = 0.0016158
# [t-SNE] Iteration 270: error = 3.8976019, gradient norm = 0.0016157
# [t-SNE] Iteration 280: error = 3.8975857, gradient norm = 0.0016157
# [t-SNE] Iteration 290: error = 3.8975759, gradient norm = 0.0016157
# [t-SNE] Iteration 300: error = 3.8975701, gradient norm = 0.0016157
# [t-SNE] Iteration 310: error = 3.8975666, gradient norm = 0.0016157
# [t-SNE] Iteration 320: error = 3.8975645, gradient norm = 0.0016157
# [t-SNE] Iteration 330: error difference 0.000000. Finished.
# [t-SNE] Error after 330 iterations: 3.897563

# %%
fig = figure(figsize=(10, 10))
ax = axes(frameon=False)
setp(ax, xticks=(), yticks=())
subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                wspace=0.0, hspace=0.0)
scatter(X_train_embedded[:, 0], X_train_embedded[:, 1],
        c=y_train, marker="x")

# %%
def plot_mnist(X, y, X_embedded, name, min_dist=10.0):
    fig = figure(figsize=(10, 10))
    ax = axes(frameon=False)
    title("\\textbf{MNIST dataset} -- Two-dimensional "
          "embedding of 70,000 handwritten digits with %s" % name)
    setp(ax, xticks=(), yticks=())
    subplots_adjust(left=0.0, bottom=0.0, right=1.0, top=0.9,
                    wspace=0.0, hspace=0.0)
    scatter(X_embedded[:, 0], X_embedded[:, 1],
            c=y, marker="x")

    if min_dist is not None:
        from matplotlib import offsetbox
        shown_images = np.array([[15., 15.]])
        indices = arange(X_embedded.shape[0])
        random.shuffle(indices)
        for i in indices[:5000]:
            dist = np.sum((X_embedded[i] - shown_images) ** 2, 1)
            if np.min(dist) < min_dist:
                continue
            shown_images = np.r_[shown_images, [X_embedded[i]]]
            imagebox = offsetbox.AnnotationBbox(
                offsetbox.OffsetImage(X[i].todense().reshape(50,50),
                                      cmap=cm.gray_r), X_embedded[i])
            ax.add_artist(imagebox)

# %%
plot_mnist(xx_train[indices[:n_train_samples]], y_train, X_train_embedded,
           "t-SNE", min_dist=20.0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-591c8cbeb111> in <module>()
#       1 plot_mnist(xx_train[indices[:n_train_samples]], y_train, X_train_embedded,
# ----> 2            "t-SNE", min_dist=20.0)
#
# <ipython-input-12-aeb24be9a63e> in plot_mnist(X, y, X_embedded, name, min_dist)
#      21             shown_images = np.r_[shown_images, [X_embedded[i]]]
#      22             imagebox = offsetbox.AnnotationBbox(
# ---> 23                 offsetbox.OffsetImage(X[i].todense().reshape(50,50),
#      24                                       cmap=cm.gray_r), X_embedded[i])
#      25             ax.add_artist(imagebox)
#
# ValueError: total size of new array must be unchanged
